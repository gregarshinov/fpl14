# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# PREPROCESSING

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]
#int_words[:30]

# %% [markdown]
# SUBSAMPLING

# %%
from collections import Counter
import random
import math

treshold = 1e-5
ttreshold = 0.8
frequencies = {}
probabilities = {}
train_words = []

word_counts = Counter(int_words)

for word in word_counts:
    frequencies[word] = word_counts[word] / len(int_words)
    probabilities[word] = 1 - math.sqrt(treshold / frequencies[word])
#print(probabilities)
for word in int_words:
    if random.random() < probabilities[word]:
        train_words.append(word)
print(len(train_words))
# Out:
# 12052691

# %% [markdown]
# MAKING BATCHES

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = random.randint(1, window_size + 1)
    start = idx - r if (idx - r) > 0 else 0
    stop = idx + r
    target_words = set(words[start:idx] + words[idx + 1:stop + 1])
    
    return list(target_words)
    
   
print(get_target(int_words, 10, 5))
print(int_words[:15])
# Out:
# [741, 10571, 45, 58, 155, 476]
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133]

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# TRAINING THE GRAPH

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# EMBEDDING

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# NEGATIVE SAMPLING

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
        
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# VALIDATION

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    
    valid_size = 16               # Random set of words to evaluate similarity on.
    valid_window = 100
    
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# !mkdir checkpoints
# Out:
# Џ®¤Ї ЇЄ  Ё«Ё д ©« checkpoints г¦Ґ бгйҐбвўгҐв.

# %% [markdown]
# TRAINING

# %%
#ПОСТАРАЮСЬ ДАТЬ ДОРАБОТАТЬ ДО КОНЦА
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 8.7307 0.6114 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.4611 0.5463 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.2062 0.5450 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.4902 0.5408 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.1655 0.5584 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.8579 0.5643 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.6314 0.5422 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.5059 0.5376 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.5668 0.5439 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.5286 0.5402 sec/batch
# Nearest to by: detrimental, net, leave, required, central, equivalent, art, british,
# Nearest to not: from, friend, begum, heart, particularly, ripper, out, has,
# Nearest to if: most, failed, widespread, amalgam, he, longbows, vehicles, according,
# Nearest to about: original, seats, types, during, pedophile, since, rather, being,
# Nearest to and: rather, condition, forces, them, carriers, separated, macedonia, old,
# Nearest to it: food, systems, although, some, present, lowest, prices, defined,
# Nearest to its: charles, or, come, declared, range, miles, just, golding,
# Nearest to this: flag, town, yet, orders, against, mind, save, basic,
# Nearest to quite: believe, opposed, bulgaria, baptism, without, carried, visigothic, vacate,
# Nearest to freedom: string, high, opportunity, executive, sun, nepos, monthly, take,
# Nearest to pre: boston, loosed, fraternities, sergius, broglie, diploma, andersonville, break,
# Nearest to liberal: ring, mean, dup, jewish, activities, revolutionary, blind, sweetness,
# Nearest to test: scholars, mathematics, reactionary, luxembourgian, vol, representing, metal, animator,
# Nearest to older: trade, foundations, six, fundamental, peace, written, elongate, frequently,
# Nearest to articles: politics, enter, rafters, sun, cycle, ussachevsky, listed, nicolo,
# Nearest to shown: korea, establish, involved, scholars, genus, when, size, land,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.4744 0.5487 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.4213 0.5367 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.3506 0.5401 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.3388 0.5397 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.3701 0.5416 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.3486 0.5478 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.3455 0.5404 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.2975 0.5613 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.3252 0.5380 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.3163 0.5415 sec/batch
# Nearest to by: detrimental, net, equivalent, ma, leave, required, art, dynasty,
# Nearest to not: begum, heart, portions, solo, particularly, weeks, drinking, from,
# Nearest to if: vehicles, most, failed, widespread, he, amalgam, longbows, according,
# Nearest to about: seats, original, since, pedophile, during, types, being, separately,
# Nearest to and: carriers, condition, macedonia, separated, olympics, forces, rather, instruction,
# Nearest to it: food, systems, although, prices, lowest, while, so, buildings,
# Nearest to its: or, charles, colonies, except, come, declared, miles, withdrawal,
# Nearest to this: orders, availability, flag, save, yet, mind, town, advanced,
# Nearest to quite: baptism, bulgaria, infinite, opposed, believe, kong, carried, without,
# Nearest to freedom: duties, string, high, executive, monthly, column, opportunity, sun,
# Nearest to pre: boston, break, label, abroad, accused, genesis, shift, loosed,
# Nearest to liberal: ring, blind, jewish, revolutionary, mean, activities, militia, offers,
# Nearest to test: mathematics, scholars, representing, installed, vol, metal, mask, computers,
# Nearest to older: foundations, trade, fundamental, written, elongate, heroes, peace, past,
# Nearest to articles: politics, enter, sun, cycle, listed, internal, fleming, rafters,
# Nearest to shown: establish, korea, scholars, size, involved, when, genus, individuals,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.2888 0.5518 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.2553 0.5478 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.2277 0.5397 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.2308 0.5378 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.2386 0.5429 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.2565 0.5424 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.2248 0.5412 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.2619 0.5464 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.2571 0.5503 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.1195 0.5390 sec/batch
# Nearest to by: detrimental, ma, net, since, leave, dynasty, central, equivalent,
# Nearest to not: begum, portions, particularly, heart, solo, drinking, from, weeks,
# Nearest to if: vehicles, most, failed, complicated, human, he, cited, gets,
# Nearest to about: seats, original, separately, since, during, being, tennessee, pedophile,
# Nearest to and: condition, carriers, macedonia, olympics, forces, separated, instruction, fortress,
# Nearest to it: food, although, systems, prices, remembered, stewart, ghost, so,
# Nearest to its: or, except, colonies, withdrawal, ottoman, charles, miles, immense,
# Nearest to this: orders, availability, asking, flag, yet, save, basic, holland,
# Nearest to quite: baptism, bulgaria, infinite, opposed, believe, kong, carried, without,
# Nearest to freedom: duties, string, monthly, potentially, high, column, executive, opportunity,
# Nearest to pre: break, boston, label, abroad, genesis, accused, shift, characters,
# Nearest to liberal: ring, jewish, blind, revolutionary, militia, dup, offers, mean,
# Nearest to test: mathematics, scholars, representing, mask, installed, te, luxembourgian, reactionary,
# Nearest to older: foundations, trade, heroes, written, fundamental, elongate, past, peace,
# Nearest to articles: politics, listed, breeding, enter, sun, employ, cycle, bolivia,
# Nearest to shown: establish, scholars, involved, individuals, size, korea, when, purchased,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.2496 0.5510 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.1908 0.5383 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.2265 0.5448 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.1941 0.5406 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.2124 0.5402 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.1775 0.5388 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.1711 0.5425 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.2104 0.5448 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.1918 0.5470 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.1868 0.5485 sec/batch
# Nearest to by: ma, detrimental, since, dynasty, net, art, tribe, leave,
# Nearest to not: begum, only, portions, particularly, heart, from, drinking, destroyed,
# Nearest to if: vehicles, human, failed, complicated, most, almost, get, can,
# Nearest to about: seats, original, separately, since, being, during, organ, tennessee,
# Nearest to and: condition, carriers, olympics, much, macedonia, forces, bear, instruction,
# Nearest to it: although, food, so, remembered, systems, victorian, better, because,
# Nearest to its: or, immense, withdrawal, except, colonies, ottoman, fifteen, miles,
# Nearest to this: orders, availability, asking, yet, save, basic, flag, said,
# Nearest to quite: baptism, infinite, believe, dishes, bulgaria, opposed, without, determine,
# Nearest to freedom: duties, monthly, potentially, string, opportunity, column, high, python,
# Nearest to pre: break, abroad, boston, label, genesis, loosed, characters, accused,
# Nearest to liberal: ring, blind, jewish, militia, revolutionary, dup, offers, introducing,
# Nearest to test: mathematics, mask, representing, scholars, installed, computers, luxembourgian, reactionary,
# Nearest to older: foundations, trade, written, zeus, heroes, elongate, past, fundamental,
# Nearest to articles: politics, employ, cycle, breeding, listed, sun, internal, bolivia,
# Nearest to shown: establish, involved, individuals, scholars, when, size, purchased, roles,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.1606 0.5505 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.1494 0.5441 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.1798 0.5779 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.1699 0.5444 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.1527 0.5559 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.1421 0.5644 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.1180 0.5695 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.1551 0.5777 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.1287 0.5795 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.1456 0.5763 sec/batch
# Nearest to by: detrimental, ma, since, dynasty, tribe, leave, art, johannes,
# Nearest to not: begum, only, heart, portions, particularly, targets, shells, destroyed,
# Nearest to if: complicated, vehicles, human, failed, can, almost, cited, get,
# Nearest to about: seats, original, being, since, tennessee, separately, organ, during,
# Nearest to and: condition, much, olympics, carriers, separated, macedonia, forces, bear,
# Nearest to it: although, food, so, because, shape, victorian, remembered, better,
# Nearest to its: or, immense, withdrawal, colonies, except, ottoman, just, declared,
# Nearest to this: orders, availability, flag, asking, yet, holland, save, reflect,
# Nearest to quite: baptism, infinite, believe, opposed, dishes, determine, bulgaria, without,
# Nearest to freedom: potentially, duties, monthly, opportunity, python, column, high, string,
# Nearest to pre: break, abroad, boston, label, characters, genesis, loosed, war,
# Nearest to liberal: ring, revolutionary, blind, militia, jewish, offers, introducing, proteins,
# Nearest to test: mask, mathematics, computers, installed, representing, scholars, luxembourgian, galaxies,
# Nearest to older: foundations, zeus, written, trade, heroes, elongate, past, most,
# Nearest to articles: politics, breeding, employ, listed, min, rafters, internal, abraham,
# Nearest to shown: involved, establish, individuals, when, scholars, size, alternatively, roles,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.1771 0.5860 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.1829 0.5757 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.1410 0.5756 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.1354 0.5815 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.1300 0.5812 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.1453 0.5723 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.1347 0.5633 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.1511 0.5621 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.1574 0.5652 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.1413 0.5629 sec/batch
# Nearest to by: ma, detrimental, since, dynasty, johannes, british, era, net,
# Nearest to not: only, begum, portions, heart, particularly, impression, destroyed, targets,
# Nearest to if: complicated, vehicles, get, can, whether, human, shall, failed,
# Nearest to about: original, organ, being, separately, tennessee, since, during, seats,
# Nearest to and: carriers, much, condition, forces, macedonia, separated, olympics, instruction,
# Nearest to it: although, so, food, shape, because, robot, victorian, better,
# Nearest to its: immense, or, withdrawal, colonies, except, ottoman, imperio, caleb,
# Nearest to this: orders, asking, availability, yet, save, flag, holland, reflect,
# Nearest to quite: baptism, infinite, believe, dishes, opposed, execution, determine, without,
# Nearest to freedom: potentially, monthly, duties, opportunity, esperanto, string, silence, python,
# Nearest to pre: break, abroad, characters, boston, war, genesis, label, loosed,
# Nearest to liberal: ring, blind, revolutionary, militia, jewish, resemble, dup, introducing,
# Nearest to test: mathematics, mask, computers, installed, representing, luxembourgian, galaxies, scholars,
# Nearest to older: zeus, foundations, written, heroes, trade, past, elongate, whose,
# Nearest to articles: politics, breeding, employ, min, listed, internal, rafters, abraham,
# Nearest to shown: individuals, involved, establish, scholars, when, size, roles, copies,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.1597 0.5769 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.0784 0.5619 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.0823 0.5604 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.1180 0.5508 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.1848 0.5600 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.1123 0.5553 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.1461 0.5590 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.1594 0.5598 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.0938 0.5612 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.1183 0.5690 sec/batch
# Nearest to by: detrimental, since, ma, dynasty, equivalent, johannes, required, net,
# Nearest to not: only, begum, portions, impression, targets, heart, particularly, destroyed,
# Nearest to if: complicated, get, vehicles, shall, me, almost, whether, can,
# Nearest to about: organ, being, original, tennessee, separately, intercourse, seats, since,
# Nearest to and: condition, much, macedonia, forces, carriers, them, instruction, fortress,
# Nearest to it: although, so, because, shape, food, robot, useful, present,
# Nearest to its: immense, or, withdrawal, except, colonies, miles, caleb, time,
# Nearest to this: orders, yet, asking, reflect, availability, sort, save, flag,
# Nearest to quite: baptism, believe, infinite, dishes, without, opposed, determine, do,
# Nearest to freedom: potentially, opportunity, duties, silence, esperanto, monthly, string, python,
# Nearest to pre: abroad, break, characters, boston, genesis, label, war, loosed,
# Nearest to liberal: ring, revolutionary, militia, blind, jewish, mystical, compilations, cairo,
# Nearest to test: mathematics, mask, representing, computers, installed, luxembourgian, reactionary, animator,
# Nearest to older: zeus, written, foundations, past, heroes, elongate, trade, whose,
# Nearest to articles: politics, breeding, employ, min, internal, listed, prometaphase, ussachevsky,
# Nearest to shown: individuals, involved, establish, size, scholars, when, cases, roles,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.1391 0.5729 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.1330 0.5665 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.1162 0.5635 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.1277 0.5612 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.1251 0.5608 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.1276 0.5650 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.1367 0.5586 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.1337 0.5572 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.1087 0.5549 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.1299 0.5545 sec/batch
# Nearest to by: detrimental, since, ma, dynasty, douglas, equivalent, johannes, shakespeare,
# Nearest to not: only, portions, begum, particularly, destroyed, targets, actual, impression,
# Nearest to if: get, complicated, vehicles, will, shall, me, whether, equivalence,
# Nearest to about: being, tennessee, organ, original, intercourse, separately, since, pedophile,
# Nearest to and: much, condition, separated, forces, carriers, them, due, macedonia,
# Nearest to it: although, so, robot, because, food, shape, victorian, useful,
# Nearest to its: immense, withdrawal, or, colonies, except, ottoman, time, caleb,
# Nearest to this: orders, yet, save, availability, truly, asking, reflect, lifestyle,
# Nearest to quite: baptism, infinite, believe, dishes, opposed, without, do, determine,
# Nearest to freedom: potentially, opportunity, silence, duties, monthly, esperanto, executive, string,
# Nearest to pre: abroad, war, break, characters, loosed, genesis, fraternities, boston,
# Nearest to liberal: revolutionary, jewish, militia, cairo, ring, mystical, blind, dup,
# Nearest to test: mask, mathematics, computers, installed, representing, luxembourgian, reactionary, animator,
# Nearest to older: zeus, written, heroes, foundations, elongate, past, six, whose,
# Nearest to articles: politics, employ, min, prometaphase, internal, listed, breeding, ussachevsky,
# Nearest to shown: individuals, involved, size, establish, scholars, when, cases, purchased,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.1099 0.5635 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.1336 0.5532 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.1070 0.5631 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.0832 0.5539 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.1372 0.5625 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.1327 0.5616 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.0604 0.5603 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.1035 0.5643 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.1136 0.5606 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.1098 0.5613 sec/batch
# Nearest to by: detrimental, ma, since, equivalent, johannes, tribe, dynasty, administration,
# Nearest to not: only, begum, actual, destroyed, particularly, heart, impression, yvonne,
# Nearest to if: get, complicated, shall, whether, me, equivalence, then, will,
# Nearest to about: being, original, organ, separately, tennessee, intercourse, pedophile, since,
# Nearest to and: condition, much, carriers, macedonia, separated, when, provincial, forces,
# Nearest to it: although, so, robot, because, victorian, shape, useful, food,
# Nearest to its: immense, withdrawal, or, except, caleb, colonies, imperio, ifr,
# Nearest to this: orders, availability, yet, save, reflect, lifestyle, asking, thinkers,
# Nearest to quite: baptism, infinite, dishes, believe, without, opposed, do, carried,
# Nearest to freedom: potentially, opportunity, duties, silence, monthly, executive, penitence, string,
# Nearest to pre: abroad, war, characters, genesis, fraternities, loosed, break, boston,
# Nearest to liberal: revolutionary, militia, jewish, blind, cairo, mystical, compilations, dup,
# Nearest to test: mask, mathematics, computers, representing, installed, luxembourgian, reactionary, galaxies,
# Nearest to older: zeus, foundations, written, heroes, six, elongate, past, debates,
# Nearest to articles: breeding, employ, min, politics, prometaphase, listed, ussachevsky, internal,
# Nearest to shown: individuals, involved, establish, size, scholars, when, alternatively, cases,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 3.7473 0.5513 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 3.9941 0.5569 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 3.9116 0.5542 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 3.9968 0.5594 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.0912 0.5617 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.0548 0.5455 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.1270 0.5416 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.1173 0.5471 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.0931 0.5509 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.0842 0.5428 sec/batch
# Nearest to by: detrimental, ma, since, johannes, required, administration, ipsec, equivalent,
# Nearest to not: only, destroyed, portions, begum, impression, particularly, actual, curae,
# Nearest to if: get, shall, whether, complicated, me, will, equivalence, gets,
# Nearest to about: being, original, tennessee, organ, separately, pedophile, intercourse, barrios,
# Nearest to and: condition, much, due, when, separated, macedonia, fortress, them,
# Nearest to it: although, so, shape, food, because, robot, victorian, useful,
# Nearest to its: immense, or, withdrawal, except, colonies, caleb, ifr, time,
# Nearest to this: orders, yet, truly, save, availability, thinkers, lifestyle, asking,
# Nearest to quite: baptism, infinite, dishes, believe, do, without, opposed, carried,
# Nearest to freedom: monthly, potentially, opportunity, executive, silence, duties, eden, penitence,
# Nearest to pre: abroad, war, characters, break, fraternities, boston, loosed, label,
# Nearest to liberal: revolutionary, jewish, cairo, militia, blind, mystical, dup, compilations,
# Nearest to test: mathematics, mask, computers, representing, luxembourgian, installed, reactionary, galaxies,
# Nearest to older: zeus, written, heroes, foundations, elongate, six, whose, durrani,
# Nearest to articles: breeding, min, politics, employ, prometaphase, listed, internal, ussachevsky,
# Nearest to shown: involved, individuals, establish, scholars, size, when, roles, alternatively,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.1218 0.5549 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.0514 0.5414 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.1183 0.5414 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.1099 0.5439 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.0837 0.5432 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.0955 0.5534 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.1351 0.5586 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.0989 0.5595 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.1326 0.5613 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.0133 0.5563 sec/batch
# Nearest to by: detrimental, ma, since, johannes, administration, required, equivalent, central,
# Nearest to not: only, destroyed, impression, portions, actual, begum, particularly, yvonne,
# Nearest to if: get, complicated, whether, shall, then, equivalence, me, say,
# Nearest to about: being, original, separately, organ, intercourse, pedophile, barrios, since,
# Nearest to and: macedonia, much, condition, due, carriers, when, forces, separated,
# Nearest to it: although, so, victorian, shape, robot, because, possible, useful,
# Nearest to its: immense, or, withdrawal, except, caleb, colonies, miles, ifr,
# Nearest to this: orders, availability, yet, save, truly, asking, reflect, thinkers,
# Nearest to quite: baptism, infinite, dishes, believe, without, do, opposed, visigothic,
# Nearest to freedom: executive, opportunity, potentially, duties, eden, penitence, monthly, defenders,
# Nearest to pre: abroad, war, break, characters, fraternities, loosed, label, undergo,
# Nearest to liberal: revolutionary, political, militia, cairo, mystical, compilations, blind, jewish,
# Nearest to test: mask, mathematics, computers, representing, reactionary, luxembourgian, installed, newfoundland,
# Nearest to older: zeus, six, foundations, elongate, written, durrani, heroes, debates,
# Nearest to articles: min, breeding, politics, employ, listed, prometaphase, newspapers, internal,
# Nearest to shown: individuals, involved, establish, size, when, roles, scholars, quickly,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.0299 0.5655 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.0867 0.5577 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.0039 0.5509 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.0666 0.5567 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.1117 0.5604 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.0956 0.5582 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.0005 0.5342 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.0661 0.5406 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.0612 0.5369 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.1121 0.5461 sec/batch
# Nearest to by: detrimental, since, ma, equivalent, required, johannes, ipsec, gehrig,
# Nearest to not: only, destroyed, actual, begum, particularly, impression, curae, yvonne,
# Nearest to if: get, whether, shall, then, complicated, me, say, equivalence,
# Nearest to about: being, organ, original, intercourse, barrios, pedophile, pls, tennessee,
# Nearest to and: condition, when, much, macedonia, separated, due, them, carriers,
# Nearest to it: so, although, robot, shape, because, victorian, useful, remembered,
# Nearest to its: immense, or, withdrawal, caleb, imperio, except, acceptance, colonies,
# Nearest to this: orders, save, truly, availability, yet, reflect, lifestyle, asking,
# Nearest to quite: baptism, infinite, believe, dishes, without, do, visigothic, apis,
# Nearest to freedom: executive, duties, opportunity, potentially, eden, penitence, monthly, queen,
# Nearest to pre: abroad, war, fraternities, break, characters, pragmatism, loosed, label,
# Nearest to liberal: revolutionary, political, jewish, cairo, blind, militia, compilations, mystical,
# Nearest to test: mask, mathematics, computers, representing, reactionary, installed, luxembourgian, animator,
# Nearest to older: zeus, foundations, written, elongate, debates, frequently, heroes, six,
# Nearest to articles: min, breeding, prometaphase, politics, employ, ussachevsky, listed, newspapers,
# Nearest to shown: involved, individuals, establish, size, when, scholars, alternatively, roles,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.1110 0.2618 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.1126 0.5540 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.0836 0.5552 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.1132 0.5584 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.0263 0.5594 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.0622 0.5585 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.0472 0.5537 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 3.9397 0.5490 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 3.9813 0.5510 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.0988 0.5438 sec/batch
# Nearest to by: detrimental, ma, since, required, equivalent, be, gehrig, central,
# Nearest to not: only, destroyed, actual, particularly, begum, curae, targets, impression,
# Nearest to if: get, whether, shall, complicated, then, me, gets, equivalence,
# Nearest to about: being, intercourse, barrios, pedophile, organ, original, structured, nearby,
# Nearest to and: when, condition, macedonia, separated, much, due, them, provincial,
# Nearest to it: although, so, robot, shape, because, remembered, victorian, food,
# Nearest to its: immense, withdrawal, or, caleb, imperio, except, miles, acceptance,
# Nearest to this: orders, truly, reflect, availability, yet, lifestyle, thinkers, save,
# Nearest to quite: baptism, infinite, believe, dishes, visigothic, without, apis, execution,
# Nearest to freedom: executive, opportunity, potentially, duties, monthly, penitence, queen, eden,
# Nearest to pre: abroad, fraternities, war, loosed, break, pragmatism, genesis, characters,
# Nearest to liberal: political, revolutionary, militia, anti, compilations, mystical, jewish, cairo,
# Nearest to test: mask, mathematics, installed, computers, reactionary, crew, meier, newfoundland,
# Nearest to older: zeus, heroes, elongate, foundations, six, durrani, debates, frequently,
# Nearest to articles: min, breeding, prometaphase, employ, politics, newspapers, ussachevsky, listed,
# Nearest to shown: involved, individuals, establish, size, substantial, scholars, when, capable,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.0809 0.5475 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.0533 0.5396 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.0511 0.5361 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.0332 0.5367 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.0992 0.5453 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.0805 0.5527 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.1107 0.5559 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.0360 0.5546 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.1045 0.5534 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.0862 0.5385 sec/batch
# Nearest to by: detrimental, ma, since, johannes, required, dynasty, ipsec, central,
# Nearest to not: only, destroyed, actual, particularly, curae, yvonne, begum, impression,
# Nearest to if: whether, get, shall, then, complicated, equivalence, say, me,
# Nearest to about: being, intercourse, barrios, pedophile, organ, structured, separately, pls,
# Nearest to and: when, much, condition, due, separated, carriers, macedonia, them,
# Nearest to it: so, although, robot, shape, because, remembered, ipv, victorian,
# Nearest to its: immense, or, imperio, withdrawal, caleb, except, miles, ifr,
# Nearest to this: orders, truly, availability, reflect, basic, thinkers, yet, save,
# Nearest to quite: baptism, infinite, dishes, visigothic, believe, apis, without, kong,
# Nearest to freedom: executive, potentially, duties, penitence, monthly, opportunity, judah, esperanto,
# Nearest to pre: abroad, fraternities, war, pragmatism, characters, loosed, break, andersonville,
# Nearest to liberal: political, revolutionary, anti, militia, mystical, compilations, jewish, blind,
# Nearest to test: mask, mathematics, installed, reactionary, computers, distributist, luxembourgian, newfoundland,
# Nearest to older: zeus, six, elongate, heroes, durrani, foundations, ala, female,
# Nearest to articles: breeding, min, politics, prometaphase, ussachevsky, newspapers, employ, listed,
# Nearest to shown: involved, individuals, establish, size, substantial, scholars, roles, when,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.0979 0.5521 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.0978 0.5478 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.0965 0.5463 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.0602 0.5461 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.0621 0.5426 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.1071 0.5503 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.0842 0.5657 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.0871 0.5677 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.1006 0.5587 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.0474 0.5569 sec/batch
# Nearest to by: ma, detrimental, since, johannes, required, dynasty, administration, ipsec,
# Nearest to not: only, destroyed, actual, particularly, yvonne, curae, begum, impression,
# Nearest to if: whether, get, complicated, shall, then, equivalence, gets, me,
# Nearest to about: being, intercourse, barrios, pedophile, organ, chalcolithic, structured, tennessee,
# Nearest to and: when, due, condition, macedonia, separated, much, provincial, carriers,
# Nearest to it: although, so, robot, shape, because, ipv, food, useful,
# Nearest to its: immense, withdrawal, or, imperio, caleb, colonies, it, ifr,
# Nearest to this: orders, truly, availability, yet, basic, south, asking, thinkers,
# Nearest to quite: baptism, dishes, kong, infinite, visigothic, bringing, apis, believe,
# Nearest to freedom: executive, duties, penitence, potentially, esperanto, shimazu, opportunity, monthly,
# Nearest to pre: war, abroad, fraternities, pragmatism, loosed, genesis, break, andersonville,
# Nearest to liberal: political, militia, revolutionary, anti, cairo, compilations, dup, conservative,
# Nearest to test: mask, distributist, reactionary, installed, meier, animator, mathematics, computers,
# Nearest to older: zeus, heroes, elongate, six, ala, durrani, acceptance, frequently,
# Nearest to articles: prometaphase, min, breeding, newspapers, ussachevsky, politics, article, employ,
# Nearest to shown: involved, individuals, establish, size, substantial, scholars, roles, when,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.0419 0.5576 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.1060 0.5523 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.0625 0.5413 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.0680 0.5452 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.0893 0.5418 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.0972 0.5414 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.0433 0.5547 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.0903 0.5580 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.0827 0.5512 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.0871 0.5549 sec/batch
# Nearest to by: detrimental, ma, since, required, gehrig, ipsec, be, johannes,
# Nearest to not: only, destroyed, actual, impression, yvonne, begum, curae, targets,
# Nearest to if: whether, get, then, complicated, equivalence, shall, where, when,
# Nearest to about: being, intercourse, barrios, pedophile, how, organ, pls, fourteen,
# Nearest to and: when, much, condition, due, separated, carriers, provincial, put,
# Nearest to it: so, although, robot, shape, useful, remembered, ipv, nep,
# Nearest to its: immense, caleb, imperio, or, withdrawal, except, acceptance, derived,
# Nearest to this: orders, availability, yet, truly, basic, asking, vim, reflect,
# Nearest to quite: baptism, dishes, kong, visigothic, infinite, apis, lira, oldest,
# Nearest to freedom: executive, duties, potentially, shimazu, opportunity, penitence, monthly, quae,
# Nearest to pre: fraternities, war, abroad, pragmatism, loosed, josep, characters, tigran,
# Nearest to liberal: political, militia, conservative, revolutionary, anti, compilations, mystical, dup,
# Nearest to test: mask, distributist, reactionary, installed, mathematics, animator, meier, crew,
# Nearest to older: zeus, six, elongate, ala, durrani, heroes, debates, whose,
# Nearest to articles: prometaphase, min, politics, ussachevsky, breeding, article, publications, newspapers,
# Nearest to shown: involved, individuals, establish, size, substantial, els, scholars, wizard,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.0840 0.5663 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.0609 0.5487 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.0986 0.5562 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.0967 0.5429 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.0490 0.5398 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.0558 0.5401 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.0200 0.5429 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.0781 0.5656 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.0718 0.5593 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.0412 0.5608 sec/batch
# Nearest to by: detrimental, ma, since, gehrig, douglas, johannes, required, ipsec,
# Nearest to not: only, actual, yvonne, impression, destroyed, curae, begum, targets,
# Nearest to if: whether, then, get, complicated, equivalence, shall, where, when,
# Nearest to about: being, barrios, how, intercourse, pedophile, pls, fourteen, structured,
# Nearest to and: when, due, condition, much, separated, put, provincial, them,
# Nearest to it: so, although, robot, useful, shape, ipv, nep, victorian,
# Nearest to its: immense, caleb, imperio, withdrawal, or, oppresses, ifr, acceptance,
# Nearest to this: orders, availability, reflect, yet, asking, truly, south, vim,
# Nearest to quite: baptism, dishes, kong, believe, visigothic, apis, oldest, lira,
# Nearest to freedom: duties, executive, potentially, shimazu, opportunity, penitence, defenders, esperanto,
# Nearest to pre: abroad, fraternities, war, pragmatism, loosed, josep, break, tigran,
# Nearest to liberal: political, conservative, revolutionary, militia, compilations, anti, mystical, cairo,
# Nearest to test: mask, installed, distributist, reactionary, crew, mathematics, meier, animator,
# Nearest to older: zeus, heroes, elongate, six, ala, female, hiv, durrani,
# Nearest to articles: prometaphase, min, ussachevsky, breeding, politics, article, newspapers, publications,
# Nearest to shown: involved, establish, individuals, substantial, size, scholars, wizard, quantum,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.0887 0.5679 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.0726 0.5474 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.0523 0.5392 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.0877 0.5485 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.0490 0.5407 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.0810 0.5429 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.0890 0.5488 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.0618 0.5420 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.0769 0.5599 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.0752 0.5559 sec/batch
# Nearest to by: detrimental, ma, since, gehrig, johannes, dynasty, required, ipsec,
# Nearest to not: only, yvonne, destroyed, actual, impression, curae, targets, begum,
# Nearest to if: whether, complicated, get, then, equivalence, shall, where, when,
# Nearest to about: being, barrios, intercourse, pedophile, how, pls, chalcolithic, organ,
# Nearest to and: when, separated, carriers, due, much, condition, provincial, macedonia,
# Nearest to it: so, although, robot, useful, shape, nep, because, possible,
# Nearest to its: immense, caleb, withdrawal, imperio, or, oppresses, ifr, except,
# Nearest to this: orders, availability, yet, truly, south, vim, asking, it,
# Nearest to quite: baptism, dishes, believe, lira, kong, visigothic, oldest, apis,
# Nearest to freedom: duties, executive, potentially, shimazu, opportunity, penitence, esperanto, defenders,
# Nearest to pre: fraternities, war, abroad, loosed, pragmatism, genesis, josep, andersonville,
# Nearest to liberal: political, militia, conservative, revolutionary, compilations, anti, parliamentary, dup,
# Nearest to test: distributist, mask, reactionary, meier, installed, animator, mathematics, luxembourgian,
# Nearest to older: zeus, heroes, elongate, six, hiv, ala, durrani, female,
# Nearest to articles: min, prometaphase, ussachevsky, newspapers, politics, breeding, article, publications,
# Nearest to shown: involved, establish, individuals, size, scholars, substantial, scientists, els,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.0669 0.5729 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.0315 0.5626 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.0279 0.5515 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.0683 0.5548 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.0473 0.5478 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.0995 0.5599 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.0620 0.5601 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.1087 0.5543 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.0237 0.5501 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.0886 0.5659 sec/batch
# Nearest to by: detrimental, ma, since, gehrig, dynasty, required, johannes, administration,
# Nearest to not: only, yvonne, destroyed, actual, curae, begum, targets, impression,
# Nearest to if: whether, get, complicated, shall, where, then, equivalence, when,
# Nearest to about: being, barrios, intercourse, how, pedophile, chalcolithic, articles, structured,
# Nearest to and: when, due, macedonia, provincial, separated, condition, inexpensive, much,
# Nearest to it: so, although, robot, useful, shape, possible, remembered, nep,
# Nearest to its: immense, caleb, withdrawal, imperio, or, ifr, oppresses, acceptance,
# Nearest to this: south, orders, yet, availability, vim, it, thinkers, reflect,
# Nearest to quite: baptism, believe, kong, dishes, visigothic, oldest, lira, apis,
# Nearest to freedom: duties, potentially, shimazu, defenders, executive, opportunity, penitence, esperanto,
# Nearest to pre: fraternities, abroad, war, loosed, josep, pragmatism, andersonville, tigran,
# Nearest to liberal: political, conservative, militia, revolutionary, compilations, anti, parliamentary, cairo,
# Nearest to test: distributist, reactionary, meier, installed, animator, mask, mathematics, crew,
# Nearest to older: heroes, zeus, elongate, acceptance, whose, hiv, six, female,
# Nearest to articles: prometaphase, min, ussachevsky, newspapers, publications, breeding, article, politics,
# Nearest to shown: involved, establish, size, substantial, individuals, scholars, quantum, wizard,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.0509 0.5711 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.0813 0.5583 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.0577 0.5557 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.0787 0.5481 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.0685 0.5483 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.0661 0.5586 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.1018 0.5624 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.0829 0.5586 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.0674 0.5603 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.0726 0.5695 sec/batch
# Nearest to by: detrimental, ma, since, gehrig, douglas, shakespeare, dynasty, johannes,
# Nearest to not: only, yvonne, actual, destroyed, curae, begum, impression, obesity,
# Nearest to if: whether, shall, complicated, get, equivalence, then, where, y,
# Nearest to about: being, barrios, how, intercourse, pedophile, articles, chalcolithic, structured,
# Nearest to and: when, provincial, due, put, separated, macedonia, condition, much,
# Nearest to it: so, although, useful, robot, shape, possible, nep, this,
# Nearest to its: withdrawal, caleb, immense, imperio, ifr, oppresses, or, miles,
# Nearest to this: south, orders, yet, availability, it, vim, truly, thinkers,
# Nearest to quite: baptism, believe, dishes, lira, kong, apis, visigothic, oldest,
# Nearest to freedom: duties, potentially, shimazu, penitence, defenders, executive, opportunity, esperanto,
# Nearest to pre: fraternities, war, abroad, pragmatism, loosed, josep, andersonville, genesis,
# Nearest to liberal: political, conservative, revolutionary, militia, parliamentary, compilations, anti, dup,
# Nearest to test: distributist, reactionary, mask, installed, meier, crew, fierce, mathematics,
# Nearest to older: heroes, elongate, zeus, whose, six, hiv, ala, acceptance,
# Nearest to articles: prometaphase, min, ussachevsky, article, newspapers, publications, politics, breeding,
# Nearest to shown: involved, establish, substantial, individuals, size, scholars, quantum, els,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.0632 0.5715 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.0663 0.5609 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.0784 0.5636 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.0696 0.5690 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.0368 0.5513 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.0802 0.5564 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.0176 0.5481 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.0634 0.5399 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.0483 0.5388 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.0904 0.5444 sec/batch
# Nearest to by: detrimental, ma, since, gehrig, shakespeare, johannes, conforms, ipsec,
# Nearest to not: only, yvonne, actual, begum, impression, curae, destroyed, obesity,
# Nearest to if: whether, get, then, where, shall, equivalence, complicated, y,
# Nearest to about: being, barrios, how, intercourse, structured, pedophile, articles, chalcolithic,
# Nearest to and: when, due, provincial, separated, carriers, inexpensive, macedonia, condition,
# Nearest to it: so, although, robot, useful, nep, shape, possible, stationed,
# Nearest to its: withdrawal, immense, caleb, imperio, ifr, oppresses, or, acceptance,
# Nearest to this: availability, south, yet, it, orders, vim, cart, controversy,
# Nearest to quite: baptism, believe, lira, kong, dishes, visigothic, oldest, apis,
# Nearest to freedom: duties, potentially, shimazu, penitence, defenders, opportunity, executive, jolla,
# Nearest to pre: fraternities, abroad, pragmatism, josep, war, loosed, andersonville, genesis,
# Nearest to liberal: political, conservative, revolutionary, parliamentary, militia, compilations, anti, opposition,
# Nearest to test: reactionary, distributist, mask, installed, meier, crew, fierce, luxembourgian,
# Nearest to older: heroes, whose, elongate, acceptance, zeus, six, female, hiv,
# Nearest to articles: prometaphase, min, ussachevsky, newspapers, article, publications, breeding, politics,
# Nearest to shown: involved, establish, substantial, individuals, scholars, size, els, relinquished,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 3.9174 0.5724 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 3.7308 0.5374 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 3.8950 0.5540 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 3.9435 0.5540 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.0207 0.5666 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.0258 0.5630 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.0539 0.5611 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.0844 0.5570 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.0583 0.5642 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.0603 0.5592 sec/batch
# Nearest to by: detrimental, ma, gehrig, since, shakespeare, douglas, heavily, conforms,
# Nearest to not: only, yvonne, destroyed, begum, curae, impression, actual, obesity,
# Nearest to if: whether, get, shall, complicated, then, equivalence, when, answer,
# Nearest to about: being, how, barrios, intercourse, pedophile, fourteen, pls, structured,
# Nearest to and: when, due, provincial, separated, condition, put, much, inexpensive,
# Nearest to it: so, although, robot, shape, useful, nep, possible, ipv,
# Nearest to its: immense, caleb, withdrawal, imperio, ifr, oppresses, or, consistently,
# Nearest to this: south, vim, controversy, yet, present, availability, it, thinkers,
# Nearest to quite: baptism, believe, lira, oldest, dishes, kong, apis, very,
# Nearest to freedom: duties, penitence, defenders, potentially, shimazu, executive, monthly, opportunity,
# Nearest to pre: fraternities, pragmatism, abroad, war, josep, loosed, andersonville, diploma,
# Nearest to liberal: conservative, political, revolutionary, parliamentary, militia, compilations, anti, dup,
# Nearest to test: distributist, reactionary, mask, meier, crew, installed, skookum, luxembourgian,
# Nearest to older: whose, heroes, zeus, elongate, hiv, six, ala, acceptance,
# Nearest to articles: min, prometaphase, newspapers, article, ussachevsky, politics, publications, breeding,
# Nearest to shown: involved, establish, substantial, scholars, els, individuals, relinquished, unarmed,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.0845 0.5714 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.0701 0.5716 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.0257 0.5636 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.0816 0.5615 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.0570 0.5478 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.0341 0.5518 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.0741 0.5380 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.0918 0.5418 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.0628 0.5380 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.0339 0.5395 sec/batch
# Nearest to by: detrimental, ma, since, central, ipsec, douglas, johannes, wandered,
# Nearest to not: only, yvonne, begum, destroyed, curae, actual, never, obesity,
# ...
# Nearest to this: it, which, what, proper, vince, scudetto, ghiorso, dependents,
# Nearest to quite: very, extremely, southern, lira, kong, formants, relatively, bobbio,
# Nearest to freedom: juilliard, zapatistas, promote, lack, amanda, intervals, circumnavigation, free,
# Nearest to pre: loosed, ahmed, battle, survived, emulsifiers, warden, undergo, profession,
# Nearest to liberal: conservative, compilations, agnes, landsat, libertarian, oppose, social, parliamentary,
# Nearest to test: hexagon, messenger, distributist, crew, pitcher, requirement, ban, atlas,
# Nearest to older: previous, old, earliest, whose, halakhah, earlier, average, yokohama,
# Nearest to articles: article, how, publications, newspapers, information, prometaphase, detailed, sinuous,
# Nearest to shown: seen, observed, reported, found, elongated, noted, identified, verge,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 3.9445 0.5555 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 4.0214 0.5536 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 4.0220 0.5673 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 4.0202 0.5718 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 4.0373 0.5562 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 4.0363 0.5642 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 4.0188 0.5532 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 4.0507 0.5618 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 3.9942 0.5549 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 4.0342 0.5600 sec/batch
# Nearest to by: detrimental, as, shakespeare, loosely, determined, nomadic, farmer, directly,
# Nearest to not: never, yvonne, remained, jehoash, ethnography, rarely, mostly, still,
# Nearest to if: where, though, then, when, that, whether, whose, because,
# Nearest to about: structured, flagellum, hp, fir, mosander, retrieved, cagney, regarding,
# Nearest to and: when, that, relationship, the, shared, but, way, especially,
# Nearest to it: he, this, the, she, what, alliances, nep, itself,
# Nearest to its: their, the, thwomps, his, borders, immense, whose, infiltrate,
# Nearest to this: it, which, what, proper, dependents, the, any, vince,
# Nearest to quite: very, extremely, southern, lira, kong, formants, heber, relatively,
# Nearest to freedom: juilliard, zapatistas, promote, lack, intervals, amanda, trying, circumnavigation,
# Nearest to pre: loosed, ahmed, battle, survived, emulsifiers, salm, organ, warden,
# Nearest to liberal: conservative, compilations, agnes, landsat, oppose, libertarian, kmt, opposition,
# Nearest to test: hexagon, distributist, messenger, crew, pitcher, requirement, using, atlas,
# Nearest to older: old, previous, earliest, whose, halakhah, average, earlier, yokohama,
# Nearest to articles: article, how, publications, newspapers, information, prometaphase, detailed, wrote,
# Nearest to shown: seen, observed, found, reported, elongated, identified, noted, verge,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 4.0409 0.5700 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 4.0178 0.5563 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 4.0285 0.5578 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 4.0251 0.5726 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.0241 0.5796 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.0241 0.5574 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 3.9485 0.5578 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 4.0175 0.5569 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 3.9701 0.5518 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.0476 0.5583 sec/batch
# Nearest to by: as, loosely, detrimental, shakespeare, nomadic, malicious, determined, farmer,
# Nearest to not: never, yvonne, remained, ethnography, jehoash, mostly, rarely, still,
# Nearest to if: where, though, when, then, that, whether, because, whose,
# Nearest to about: structured, flagellum, hp, fir, how, mosander, retrieved, samurai,
# Nearest to and: when, that, relationship, shared, but, the, way, honorius,
# Nearest to it: he, this, she, the, what, nep, itself, dispensed,
# Nearest to its: their, thwomps, infiltrate, the, immense, his, whose, ayer,
# Nearest to this: it, which, what, dependents, any, the, vince, proper,
# Nearest to quite: very, extremely, kong, southern, lira, praetexta, formants, heber,
# Nearest to freedom: juilliard, lack, intervals, zapatistas, promote, trying, circumnavigation, penitence,
# Nearest to pre: loosed, battle, ahmed, emulsifiers, survived, salm, psychedelics, organ,
# Nearest to liberal: conservative, compilations, agnes, landsat, oppose, libertarian, kmt, opposition,
# Nearest to test: hexagon, messenger, distributist, crew, requirement, using, pitcher, ban,
# Nearest to older: old, previous, earliest, whose, halakhah, average, earlier, yokohama,
# Nearest to articles: article, how, publications, newspapers, information, detailed, wrote, prometaphase,
# Nearest to shown: seen, observed, found, reported, elongated, identified, verge, noted,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 4.0271 0.5635 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.0453 0.5517 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 3.9809 0.5503 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.0380 0.5632 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 4.0222 0.5750 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 4.0280 0.5493 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 4.0322 0.5535 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 4.0451 0.5660 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 4.0295 0.5595 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 4.0338 0.5631 sec/batch
# Nearest to by: detrimental, nomadic, shakespeare, as, loosely, skaters, directly, corelli,
# Nearest to not: never, yvonne, remained, jehoash, ethnography, mostly, rarely, only,
# Nearest to if: though, where, when, then, that, whose, whether, because,
# Nearest to about: structured, flagellum, hp, fir, mosander, retrieved, cagney, how,
# Nearest to and: when, the, that, relationship, but, shared, in, much,
# Nearest to it: he, this, she, the, what, raven, nep, dispensed,
# Nearest to its: their, thwomps, the, borders, immense, his, caleb, bojinka,
# Nearest to this: it, which, what, dependents, vince, scudetto, ghiorso, proper,
# Nearest to quite: very, extremely, southern, kong, lira, praetexta, relatively, formants,
# Nearest to freedom: juilliard, lack, intervals, zapatistas, trying, promote, amanda, calling,
# Nearest to pre: loosed, battle, ahmed, survived, emulsifiers, resist, salm, psychedelics,
# Nearest to liberal: conservative, compilations, landsat, agnes, kmt, libertarian, social, oppose,
# Nearest to test: hexagon, messenger, crew, distributist, using, requirement, ban, atlas,
# Nearest to older: old, previous, earliest, whose, earlier, halakhah, yokohama, zeus,
# Nearest to articles: article, how, newspapers, publications, detailed, information, wrote, safest,
# Nearest to shown: seen, observed, reported, found, elongated, identified, noted, verge,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 4.0398 0.5754 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 4.0381 0.5685 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 4.0313 0.5649 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 4.0300 0.5620 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 4.0376 0.5801 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 4.0312 0.5612 sec/batch
# Epoch 10/10 Iteration: 116700 Avg. Training loss: 4.0326 0.5597 sec/batch
# Epoch 10/10 Iteration: 116800 Avg. Training loss: 4.0265 0.5498 sec/batch
# Epoch 10/10 Iteration: 116900 Avg. Training loss: 4.0101 0.5483 sec/batch
# Epoch 10/10 Iteration: 117000 Avg. Training loss: 4.0405 0.5530 sec/batch
# Nearest to by: detrimental, skaters, as, shakespeare, nomadic, directly, corelli, microfluidics,
# Nearest to not: never, yvonne, remained, ethnography, jehoash, rarely, mostly, only,
# Nearest to if: where, though, when, then, that, whether, because, whose,
# Nearest to about: structured, fir, flagellum, hp, retrieved, cagney, mosander, how,
# Nearest to and: that, the, when, shared, but, relationship, especially, forces,
# Nearest to it: he, this, the, she, what, raven, alliances, nep,
# Nearest to its: their, borders, the, immense, thwomps, bojinka, withdrawal, infiltrate,
# Nearest to this: it, which, what, dependents, proper, scudetto, vince, need,
# Nearest to quite: very, extremely, southern, kong, lira, relatively, formants, praetexta,
# Nearest to freedom: juilliard, intervals, lack, zapatistas, amanda, trying, promote, calling,
# Nearest to pre: loosed, survived, battle, ahmed, emulsifiers, warden, salm, josep,
# Nearest to liberal: conservative, compilations, landsat, agnes, oppose, kmt, opposing, libertarian,
# Nearest to test: hexagon, messenger, using, crew, distributist, requirement, atlas, incompatibility,
# Nearest to older: old, previous, earliest, whose, halakhah, earlier, average, zeus,
# Nearest to articles: article, how, publications, newspapers, information, wrote, prometaphase, detailed,
# Nearest to shown: seen, observed, reported, found, elongated, identified, noted, verge,
# Epoch 10/10 Iteration: 117100 Avg. Training loss: 3.9770 0.5577 sec/batch
# Epoch 10/10 Iteration: 117200 Avg. Training loss: 4.0445 0.5446 sec/batch
# Epoch 10/10 Iteration: 117300 Avg. Training loss: 4.0255 0.5403 sec/batch
# Epoch 10/10 Iteration: 117400 Avg. Training loss: 4.0529 0.5422 sec/batch
# Epoch 10/10 Iteration: 117500 Avg. Training loss: 3.9302 0.5326 sec/batch
# Epoch 10/10 Iteration: 117600 Avg. Training loss: 3.6321 0.5438 sec/batch
# Epoch 10/10 Iteration: 117700 Avg. Training loss: 3.9162 0.5551 sec/batch
# Epoch 10/10 Iteration: 117800 Avg. Training loss: 3.8507 0.5497 sec/batch
# Epoch 10/10 Iteration: 117900 Avg. Training loss: 3.9633 0.5499 sec/batch
# Epoch 10/10 Iteration: 118000 Avg. Training loss: 3.9845 0.5594 sec/batch
# Nearest to by: as, shakespeare, detrimental, nomadic, loosely, heavily, determined, directly,
# Nearest to not: never, yvonne, remained, ethnography, rarely, jehoash, only, mostly,
# Nearest to if: though, where, when, then, that, whether, because, whose,
# Nearest to about: structured, fir, flagellum, how, hp, cagney, regarding, mosander,
# Nearest to and: the, that, when, relationship, in, but, way, a,
# Nearest to it: he, this, she, the, what, just, nep, which,
# Nearest to its: their, his, immense, borders, thwomps, the, infiltrate, consistently,
# Nearest to this: it, which, what, vince, dependents, ghiorso, the, scudetto,
# Nearest to quite: very, extremely, southern, kong, lira, formants, praetexta, heber,
# Nearest to freedom: juilliard, intervals, lack, amanda, trying, zapatistas, circumnavigation, calling,
# Nearest to pre: loosed, battle, ahmed, survived, warden, emulsifiers, salm, resist,
# Nearest to liberal: conservative, compilations, landsat, agnes, kmt, opposing, oppose, chancellor,
# Nearest to test: hexagon, messenger, using, crew, distributist, atlas, requirement, incompatibility,
# Nearest to older: old, previous, earliest, whose, earlier, less, halakhah, zeus,
# Nearest to articles: article, how, newspapers, publications, wrote, prometaphase, safest, information,
# Nearest to shown: seen, observed, reported, found, noted, identified, verge, elongated,
# Epoch 10/10 Iteration: 118100 Avg. Training loss: 4.0207 0.5647 sec/batch
# Epoch 10/10 Iteration: 118200 Avg. Training loss: 4.0321 0.5541 sec/batch
# Epoch 10/10 Iteration: 118300 Avg. Training loss: 4.0222 0.5523 sec/batch
# Epoch 10/10 Iteration: 118400 Avg. Training loss: 4.0317 0.5573 sec/batch
# Epoch 10/10 Iteration: 118500 Avg. Training loss: 4.0248 0.5570 sec/batch
# Epoch 10/10 Iteration: 118600 Avg. Training loss: 4.0548 0.5590 sec/batch
# Epoch 10/10 Iteration: 118700 Avg. Training loss: 3.9759 0.5664 sec/batch
# Epoch 10/10 Iteration: 118800 Avg. Training loss: 4.0371 0.5573 sec/batch
# Epoch 10/10 Iteration: 118900 Avg. Training loss: 4.0230 0.5556 sec/batch
# Epoch 10/10 Iteration: 119000 Avg. Training loss: 3.9931 0.5541 sec/batch
# Nearest to by: loosely, detrimental, as, nomadic, shakespeare, corelli, historically, skaters,
# Nearest to not: never, yvonne, remained, ethnography, rarely, jehoash, mostly, only,
# Nearest to if: where, though, then, when, that, because, whether, whose,
# Nearest to about: structured, flagellum, fir, hp, retrieved, cagney, uzi, mosander,
# Nearest to and: when, that, the, but, way, relationship, in, german,
# Nearest to it: he, this, the, she, what, just, nep, itself,
# Nearest to its: their, thwomps, his, borders, infiltrate, the, bojinka, immense,
# Nearest to this: it, which, what, dependents, vince, proper, sehul, any,
# Nearest to quite: very, extremely, southern, formants, kong, relatively, lira, praetexta,
# Nearest to freedom: juilliard, intervals, lack, zapatistas, amanda, trying, promote, circumnavigation,
# Nearest to pre: loosed, battle, survived, ahmed, salm, emulsifiers, resist, warden,
# Nearest to liberal: conservative, compilations, landsat, social, agnes, opposing, socialism, oppose,
# Nearest to test: hexagon, messenger, crew, requirement, distributist, using, ban, atlas,
# Nearest to older: old, previous, earliest, whose, halakhah, zeus, earlier, soaps,
# Nearest to articles: article, how, newspapers, publications, wrote, prometaphase, sinuous, information,
# Nearest to shown: seen, observed, found, reported, elongated, identified, noted, verge,
# Epoch 10/10 Iteration: 119100 Avg. Training loss: 4.0308 0.5602 sec/batch
# Epoch 10/10 Iteration: 119200 Avg. Training loss: 4.0485 0.5565 sec/batch
# Epoch 10/10 Iteration: 119300 Avg. Training loss: 4.0222 0.5572 sec/batch
# Epoch 10/10 Iteration: 119400 Avg. Training loss: 4.0220 0.5568 sec/batch
# Epoch 10/10 Iteration: 119500 Avg. Training loss: 3.8758 0.5504 sec/batch
# Epoch 10/10 Iteration: 119600 Avg. Training loss: 4.0241 0.5528 sec/batch
# Epoch 10/10 Iteration: 119700 Avg. Training loss: 4.0015 0.5614 sec/batch
# Epoch 10/10 Iteration: 119800 Avg. Training loss: 3.8919 0.5534 sec/batch
# Epoch 10/10 Iteration: 119900 Avg. Training loss: 4.0154 0.5577 sec/batch
# Epoch 10/10 Iteration: 120000 Avg. Training loss: 4.0347 0.5588 sec/batch
# Nearest to by: loosely, detrimental, shakespeare, as, nomadic, determined, corelli, farmer,
# Nearest to not: never, yvonne, remained, ethnography, jehoash, rarely, mostly, both,
# Nearest to if: where, though, then, when, that, whether, because, whose,
# Nearest to about: structured, flagellum, hp, fir, mosander, uzi, retrieved, cagney,
# Nearest to and: that, the, when, but, shared, relationship, in, especially,
# Nearest to it: he, this, the, she, what, alliances, nep, just,
# Nearest to its: their, the, thwomps, borders, his, immense, whose, ifr,
# Nearest to this: it, which, what, dependents, vince, scudetto, sehul, proper,
# Nearest to quite: very, extremely, southern, kong, formants, relatively, lira, heber,
# Nearest to freedom: juilliard, intervals, lack, circumnavigation, amanda, promote, zapatistas, penitence,
# Nearest to pre: loosed, battle, survived, ahmed, salm, emulsifiers, resist, warden,
# Nearest to liberal: conservative, compilations, landsat, agnes, social, opposing, kmt, oppose,
# Nearest to test: hexagon, messenger, crew, distributist, requirement, atlas, ban, pitcher,
# Nearest to older: old, previous, earliest, whose, yokohama, halakhah, zeus, less,
# Nearest to articles: article, how, newspapers, publications, wrote, detailed, information, safest,
# Nearest to shown: seen, observed, found, reported, elongated, identified, noted, discussed,
# Epoch 10/10 Iteration: 120100 Avg. Training loss: 3.9929 0.5661 sec/batch
# Epoch 10/10 Iteration: 120200 Avg. Training loss: 3.9844 0.5590 sec/batch
# Epoch 10/10 Iteration: 120300 Avg. Training loss: 4.0081 0.5564 sec/batch
# Epoch 10/10 Iteration: 120400 Avg. Training loss: 4.0049 0.5578 sec/batch
# Epoch 10/10 Iteration: 120500 Avg. Training loss: 4.0623 0.5626 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# VISUALIZING THE WORD VECTORS

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
