# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
import random
import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import numpy as np
from collections import Counter
np.random.seed(123)

def sub_sampling(int_words, threshold):
    word_counter = Counter(int_words)
    total_count = len(int_words)
    freq= {word: count/total_count for word,count in word_counter.items()}
    p_drop ={word:(1-np.sqrt(threshold/ freq[word])) for word in word_counter}
    trained_words = [word for word in int_words if p_drop[word]<np.random.random()]
    return trained_words
train_words = sub_sampling(int_words, threshold=1e-5)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %%
print(words[1])
get_target(words, 2)
# Out:
# originated
# ['anarchism', 'a', 'of', 'originated', 'term']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
for x, y in get_batches(words, 1000):
    print(x, y)
# Out:
# ['anarchism', 'anarchism', 'anarchism', 'originated', 'originated', 'originated', 'originated', 'originated', 'as', 'as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse', 'abuse', 'abuse', 'abuse', 'abuse', 'first', 'first', 'first', 'first', 'first', 'first', 'used', 'used', 'used', 'used', 'used', 'used', 'against', 'against', 'against', 'against', 'against', 'against', 'against', 'against', 'early', 'early', 'early', 'early', 'early', 'early', 'early', 'early', 'early', 'early', 'working', 'working', 'working', 'working', 'working', 'working', 'class', 'class', 'class', 'class', 'radicals', 'radicals', 'radicals', 'radicals', 'including', 'including', 'the', 'the', 'diggers', 'diggers', 'diggers', 'diggers', 'diggers', 'diggers', 'diggers', 'diggers', 'diggers', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'the', 'the', 'the', 'the', 'english', 'english', 'english', 'english', 'revolution', 'revolution', 'revolution', 'revolution', 'revolution', 'revolution', 'revolution', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'the', 'the', 'sans', 'sans', 'sans', 'sans', 'sans', 'culottes', 'culottes', 'culottes', 'of', 'of', 'of', 'of', 'the', 'the', 'the', 'the', 'french', 'french', 'revolution', 'revolution', 'revolution', 'whilst', 'whilst', 'whilst', 'whilst', 'whilst', 'the', 'the', 'the', 'the', 'the', 'the', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'is', 'is', 'is', 'is', 'still', 'still', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'in', 'in', 'in', 'in', 'in', 'in', 'a', 'a', 'a', 'a', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'pejorative', 'way', 'way', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'describe', 'describe', 'describe', 'describe', 'describe', 'describe', 'describe', 'describe', 'any', 'any', 'any', 'any', 'any', 'any', 'any', 'any', 'act', 'act', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'used', 'used', 'used', 'used', 'violent', 'violent', 'means', 'means', 'means', 'means', 'to', 'to', 'to', 'to', 'to', 'to', 'destroy', 'destroy', 'destroy', 'destroy', 'destroy', 'destroy', 'destroy', 'destroy', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'organization', 'organization', 'organization', 'organization', 'organization', 'organization', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'society', 'society', 'society', 'society', 'society', 'society', 'it', 'it', 'it', 'it', 'it', 'it', 'it', 'it', 'it', 'it', 'has', 'has', 'has', 'has', 'also', 'also', 'also', 'also', 'been', 'been', 'been', 'been', 'been', 'been', 'been', 'been', 'been', 'been', 'taken', 'taken', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'a', 'a', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'positive', 'label', 'label', 'label', 'label', 'label', 'label', 'by', 'by', 'by', 'by', 'self', 'self', 'defined', 'defined', 'anarchists', 'anarchists', 'the', 'the', 'the', 'the', 'the', 'the', 'word', 'word', 'word', 'word', 'word', 'word', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'is', 'is', 'is', 'is', 'derived', 'derived', 'derived', 'derived', 'derived', 'derived', 'derived', 'from', 'from', 'from', 'from', 'the', 'the', 'the', 'the', 'greek', 'greek', 'without', 'without', 'without', 'without', 'without', 'without', 'without', 'without', 'without', 'without', 'archons', 'archons', 'archons', 'archons', 'ruler', 'ruler', 'chief', 'chief', 'chief', 'chief', 'chief', 'chief', 'chief', 'chief', 'chief', 'chief', 'king', 'king', 'king', 'king', 'anarchism', 'anarchism', 'as', 'as', 'as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'political', 'political', 'political' ...
# ['eight', 'eight', 'eight', 'eight', 'eight', 'two', 'two', 'two', 'two', 'two', 'five', 'five', 'josiah', 'josiah', 'warren', 'warren', 'had', 'had', 'had', 'had', 'had', 'had', 'had', 'had', 'participated', 'participated', 'participated', 'participated', 'in', 'in', 'in', 'in', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'communitarian', 'experiment', 'experiment', 'experiment', 'experiment', 'headed', 'headed', 'headed', 'headed', 'headed', 'headed', 'headed', 'headed', 'headed', 'headed', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'robert', 'robert', 'robert', 'robert', 'robert', 'robert', 'owen', 'owen', 'owen', 'owen', 'owen', 'owen', 'owen', 'owen', 'owen', 'owen', 'called', 'called', 'called', 'called', 'new', 'new', 'harmony', 'harmony', 'harmony', 'harmony', 'harmony', 'harmony', 'which', 'which', 'which', 'which', 'which', 'which', 'which', 'which', 'which', 'which', 'failed', 'failed', 'failed', 'failed', 'failed', 'failed', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'a', 'a', 'a', 'a', 'few', 'few', 'years', 'years', 'years', 'years', 'years', 'years', 'amidst', 'amidst', 'amidst', 'amidst', 'amidst', 'amidst', 'amidst', 'amidst', 'much', 'much', 'internal', 'internal', 'internal', 'internal', 'internal', 'internal', 'conflict', 'conflict', 'conflict', 'conflict', 'warren', 'warren', 'blamed', 'blamed', 'the', 'the', 'community', 'community', 'community', 'community', 'community', 'community', 'community', 'community', 'community', 'community', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 'failure', 'failure', 'failure', 'failure', 'failure', 'failure', 'on', 'on', 'on', 'on', 'on', 'on', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'individual', 'individual', 'individual', 'individual', 'individual', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'lack', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'private', 'private', 'private', 'private', 'private', 'private', 'private', 'private', 'property', 'property', 'warren', 'warren', 'warren', 'warren', 'warren', 'warren', 'warren', 'warren', 'warren', 'warren', 'proceeded', 'proceeded', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'organise', 'organise', 'organise', 'organise', 'organise', 'organise', 'organise', 'organise', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'communities', 'communities', 'communities', 'communities', 'communities', 'communities', 'communities', 'communities', 'communities', 'communities', 'which', 'which', 'which', 'which', 'respected', 'respected', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'what', 'he', 'he', 'he', 'he', 'he', 'he', 'called', 'called', 'called', 'called', 'called', 'called', 'called', 'the', 'the', 'the', 'the', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'sovereignty', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'at', 'at', 'at', 'at', 'at', 'at', 'at', 'at', 'utopia', 'utopia', 'utopia', 'utopia', 'utopia', 'utopia', 'utopia', 'utopia', 'utopia', 'utopia', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'times', 'times', 'times', 'times', 'times', 'times', 'times', 'times', 'times', 'in', 'in', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'eight', 'eigh ...
# ['viewed', 'viewed', 'viewed', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'a', 'form', 'form', 'form', 'form', 'form', 'form', 'of', 'of', 'christian', 'christian', 'christian', 'christian', 'christian', 'christian', 'christian', 'christian', 'christian', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'see', 'see', 'see', 'see', 'below', 'below', 'below', 'below', 'below', 'below', 'below', 'below', 'was', 'was', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'notable', 'notable', 'notable', 'notable', 'notable', 'notable', 'exponent', 'exponent', 'exponent', 'exponent', 'exponent', 'exponent', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'nonviolent', 'nonviolent', 'nonviolent', 'nonviolent', 'nonviolent', 'nonviolent', 'resistance', 'resistance', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'the', 'the', 'the', 'the', 'the', 'the', 'labour', 'labour', 'labour', 'labour', 'labour', 'labour', 'labour', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'and', 'and', 'and', 'and', 'and', 'and', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'flag', 'flag', 'coming', 'coming', 'coming', 'coming', 'coming', 'coming', 'coming', 'coming', 'from', 'from', 'from', 'from', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'experience', 'experience', 'experience', 'experience', 'experience', 'experience', 'experience', 'of', 'of', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'in', 'in', 'the', 'the', 'the', 'the', 'the', 'the', 'labour', 'labour', 'labour', 'labour', 'labour', 'labour', 'labour', 'labour', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'particularly', 'particularly', 'associated', 'associated', 'associated', 'associated', 'associated', 'associated', 'associated', 'associated', 'with', 'with', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'syndicalism', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'anarcho', 'syndicalism', 'syndicalism', 'syndicalism', 'syndicalism', 'syndicalism', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'an', 'an', 'early', 'early', 'early', 'early', 'early', 'early', 'two', 'two', 'two', 'two', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'th', 'th', 'th', 'th', 'century', 'century', 'century', 'century', 'century', 'century', 'century', 'century', 'working', 'working', 'class', 'class', 'class', 'class', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'seeking', 'seeking', 'seeking', 'seeking', 'seeking', 'seeking', 'seeking', 'seeking', 'seeking', 'seeking', 'to', 'to', 'to', 'to', 'overthrow', 'overthrow', 'capitalism', 'capitalism', 'capitalism', 'capitalism', 'capitalism', 'capitalism', 'capitalism', 'capitalism', 'capitalism', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'the', 'the', 'the', 'the', 'state', 'state', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'institute', 'institute', 'institute', 'institute', 'institute', 'institute', 'institute', 'institute', 'institute', 'a', 'a', 'worker', 'worker', 'worker', 'worker', 'controlled', 'controlled', 'controlled', 'controlled', 'controlled', 'controlled', 'controlled', 'controlled', 'society', 'society', 'society', 'society', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'movement', 'movement', 'movement', 'movement', 'pursued', 'pursued', 'pursued', 'pursued', 'industrial', 'industrial', 'industrial', 'industrial', 'actions', 'actions', 'such', 'such' ...
# ['in', 'in', 'in', 'in', 'in', 'the', 'the', 'the', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'nine', 'nine', 'nine', 'nine', 'two', 'two', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 's', 's', 's', 's', 's', 's', 'and', 'and', 'and', 'and', 'and', 'and', 'one', 'one', 'nine', 'nine', 'nine', 'nine', 'three', 'three', 'zero', 'zero', 'zero', 'zero', 's', 's', 's', 's', 's', 's', 'the', 'the', 'familiar', 'familiar', 'dynamics', 'dynamics', 'dynamics', 'dynamics', 'dynamics', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 's', 's', 's', 's', 's', 's', 's', 's', 's', 'conflict', 'conflict', 'conflict', 'conflict', 'conflict', 'conflict', 'conflict', 'conflict', 'with', 'with', 'the', 'the', 'state', 'state', 'state', 'state', 'state', 'state', 'state', 'state', 'state', 'were', 'were', 'were', 'were', 'were', 'were', 'were', 'were', 'were', 'transformed', 'transformed', 'transformed', 'transformed', 'transformed', 'transformed', 'transformed', 'transformed', 'transformed', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'the', 'the', 'the', 'the', 'rise', 'rise', 'of', 'of', 'of', 'of', 'fascism', 'fascism', 'in', 'in', 'in', 'in', 'in', 'in', 'europe', 'europe', 'europe', 'europe', 'europe', 'europe', 'europe', 'in', 'in', 'in', 'in', 'in', 'in', 'many', 'many', 'cases', 'cases', 'european', 'european', 'european', 'european', 'european', 'european', 'european', 'european', 'european', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'faced', 'faced', 'faced', 'faced', 'faced', 'faced', 'faced', 'faced', 'difficult', 'difficult', 'difficult', 'difficult', 'difficult', 'difficult', 'difficult', 'difficult', 'choices', 'choices', 'choices', 'choices', 'choices', 'choices', 'choices', 'choices', 'should', 'should', 'should', 'should', 'they', 'they', 'they', 'they', 'they', 'they', 'they', 'they', 'join', 'join', 'join', 'join', 'join', 'join', 'join', 'join', 'join', 'join', 'in', 'in', 'in', 'in', 'popular', 'popular', 'popular', 'popular', 'fronts', 'fronts', 'fronts', 'fronts', 'with', 'with', 'with', 'with', 'with', 'with', 'with', 'with', 'reformist', 'reformist', 'reformist', 'reformist', 'reformist', 'reformist', 'democrats', 'democrats', 'democrats', 'democrats', 'democrats', 'democrats', 'democrats', 'democrats', 'and', 'and', 'and', 'and', 'and', 'and', 'soviet', 'soviet', 'soviet', 'soviet', 'soviet', 'soviet', 'soviet', 'soviet', 'soviet', 'soviet', 'led', 'led', 'led', 'led', 'led', 'led', 'led', 'led', 'led', 'led', 'communists', 'communists', 'communists', 'communists', 'communists', 'communists', 'against', 'against', 'against', 'against', 'against', 'against', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'common', 'common', 'common', 'common', 'common', 'common', 'common', 'common', 'common', 'common', 'fascist', 'fascist', 'fascist', 'fascist', 'fascist', 'fascist', 'fascist', 'fascist', 'enemy', 'enemy', 'enemy', 'enemy', 'enemy', 'enemy', 'luigi', 'luigi', 'luigi', 'luigi', 'luigi', 'luigi', 'luigi', 'luigi', 'luigi', 'luigi', 'an', 'an', 'an', 'an', 'an', 'an', 'exile', 'exile', 'exile', 'exile', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'italian', 'italian', 'italian', 'italian', 'italian', 'italian', 'italian', 'italian', 'fascism', 'fascism', 'fascism', 'fascism', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'amongst', 'amongst', 'amongst', 'amongst', 'amongst', 'amongst', 'those', 'those', 'those', 'those', 'those', 'those', 'arguing', 'arguing', 'arguing', 'arguing', 'arguing', 'that', 'that', 'that', 'that', 'that', 'that', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'was', 'was', 'something', 'something', 'different', 'different', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'fascism', 'is', 'is', 'not', 'not', 'just', 'just', 'just', 'just ...
# ['property', 'property', 'the', 'the', 'the', 'the', 'the', 'true', 'true', 'right', 'right', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'that', 'that', 'that', 'that', 'which', 'which', 'which', 'which', 'which', 'which', 'is', 'is', 'is', 'is', 'proper', 'proper', 'proper', 'proper', 'proper', 'proper', 'proper', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'the', 'the', 'the', 'the', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'is', 'is', 'is', 'is', 'is', 'is', 'annihilated', 'annihilated', 'she', 'she', 'she', 'she', 'she', 'she', 'she', 'she', 'believes', 'believes', 'believes', 'believes', 'believes', 'believes', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'co', 'co', 'co', 'co', 'co', 'co', 'co', 'co', 'operation', 'operation', 'operation', 'operation', 'operation', 'operation', 'operation', 'operation', 'operation', 'operation', 'would', 'would', 'would', 'would', 'entirely', 'entirely', 'entirely', 'entirely', 'supplant', 'supplant', 'supplant', 'supplant', 'supplant', 'supplant', 'competition', 'competition', 'i', 'i', 'hold', 'hold', 'hold', 'hold', 'hold', 'hold', 'hold', 'that', 'that', 'competition', 'competition', 'in', 'in', 'in', 'in', 'in', 'in', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'form', 'form', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'another', 'another', 'will', 'will', 'always', 'always', 'exist', 'exist', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'it', 'it', 'is', 'is', 'is', 'is', 'is', 'highly', 'highly', 'highly', 'desirable', 'desirable', 'desirable', 'desirable', 'desirable', 'desirable', 'desirable', 'desirable', 'desirable', 'it', 'it', 'it', 'it', 'it', 'it', 'it', 'it', 'should', 'should', 'should', 'should', 'should', 'should', 'should', 'should', 'should', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'spanish', 'spanish', 'spanish', 'spanish', 'spanish', 'spanish', 'spanish', 'spanish', 'civil', 'civil', 'war', 'war', 'war', 'war', 'war', 'war', 'an', 'an', 'an', 'an', 'an', 'an', 'anarcha', 'anarcha', 'feminist', 'feminist', 'feminist', 'feminist', 'feminist', 'feminist', 'feminist', 'feminist', 'feminist', 'feminist', 'group', 'group', 'group', 'group', 'group', 'group', 'group', 'group', 'free', 'free', 'free', 'free', 'free', 'free', 'free', 'free', 'free', 'free', 'women', 'women', 'women', 'women', 'women', 'women', 'women', 'women', 'organized', 'organized', 'organized', 'organized', 'organized', 'organized', 'organized', 'organized', 'organized', 'organized', 'to', 'to', 'defend', 'defend', 'defend', 'defend', 'defend', 'defend', 'defend', 'defend', 'defend', 'defend', 'both', 'both', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'and', 'and', 'feminist', 'feminist', 'feminist', 'feminist', 'ideas', 'ideas', 'ideas', 'ideas', 'ideas', 'ideas', 'in', 'in', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'modern', 'day', 'day', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'anarchist', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'movement', 'many', 'many', 'many', 'many', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'male', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'female', 'consider', 'consider', 'consider', 'consider', 'consider', 'consider', 'consider', 'consider', 'themselves', 'themselves', 'themselves', 'themselves', 'themselves', 'themselves ...
# ['different', 'different', 'different', 'different', 'but', 'but', 'but', 'but', 'but', 'not', 'not', 'not', 'not', 'not', 'not', 'unconnected', 'unconnected', 'contexts', 'contexts', 'contexts', 'contexts', 'contexts', 'contexts', 'contexts', 'contexts', 'contexts', 'dave', 'dave', 'dave', 'dave', 'neal', 'neal', 'neal', 'neal', 'neal', 'neal', 'neal', 'neal', 'posited', 'posited', 'the', 'the', 'the', 'the', 'the', 'the', 'term', 'term', 'in', 'in', 'in', 'in', 'opposition', 'opposition', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'big', 'big', 'a', 'a', 'a', 'a', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'article', 'article', 'article', 'article', 'article', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'ideology', 'ideology', 'ideology', 'ideology', 'or', 'or', 'or', 'or', 'or', 'or', 'methodology', 'methodology', 'methodology', 'methodology', 'methodology', 'methodology', 'methodology', 'while', 'while', 'while', 'while', 'while', 'while', 'while', 'while', 'while', 'big', 'big', 'big', 'big', 'big', 'big', 'a', 'a', 'a', 'a', 'a', 'a', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'referred', 'referred', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'anarchists', 'anarchists', 'anarchists', 'anarchists', 'small', 'small', 'small', 'small', 'small', 'small', 'small', 'small', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'was', 'applied', 'applied', 'applied', 'applied', 'applied', 'applied', 'to', 'to', 'to', 'to', 'their', 'their', 'their', 'their', 'methodological', 'methodological', 'methodological', 'methodological', 'methodological', 'methodological', 'methodological', 'methodological', 'methodological', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'counterparts', 'those', 'those', 'those', 'those', 'those', 'those', 'who', 'who', 'who', 'who', 'viewed', 'viewed', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'way', 'way', 'way', 'way', 'way', 'way', 'way', 'way', 'way', 'of', 'of', 'of', 'of', 'of', 'acting', 'acting', 'acting', 'acting', 'acting', 'acting', 'acting', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'historical', 'historical', 'historical', 'historical', 'tendency', 'tendency', 'tendency', 'tendency', 'tendency', 'tendency', 'tendency', 'tendency', 'tendency', 'tendency', 'against', 'against', 'against', 'against', 'illegitimate', 'illegitimate', 'illegitimate', 'illegitimate', 'authority', 'authority', 'authority', 'authority', 'authority', 'authority', 'authority', 'authority', 'authority', 'authority', 'as', 'as', 'as', 'as', 'an', 'an', 'an', 'an', 'an', 'an', 'an', 'an', 'an', 'an', 'anti', 'anti', 'anti', 'anti', 'anti', 'anti', 'anti', 'anti', 'anti', 'anti', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'ideological', 'position', 'position', 'position', 'position', 'position', 'position', 'position', 'position', 'small', 'small', 'small', 'small', 'a', 'a', 'a', 'a', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'shares', 'shares', 'shares', 'shares', 'shares', 'shares', 'shares', 'shares', 'some', ...
# ['or', 'or', 'or', 'plain', 'plain', 'plain', 'plain', 'plain', 'plain', 'utopian', 'utopian', 'even', 'even', 'even', 'even', 'by', 'by', 'by', 'by', 'by', 'by', 'many', 'many', 'many', 'many', 'many', 'many', 'many', 'many', 'many', 'many', 'who', 'who', 'who', 'who', 'who', 'who', 'who', 'who', 'who', 'who', 'agree', 'agree', 'agree', 'agree', 'agree', 'agree', 'that', 'that', 'that', 'that', 'it', 'it', 'it', 'it', 'it', 'it', 's', 's', 'a', 'a', 'a', 'a', 'a', 'a', 'nice', 'nice', 'nice', 'nice', 'idea', 'idea', 'idea', 'idea', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'principle', 'principle', 'principle', 'principle', 'principle', 'principle', 'principle', 'principle', 'principle', 'for', 'for', 'for', 'for', 'for', 'example', 'example', 'example', 'example', 'example', 'carl', 'carl', 'in', 'in', 'in', 'in', 'in', 'in', 'his', 'his', 'his', 'his', 'his', 'his', 'his', 'his', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'book', 'european', 'european', 'european', 'european', 'european', 'european', 'european', 'european', 'socialism', 'socialism', 'socialism', 'socialism', 'criticizes', 'criticizes', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'being', 'being', 'being', 'being', 'being', 'being', 'being', 'being', 'being', 'being', 'unrealistically', 'unrealistically', 'unrealistically', 'unrealistically', 'unrealistically', 'unrealistically', 'unrealistically', 'unrealistically', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'and', 'and', 'and', 'and', 'holds', 'holds', 'that', 'that', 'government', 'government', 'government', 'government', 'is', 'is', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'lesser', 'lesser', 'lesser', 'lesser', 'evil', 'evil', 'evil', 'evil', 'evil', 'evil', 'evil', 'evil', 'evil', 'than', 'than', 'a', 'a', 'society', 'society', 'society', 'society', 'society', 'society', 'society', 'society', 'without', 'without', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'force', 'force', 'force', 'force', 'he', 'he', 'he', 'he', 'he', 'he', 'he', 'he', 'holds', 'holds', 'holds', 'holds', 'holds', 'holds', 'holds', 'holds', 'holds', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'the', 'the', 'the', 'belief', 'belief', 'that', 'that', 'ill', 'ill', 'intentions', 'intentions', 'intentions', 'intentions', 'will', 'will', 'will', 'will', 'will', 'will', 'will', 'will', 'will', 'will', 'cease', 'cease', 'cease', 'cease', 'cease', 'cease', 'if', 'if', 'if', 'if', 'if', 'if', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'repressive', 'force', 'force', 'force', 'force', 'force', 'force', 'force', 'force', 'force', 'force', 'disappears', 'disappears', 'disappears', 'disappears', 'disappears', 'disappears', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'an', 'an', 'absurdity', 'absurdity', 'absurdity', 'absurdity', 'however', 'however', 'however', 'however', 'however', 'however', 'it', 'it', 'it', 'it', 'must', 'must', 'must', 'must', 'must', 'must', 'must', 'must', 'be', 'be', 'be', 'be', 'noted', 'noted', 'that', 'that', 'that', 'that', 'that', 'that', 'not', 'not', 'not', 'not', 'not', 'not', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'all', 'anarchists', 'anarchists', 'have', 'have', 'have', 'have', 'have', 'have', 'such', 'such', 'such', 'such', 'such', 'such', 'such', 'such', 'such', 'such', 'a', 'a', 'a', 'a', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'utopian', 'view', 'view', 'view', 'view', 'view', 'view', 'of', 'of', 'of', 'of', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'anarchism', 'for', 'for', 'for', 'for', 'for', 'for', 'for', 'for', 'example', 'example', 's ...
# ['as', 'as', 'as', 'as', 'many', 'many', 'many', 'many', 'many', 'as', 'as', 'one', 'one', 'one', 'one', 'united', 'united', 'united', 'united', 'united', 'united', 'states', 'states', 'child', 'child', 'child', 'child', 'in', 'in', 'in', 'in', 'in', 'in', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'six', 'six', 'six', 'six', 'six', 'six', 'six', 'six', 'six', 'six', 'however', 'however', 'however', 'the', 'the', 'the', 'the', 'national', 'national', 'institute', 'institute', 'institute', 'institute', 'of', 'of', 'of', 'of', 'of', 'of', 'mental', 'mental', 'mental', 'mental', 'mental', 'mental', 'mental', 'mental', 'health', 'health', 'health', 'health', 'health', 'health', 'health', 'health', 'gives', 'gives', 'gives', 'gives', 'gives', 'gives', 'a', 'a', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'conservative', 'conservative', 'estimate', 'estimate', 'estimate', 'estimate', 'estimate', 'estimate', 'estimate', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'one', 'one', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'zero', 'for', 'for', 'for', 'for', 'for', 'for', 'for', 'families', 'families', 'families', 'families', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'already', 'already', 'have', 'have', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'child', 'child', 'child', 'child', 'child', 'child', 'child', 'child', 'child', 'child', 'the', 'the', 'odds', 'odds', 'odds', 'odds', 'odds', 'odds', 'of', 'of', 'of', 'of', 'of', 'of', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'second', 'second', 'second', 'second', 'second', 'second', 'second', 'second', 'second', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'child', 'child', 'child', 'child', 'may', 'may', 'may', 'may', 'may', 'may', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'high', 'high', 'high', 'as', 'as', 'as', 'as', 'as', 'as', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'in', 'in', 'in', 'in', 'in', 'in', 'twenty', 'twenty', 'twenty', 'twenty', 'twenty', 'twenty', 'diagnosis', 'diagnosis', 'diagnosis', 'diagnosis', 'diagnosis', 'diagnosis', 'is', 'is', 'based', 'based', 'based', 'based', 'on', 'on', 'on', 'on', 'on', 'on', 'a', 'a', 'a', 'a', 'a', 'a', 'list', 'list', 'list', 'list', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'psychiatric', 'psychiatric', 'psychiatric', 'psychiatric', 'criteria', 'criteria', 'and', 'and', 'a', 'a', 'series', 'series', 'series', 'series', 'series', 'series', 'series', 'series', 'of', 'of', 'of', 'of', 'standardized', 'standardized', 'standardized', 'standardized', 'standardized', 'standardized', 'standardized', 'standardized', 'standardized', 'standardized', 'clinical', 'clinical', 'clinical', 'clinical', 'clinical', 'clinical', 'clinical', 'clinical', 'clinical', 'clinical', 'tests', 'tests', 'may', 'may', 'may', 'may', 'also', 'also', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'autism', 'autism', 'autism', 'autism', 'may', 'may', 'may', 'may', 'not', 'not', 'not', 'not', 'not', 'not', 'not', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'be', 'physiologically', 'physiologically', 'obvious', 'obvious', 'obvious', 'obvious', 'obvious', 'obvious', 'a', 'a', 'a', 'a', 'a', 'a', 'complete', 'complete', 'complete', 'complete', 'complete', 'complete', 'complete', 'complete', 'complete', 'complete', 'physical', 'physical', 'physical', 'physical', 'and', 'and', 'and', 'and', 'and', 'and', 'neurological', 'neurological', 'neurological', 'neurological', 'neurological', 'neurological', 'neurological', 'neurological', 'neurological', 'neurological', 'evaluation', 'evaluation', 'evaluation', 'evaluation', ...
# ['of', 'of', 'of', 'of', 'expected', 'expected', 'attachment', 'attachment', 'attachment', 'attachment', 'behavior', 'behavior', 'behavior', 'behavior', 'behavior', 'behavior', 'behavior', 'children', 'children', 'children', 'children', 'children', 'children', 'with', 'with', 'with', 'with', 'with', 'with', 'autism', 'autism', 'autism', 'autism', 'autism', 'autism', 'appear', 'appear', 'appear', 'appear', 'appear', 'appear', 'to', 'to', 'to', 'to', 'to', 'to', 'lack', 'lack', 'lack', 'lack', 'theory', 'theory', 'of', 'of', 'of', 'of', 'mind', 'mind', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'ability', 'ability', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'see', 'see', 'things', 'things', 'things', 'things', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'from', 'another', 'another', 'another', 'another', 'another', 'another', 'another', 'another', 'another', 'another', 'person', 'person', 's', 's', 'perspective', 'perspective', 'perspective', 'perspective', 'perspective', 'perspective', 'perspective', 'perspective', 'a', 'a', 'behavior', 'behavior', 'behavior', 'behavior', 'behavior', 'behavior', 'cited', 'cited', 'cited', 'cited', 'cited', 'cited', 'as', 'as', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'exclusive', 'to', 'to', 'to', 'to', 'to', 'to', 'human', 'human', 'beings', 'beings', 'beings', 'beings', 'beings', 'beings', 'beings', 'beings', 'above', 'above', 'above', 'above', 'above', 'above', 'above', 'above', 'above', 'above', 'the', 'the', 'age', 'age', 'age', 'age', 'age', 'age', 'of', 'of', 'of', 'of', 'five', 'five', 'five', 'five', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'possibly', 'possibly', 'possibly', 'possibly', 'possibly', 'possibly', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'higher', 'higher', 'higher', 'higher', 'higher', 'higher', 'higher', 'higher', 'higher', 'higher', 'primates', 'primates', 'primates', 'primates', 'primates', 'primates', 'primates', 'primates', 'such', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'adult', 'adult', 'adult', 'adult', 'gorillas', 'gorillas', 'gorillas', 'gorillas', 'gorillas', 'gorillas', 'gorillas', 'gorillas', 'chimpanzees', 'chimpanzees', 'and', 'and', 'typical', 'typical', 'typical', 'typical', 'typical', 'typical', 'typical', 'typical', 'typical', 'typical', 'five', 'five', 'five', 'five', 'year', 'year', 'year', 'year', 'olds', 'olds', 'olds', 'olds', 'olds', 'olds', 'olds', 'olds', 'olds', 'olds', 'can', 'can', 'develop', 'develop', 'develop', 'develop', 'insights', 'insights', 'insights', 'insights', 'insights', 'insights', 'insights', 'insights', 'into', 'into', 'into', 'into', 'into', 'into', 'into', 'into', 'into', 'into', 'other', 'other', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 's', 's', 's', 's', 's', 's', 's', 's', 'different', 'different', 'different', 'different', 'different', 'different', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'knowledge', 'feelings', 'feelings', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'intentions', 'intentions', 'intentions', 'intentions', 'interpretations', 'interpretations', 'interpretations', 'interpretations', 'based', 'based', 'based', 'based', 'based', 'based', 'based', 'based', 'based', 'based', 'upon', 'upon', 'social', 'social', 'social', 'social', 'cues', 'cues', 'cues', 'cues', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'gestures', 'gestures', 'facial', 'facial', 'expressions', 'expressions', 'expressions', 'expressions', 'an', 'an', 'an', 'an', 'an', 'an', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'individual', 'with', 'with', 'autism', 'autism', 'autism', 'autism', 'seems ...
# ['frustration', 'or', 'or', 'or', 'or', 'or', 'or', 'resort', 'resort', 'resort', 'resort', 'resort', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'grabbing', 'grabbing', 'grabbing', 'grabbing', 'what', 'what', 'they', 'they', 'they', 'they', 'they', 'they', 'they', 'they', 'they', 'they', 'want', 'want', 'want', 'want', 'want', 'want', 'want', 'want', 'while', 'while', 'while', 'while', 'while', 'while', 'while', 'while', 'waiting', 'waiting', 'waiting', 'waiting', 'waiting', 'waiting', 'for', 'for', 'for', 'for', 'for', 'for', 'non', 'non', 'non', 'non', 'non', 'non', 'non', 'non', 'autistic', 'autistic', 'people', 'people', 'people', 'people', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'learn', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'communicate', 'communicate', 'communicate', 'communicate', 'communicate', 'with', 'with', 'with', 'with', 'with', 'with', 'with', 'with', 'them', 'them', 'them', 'them', 'them', 'people', 'people', 'with', 'with', 'with', 'with', 'with', 'with', 'with', 'with', 'autism', 'autism', 'do', 'do', 'do', 'do', 'do', 'do', 'whatever', 'whatever', 'whatever', 'whatever', 'whatever', 'whatever', 'they', 'they', 'can', 'can', 'to', 'to', 'to', 'to', 'to', 'to', 'get', 'get', 'get', 'get', 'get', 'through', 'through', 'through', 'through', 'through', 'through', 'through', 'through', 'through', 'to', 'to', 'to', 'to', 'to', 'to', 'them', 'them', 'them', 'them', 'them', 'them', 'communication', 'communication', 'communication', 'communication', 'communication', 'communication', 'communication', 'difficulties', 'difficulties', 'difficulties', 'difficulties', 'difficulties', 'difficulties', 'difficulties', 'difficulties', 'difficulties', 'may', 'may', 'may', 'may', 'may', 'may', 'contribute', 'contribute', 'contribute', 'contribute', 'contribute', 'contribute', 'contribute', 'contribute', 'contribute', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'autistic', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'becoming', 'becoming', 'becoming', 'becoming', 'becoming', 'becoming', 'becoming', 'becoming', 'socially', 'socially', 'socially', 'socially', 'anxious', 'anxious', 'or', 'or', 'or', 'or', 'depressed', 'depressed', 'depressed', 'depressed', 'repetitive', 'repetitive', 'repetitive', 'repetitive', 'behaviors', 'behaviors', 'behaviors', 'behaviors', 'behaviors', 'behaviors', 'although', 'although', 'although', 'although', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'people', 'with', 'with', 'with', 'with', 'autism', 'autism', 'autism', 'autism', 'autism', 'autism', 'autism', 'autism', 'autism', 'autism', 'usually', 'usually', 'appear', 'appear', 'appear', 'appear', 'appear', 'appear', 'appear', 'appear', 'physically', 'physically', 'physically', 'physically', 'physically', 'physically', 'physically', 'physically', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'and', 'and', 'have', 'have', 'have', 'have', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good', 'muscle', 'muscle', 'muscle', 'muscle', 'muscle', 'muscle', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'unusual', 'unusual', 'unusual', 'unusual', 'repetitive', 'repetitive', 'repetitive', 'repetitive', 'repetitive', 'repetitive', 'repetitive', 'repetitive', 'motions', 'motions', 'motions', 'motions', 'motions', 'motions', 'motions', 'motions', 'motions', 'motions', 'known', 'known', 'known', 'known', 'as', 'as', 'self', 'self', 'stimulation', 'stimulation', 'stimulation', 'stimulation', 'stimulation', 'stimulation', 'stimulation', 'stimulation', 'or', 'or', 'or', 'or', 'or', 'or', 'may', 'may', 'set', 'set', 'set', 'set', 'them', 'them', 'apart', 'apart', 'these', 'these', 'these', 'these', 'these', 'these', 'behaviors', 'behavio ...
# ['in', 'intensity', 'intensity', 'intensity', 'intensity', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'focus', 'focus', 'apparently', 'apparently', 'apparently', 'apparently', 'apparently', 'apparently', 'inflexible', 'inflexible', 'inflexible', 'inflexible', 'inflexible', 'inflexible', 'adherence', 'adherence', 'adherence', 'adherence', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'specific', 'specific', 'specific', 'specific', 'specific', 'specific', 'specific', 'specific', 'specific', 'specific', 'routines', 'routines', 'routines', 'routines', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'rituals', 'rituals', 'rituals', 'rituals', 'rituals', 'rituals', 'stereotyped', 'stereotyped', 'stereotyped', 'stereotyped', 'stereotyped', 'stereotyped', 'stereotyped', 'stereotyped', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'repetitive', 'repetitive', 'motor', 'motor', 'mannerisms', 'mannerisms', 'mannerisms', 'mannerisms', 'mannerisms', 'mannerisms', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'e', 'g', 'g', 'g', 'g', 'g', 'g', 'hand', 'hand', 'hand', 'hand', 'hand', 'hand', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'finger', 'finger', 'finger', 'finger', 'finger', 'finger', 'finger', 'finger', 'flapping', 'flapping', 'flapping', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'twisting', 'twisting', 'twisting', 'twisting', 'twisting', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'or', 'complex', 'complex', 'complex', 'complex', 'complex', 'whole', 'whole', 'whole', 'whole', 'body', 'body', 'body', 'body', 'body', 'body', 'body', 'body', 'body', 'movements', 'movements', 'movements', 'movements', 'movements', 'movements', 'movements', 'movements', 'persistent', 'persistent', 'preoccupation', 'preoccupation', 'preoccupation', 'preoccupation', 'preoccupation', 'preoccupation', 'preoccupation', 'preoccupation', 'with', 'with', 'with', 'with', 'parts', 'parts', 'parts', 'parts', 'parts', 'parts', 'of', 'of', 'objects', 'objects', 'objects', 'objects', 'delays', 'delays', 'delays', 'delays', 'or', 'or', 'abnormal', 'abnormal', 'abnormal', 'abnormal', 'abnormal', 'abnormal', 'functioning', 'functioning', 'functioning', 'functioning', 'functioning', 'functioning', 'in', 'in', 'in', 'in', 'at', 'at', 'at', 'at', 'at', 'at', 'at', 'at', 'at', 'at', 'least', 'least', 'least', 'least', 'one', 'one', 'one', 'one', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'the', 'the', 'the', 'the', 'the', 'the', 'following', 'following', 'areas', 'areas', 'areas', 'areas', 'with', 'with', 'with', 'with', 'with', 'with', 'onset', 'onset', 'onset', 'onset', 'prior', 'prior', 'prior', 'prior', 'to', 'to', 'to', 'to', 'age', 'age', 'age', 'age', 'age', 'age', 'three', 'three', 'three', 'three', 'years', 'years', 'years', 'years', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'one', 'social', 'social', 'social', 'social', 'interaction', 'interaction', 'interaction', 'interaction', 'interaction', 'interaction', 'two', 'two', 'two', 'two', 'language', 'language', 'as', 'as', 'as', 'as', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'used', 'in', 'in', 'social', 'social', 'social', 'social', 'social', 'social', 'social', 'social', 'communication', 'communication', 'communication', 'communication', 'or', 'or', 'or', 'or', 'or', 'or', 'three', 'three', 'symbolic', 'symbolic', 'symbolic', 'symbolic', 'symbolic', 'symbolic', 'symbolic', 'symbolic', 'symbolic', 'or', 'or', 'or', 'or', 'or', 'or', 'imaginative', 'imaginative', 'imaginative', 'imaginative', 'play', 'play', 'play', 'play', 'play', 'play', 'play', 'play', 'play', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'disturbance', 'disturbance', 'disturbance', 'disturbance', 'disturbance', 'disturbance', 'disturbance', 'disturbance', 'is', 'is', 'is', 'is', 'is', 'is', 'not', 'not', 'not', 'not', 'not', 'not', 'not', 'not', 'not', 'not', 'better', 'better', 'accounted', 'accounted', 'accounted', 'accounted', 'accou ...
# ['seeing', 'seeing', 'seeing', 'seeing', 'seeing', 'a', 'a', 'a', 'true', 'true', 'true', 'true', 'true', 'true', 'rise', 'rise', 'rise', 'rise', 'rise', 'rise', 'rise', 'but', 'but', 'right', 'right', 'now', 'now', 'i', 'i', 'i', 'i', 'don', 'don', 'don', 'don', 'don', 'don', 'don', 'don', 'don', 'don', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 'think', 'think', 'think', 'think', 'anybody', 'anybody', 'anybody', 'anybody', 'anybody', 'anybody', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'can', 'answer', 'answer', 'answer', 'answer', 'answer', 'answer', 'answer', 'answer', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'that', 'question', 'question', 'question', 'question', 'for', 'for', 'for', 'for', 'sure', 'sure', 'sure', 'sure', 'newsweek', 'newsweek', 'newsweek', 'newsweek', 'newsweek', 'newsweek', 'newsweek', 'newsweek', 'reference', 'reference', 'reference', 'reference', 'reference', 'reference', 'reference', 'reference', 'reference', 'reference', 'below', 'below', 'the', 'the', 'answer', 'answer', 'answer', 'answer', 'answer', 'answer', 'answer', 'answer', 'to', 'to', 'to', 'to', 'to', 'to', 'this', 'this', 'question', 'question', 'has', 'has', 'has', 'has', 'has', 'has', 'has', 'has', 'significant', 'significant', 'significant', 'significant', 'significant', 'significant', 'significant', 'significant', 'ramifications', 'ramifications', 'ramifications', 'ramifications', 'ramifications', 'ramifications', 'on', 'on', 'on', 'on', 'on', 'on', 'on', 'on', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'direction', 'direction', 'of', 'of', 'of', 'of', 'of', 'of', 'research', 'research', 'research', 'research', 'since', 'since', 'since', 'since', 'a', 'a', 'real', 'real', 'increase', 'increase', 'increase', 'increase', 'increase', 'increase', 'increase', 'increase', 'increase', 'increase', 'would', 'would', 'would', 'would', 'focus', 'focus', 'focus', 'focus', 'focus', 'focus', 'focus', 'focus', 'more', 'more', 'more', 'more', 'attention', 'attention', 'attention', 'attention', 'and', 'and', 'research', 'research', 'research', 'research', 'funding', 'funding', 'funding', 'funding', 'funding', 'funding', 'on', 'on', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'search', 'search', 'search', 'search', 'for', 'for', 'for', 'for', 'environmental', 'environmental', 'factors', 'factors', 'while', 'while', 'little', 'little', 'little', 'little', 'little', 'little', 'little', 'little', 'or', 'or', 'or', 'or', 'or', 'or', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'real', 'increase', 'increase', 'increase', 'increase', 'increase', 'increase', 'would', 'would', 'would', 'would', 'focus', 'focus', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'more', 'attention', 'attention', 'attention', 'attention', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'genetics', 'genetics', 'genetics', 'genetics', 'genetics', 'genetics', 'genetics', 'genetics', 'on', 'on', 'on', 'on', 'on', 'on', 'on', 'on', 'the', 'the', 'the', 'the', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'hand', 'hand', 'hand', 'hand', 'it', 'it', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'conceivable', 'that', 'that', 'that', 'that', 'that', 'that', 'certain', 'certain', 'certain', 'certain', 'certain', 'certain', 'certain', 'certain', 'environmental', 'environmental', 'factors', 'factors', 'vaccination', 'vaccination', 'vaccination', 'vaccination', 'vaccination', 'vaccination', 'vaccination', 'vaccination', 'diet', 'diet', 'diet', 'diet', 'societal', 'societal', 'societal', 'societal', 'societal', 'societal', 'societal', 'societal', 'societal', 'societal', 'changes', 'changes', 'changes', 'changes', 'may', 'may', 'have', 'have', 'hav ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# Exception ignored in: 'zmq.backend.cython.message.Frame.__dealloc__'
# Traceback (most recent call last):
#   File "zmq/backend/cython/checkrc.pxd", line 12, in zmq.backend.cython.checkrc._check_rc (zmq/backend/cython/message.c:4294)
# KeyboardInterrupt
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-1830bd11d13f> in <module>()
# ----> 1 for x, y in get_batches(words, 1000):
#       2     print(x, y)
#
# <ipython-input-108-bbde76dd99ea> in get_batches(words, batch_size, window_size)
#       9     for idx in range(0, len(words), batch_size):
#      10         x, y = [], []
# ---> 11         batch = words[idx:idx+batch_size]
#      12         for ii in range(len(batch)):
#      13             batch_x = batch[ii]
#
# KeyboardInterrupt:

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1, 1))   
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6327 0.3348 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6217 0.3251 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5184 0.3232 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6057 0.3573 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5204 0.3954 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5300 0.3609 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5451 0.3417 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5322 0.3584 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4871 0.3156 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4315 0.3143 sec/batch
# Nearest to five: macy, budgets, isomorphisms, indicate, law, pataki, stung, emmanuel,
# Nearest to time: mineralogical, credible, eval, bile, hipc, fantasy, strains, puzzled,
# Nearest to has: soloists, vld, fahd, greenman, defer, mihai, xiaoping, sx,
# Nearest to many: intolerant, centrioles, corroborate, milked, august, bronx, guilds, profoundly,
# Nearest to to: amadou, newsstand, heuss, disbanding, window, bullshit, lesund, multicoloured,
# Nearest to only: gibi, transoxiana, vida, admirably, housing, msrp, sardis, fisch,
# Nearest to be: bays, fu, valeri, europium, hinges, ceremonially, readability, ous,
# Nearest to this: janitor, relied, pastiche, furnaces, biogeography, dago, disadvantaged, buchanan,
# Nearest to square: h, ancient, mein, outbreak, young, shenanigans, acupuncturists, interpreting,
# Nearest to hit: exxon, csm, cornish, progressive, lili, reserving, giants, manage,
# Nearest to nobel: improvised, ligatures, pricking, mesh, orange, bon, hr, colophon,
# Nearest to freedom: battlefields, ansbach, docks, boddason, foo, ecologists, chariot, age,
# Nearest to operating: esperanto, kk, lexcorp, ccj, timbers, unattractive, rounders, devon,
# Nearest to mainly: aelius, dich, lemmas, vessel, cxd, politiken, petn, issuing,
# Nearest to joseph: excelsa, borromini, fushimi, marini, ilois, qu, nanotech, prophesying,
# Nearest to notes: hashim, domestication, perry, jaber, asimov, argue, alley, bulbs,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4707 0.3365 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3723 0.3311 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3343 0.3493 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2566 0.3118 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1859 0.3199 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1810 0.3148 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1027 0.3124 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0748 0.3164 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0124 0.3106 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9891 0.3080 sec/batch
# Nearest to five: indicate, macy, law, isomorphisms, budgets, emmanuel, germans, nippon,
# Nearest to time: credible, fantasy, mineralogical, eval, strains, bile, unclear, baile,
# Nearest to has: soloists, the, vld, simultaneously, points, defer, cold, breaks,
# Nearest to many: intolerant, centrioles, corroborate, milked, supplied, guilds, august, meant,
# Nearest to to: window, disambiguation, amadou, continuing, hide, multicoloured, battler, bullshit,
# Nearest to only: housing, gibi, possible, admirably, transoxiana, vida, plot, stimulated,
# Nearest to be: lectures, maintained, died, valeri, consolidated, ladoga, fu, hinges,
# Nearest to this: janitor, confusion, relied, furnaces, pastiche, coriolis, disadvantaged, buchanan,
# Nearest to square: h, young, ancient, variously, v, interpreting, gaffe, outbreak,
# Nearest to hit: exxon, manage, special, giants, cornish, progressive, compare, mainly,
# Nearest to nobel: improvised, ligatures, primarily, orange, well, experimenting, bon, hr,
# Nearest to freedom: battlefields, age, package, intelligent, ecologists, boddason, foo, ansbach,
# Nearest to operating: esperanto, ccj, believes, devon, kk, timbers, creator, cosine,
# Nearest to mainly: aelius, velocity, teachers, vessel, turkey, leslie, hit, cxd,
# Nearest to joseph: excelsa, ilois, promise, qu, marini, wide, borromini, astbury,
# Nearest to notes: perry, argue, junior, hashim, evil, calicut, domestication, outer,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9170 0.3159 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9021 0.3098 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8770 0.3184 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8780 0.3258 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8302 0.3100 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8091 0.3132 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7842 0.3146 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8031 0.3253 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7850 0.3203 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7796 0.3184 sec/batch
# Nearest to five: macy, nippon, emmanuel, budgets, award, indicate, administering, hyde,
# Nearest to time: credible, fantasy, mineralogical, bile, christianised, eval, hipc, strains,
# Nearest to has: soloists, vld, simultaneously, acquiring, the, defer, sx, presents,
# Nearest to many: intolerant, centrioles, guilds, corroborate, milked, retarded, disasters, bronx,
# Nearest to to: amadou, window, disambiguation, hide, bullshit, continuing, heuss, crimson,
# Nearest to only: gibi, transoxiana, stimulated, possible, housing, admirably, vida, reformed,
# Nearest to be: readability, hinges, fu, bays, maintained, lectures, humanely, theory,
# Nearest to this: janitor, relied, confusion, pastiche, furnaces, biogeography, coriolis, disadvantaged,
# Nearest to square: h, variously, outbreak, young, shenanigans, ancient, interpreting, v,
# Nearest to hit: exxon, manage, progressive, giants, narnia, csm, special, compare,
# Nearest to nobel: improvised, actor, mesh, orange, legacy, primarily, hr, ligatures,
# Nearest to freedom: battlefields, age, ecologists, package, foo, ansbach, intelligent, cars,
# Nearest to operating: kk, ccj, esperanto, believes, timbers, puppy, devon, reprisal,
# Nearest to mainly: aelius, teachers, velocity, vessel, issuing, leslie, patriotism, engravings,
# Nearest to joseph: excelsa, promise, astbury, borromini, ilois, workmen, qu, reunion,
# Nearest to notes: perry, argue, domestication, evil, horrified, bulbs, junior, hashim,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7939 0.3235 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7642 0.3138 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7126 0.3157 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6995 0.3166 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7404 0.3198 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7243 0.3171 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7222 0.3196 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7124 0.3166 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7060 0.3169 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6714 0.3122 sec/batch
# Nearest to five: emmanuel, nippon, macy, two, edwards, engelbert, award, hyde,
# Nearest to time: credible, mineralogical, bile, gangsters, fantasy, christianised, eval, hipc,
# Nearest to has: soloists, vld, the, transits, defer, mediator, acquiring, simultaneously,
# Nearest to many: intolerant, centrioles, retarded, guilds, corroborate, disasters, milked, bronx,
# Nearest to to: bullshit, crimson, amadou, hide, disbanding, window, disambiguation, heuss,
# Nearest to only: gibi, transoxiana, vida, stimulated, possible, tutors, plot, admirably,
# Nearest to be: readability, hinges, theory, then, melted, humanely, fu, seaboard,
# Nearest to this: confusion, janitor, pastiche, hashes, furnaces, relied, disadvantaged, coriolis,
# Nearest to square: h, variously, v, shenanigans, young, gaffe, streams, interpreting,
# Nearest to hit: exxon, manage, lili, csm, narnia, progressive, giants, byron,
# Nearest to nobel: actor, improvised, legacy, javier, mesh, orange, milliseconds, hr,
# Nearest to freedom: battlefields, foo, ansbach, age, ecologists, intelligent, boddason, package,
# Nearest to operating: kk, ccj, puppy, lexcorp, timbers, believes, reprisal, hopefully,
# Nearest to mainly: aelius, vessel, issuing, velocity, teachers, patriotism, engravings, lemmas,
# Nearest to joseph: excelsa, promise, reunion, astbury, nanotech, borromini, rebellious, qu,
# Nearest to notes: perry, argue, domestication, hashim, armagh, boers, evil, horrified,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6957 0.3196 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6914 0.3189 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6070 0.3188 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6406 0.3382 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6107 0.3292 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5945 0.3196 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6038 0.2382 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5491 0.3252 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5093 0.3240 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4950 0.3206 sec/batch
# Nearest to five: emmanuel, two, macy, nippon, edwards, ewing, kelley, hyde,
# Nearest to time: christianised, credible, gangsters, fantasy, visualisation, hipc, eval, obstinate,
# Nearest to has: soloists, vld, the, transits, simultaneously, defer, acquiring, mindful,
# Nearest to many: intolerant, centrioles, corroborate, retarded, guilds, milked, disasters, meant,
# Nearest to to: amadou, crimson, bullshit, hide, disbanding, heuss, window, clear,
# Nearest to only: transoxiana, gibi, possible, tutors, admirably, stimulated, vida, underlie,
# Nearest to be: readability, hinges, theory, humanely, solids, then, develop, fu,
# Nearest to this: confusion, janitor, relied, pastiche, hashes, biogeography, disadvantaged, furnaces,
# Nearest to square: h, v, variously, gaffe, the, streams, int, approximately,
# Nearest to hit: exxon, lili, manage, csm, narnia, jamie, giants, progressive,
# Nearest to nobel: actor, poet, nine, prize, javier, francesco, laureate, archbishop,
# Nearest to freedom: battlefields, ansbach, foo, ecologists, intelligent, boddason, age, militias,
# Nearest to operating: ccj, utf, kk, macintosh, cordially, lexcorp, believes, puppy,
# Nearest to mainly: aelius, vessel, teachers, lemmas, issuing, velocity, engravings, petn,
# Nearest to joseph: excelsa, nanotech, astbury, promise, columnist, reunion, borromini, archibald,
# Nearest to notes: perry, domestication, hashim, argue, armagh, alley, bulbs, horrified,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5002 0.3254 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5099 0.3565 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4532 0.3733 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5173 0.3452 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5201 0.3224 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4612 0.3213 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4723 0.3181 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3852 0.3205 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4298 0.3219 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4224 0.3192 sec/batch
# Nearest to five: two, macy, nippon, emmanuel, ewing, kelley, dwt, heliports,
# Nearest to time: christianised, credible, visualisation, gangsters, fantasy, hipc, obstinate, eval,
# Nearest to has: the, vld, points, soloists, mindful, transits, defer, simultaneously,
# Nearest to many: intolerant, centrioles, corroborate, retarded, guilds, meant, milked, ventral,
# Nearest to to: amadou, bullshit, crimson, newsstand, disbanding, heuss, lesund, bohm,
# Nearest to only: gibi, transoxiana, possible, tutors, stimulated, admirably, vida, underlie,
# Nearest to be: theory, readability, hinges, solids, then, humanely, particular, always,
# Nearest to this: confusion, relied, hashes, disadvantaged, knowing, footnote, janitor, biogeography,
# Nearest to square: h, streams, v, approximately, gaffe, int, the, variously,
# Nearest to hit: exxon, lili, narnia, csm, manage, giants, jamie, roasted,
# Nearest to nobel: actor, poet, francesco, javier, prize, legacy, hr, bon,
# Nearest to freedom: battlefields, ansbach, foo, political, intelligent, ecologists, militias, boddason,
# Nearest to operating: macintosh, ccj, utf, kk, handled, cordially, syntax, rounders,
# Nearest to mainly: aelius, lemmas, issuing, vessel, petn, engravings, heflin, velocity,
# Nearest to joseph: excelsa, nanotech, reunion, astbury, columnist, trent, promise, presbyter,
# Nearest to notes: domestication, perry, hashim, alley, jaber, argue, armagh, starfish,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4564 0.3265 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4348 0.3207 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4148 0.3209 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3711 0.3202 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4106 0.3179 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4596 0.3198 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3810 0.3226 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3843 0.3215 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4195 0.3168 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3879 0.3173 sec/batch
# Nearest to five: two, ewing, macy, four, nippon, emmanuel, kelley, dwt,
# Nearest to time: christianised, visualisation, credible, fantasy, obstinate, hipc, gangsters, mineralogical,
# Nearest to has: the, vld, simultaneously, points, transits, soloists, defer, perpetuity,
# Nearest to many: intolerant, centrioles, retarded, corroborate, meant, obesity, unanimity, guilds,
# Nearest to to: amadou, newsstand, bohm, heathen, bullshit, crimson, glides, tyranny,
# Nearest to only: transoxiana, gibi, stimulated, tutors, possible, vida, fisch, admirably,
# Nearest to be: readability, then, humanely, hinges, ceremonially, solids, particular, theory,
# Nearest to this: confusion, disadvantaged, relied, hashes, quantified, janitor, lest, pastiche,
# Nearest to square: h, v, streams, int, approximately, gaffe, cheyenne, indomitable,
# Nearest to hit: exxon, lili, narnia, jamie, chris, manage, csm, roasted,
# Nearest to nobel: actor, poet, francesco, prize, javier, laureate, hr, improvised,
# Nearest to freedom: battlefields, ansbach, political, foo, sanctions, militias, boddason, acknowledge,
# Nearest to operating: macintosh, ccj, utf, systems, kk, handled, dos, cordially,
# Nearest to mainly: aelius, issuing, lemmas, engravings, turkey, heflin, petn, vessel,
# Nearest to joseph: excelsa, rainer, reunion, trent, columnist, archibald, nara, presbyter,
# Nearest to notes: perry, hashim, domestication, reared, jaber, horrified, evil, starfish,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4008 0.3266 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3897 0.3214 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3667 0.3202 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3648 0.3252 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4159 0.3332 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3696 0.3322 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3946 0.3227 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3762 0.3206 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3444 0.3228 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3215 0.3193 sec/batch
# Nearest to five: two, four, eight, zero, ewing, macy, dwt, three,
# Nearest to time: christianised, gangsters, credible, visualisation, hipc, worshipful, obstinate, eval,
# Nearest to has: the, points, soloists, perpetuity, xiaoping, transits, vld, christianised,
# Nearest to many: centrioles, intolerant, retarded, corroborate, unanimity, teixeira, meant, guilds,
# Nearest to to: amadou, tyranny, offences, glides, swingarm, ocaml, clear, specious,
# Nearest to only: gibi, transoxiana, stimulated, tutors, vida, fisch, anomaly, phonemic,
# Nearest to be: readability, humanely, then, hinges, ceremonially, arbitrary, always, solids,
# Nearest to this: confusion, disadvantaged, relied, hashes, lest, coriolis, janitor, pastiche,
# Nearest to square: h, v, streams, int, approximately, heights, gaffe, vechten,
# Nearest to hit: exxon, lili, jamie, chris, narnia, directorial, epilogue, giants,
# Nearest to nobel: actor, poet, physiology, javier, francesco, prize, hr, modernist,
# Nearest to freedom: battlefields, political, ansbach, sanctions, militias, acknowledge, foo, indicted,
# Nearest to operating: ccj, utf, macintosh, systems, kk, unix, handled, dos,
# Nearest to mainly: aelius, turkey, middle, heflin, lemmas, engravings, issuing, alpine,
# Nearest to joseph: excelsa, borromini, reunion, columnist, rainer, presbyter, archibald, nara,
# Nearest to notes: hashim, perry, domestication, jaber, starfish, strings, reared, solo,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3700 0.3267 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2760 0.3263 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3530 0.3205 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3562 0.3192 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3861 0.3316 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2936 0.3354 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2842 0.3921 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3270 0.3317 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
