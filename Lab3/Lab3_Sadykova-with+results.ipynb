# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
with open('text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    rand = random.randint(1, window_size+1)
    if (idx - rand) > 0:
        a = idx - rand
    else: 
        a=0
    b = idx + rand + 1
    get_target_words = set(words[a:idx] + words[idx+1:b])
   
    return list(get_target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) 
    softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias")
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w,
        biases=softmax_b,
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6343 0.3882 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6102 0.4002 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4990 0.4309 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5808 0.3961 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4705 0.3961 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4498 0.3981 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4886 0.3917 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5363 0.3782 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4334 0.3832 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3965 0.3821 sec/batch
# Nearest to who: index, broadsword, axiomatic, customizations, rapunzel, cortona, chojn, houdini,
# Nearest to while: werther, puttnam, seigneurial, sad, stoked, withdraw, elevation, doohan,
# Nearest to from: sebastien, dak, serbian, wark, asenath, tomahawk, marrying, toxins,
# Nearest to into: resolving, schillinger, escapees, blok, khaganate, haggai, varennes, radicalism,
# Nearest to as: whispers, small, tile, markus, napo, bengal, baptize, electroplating,
# Nearest to during: hotdog, ramsey, antithesis, freire, dh, perinatal, glamorgan, avalon,
# Nearest to also: freezing, sonny, terrace, tournaments, founds, primed, oratio, praia,
# Nearest to its: buffs, haunt, spectral, hoche, winwood, secaucus, gabba, materialism,
# Nearest to shows: rhee, astronomia, droit, herbivorous, nuke, tommie, lipscomb, neurath,
# Nearest to bible: diced, hydroxide, rud, asatru, prone, advancements, kissinger, privatdozent,
# Nearest to test: interdependencies, cocker, retainers, torah, alcindor, businesspeople, officialdom, ewe,
# Nearest to engine: mainframe, subfield, delay, sorceress, staged, billed, strutt, schleswig,
# Nearest to articles: doers, tips, tilburg, danuta, solano, accurate, brimstone, keres,
# Nearest to instance: belmondo, gagne, protea, szlachta, kasem, handel, probability, fraktion,
# Nearest to alternative: decidedly, joachim, las, workability, unnamed, pomeroy, mercenary, waleed,
# Nearest to consists: copyrighted, ellsworth, benguela, alphabets, handy, dunbar, triangular, fao,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4517 0.3864 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3576 0.3795 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3082 0.3827 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2164 0.3793 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1486 0.3802 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1722 0.3911 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0889 0.3803 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0319 0.3800 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0253 0.3806 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9975 0.3805 sec/batch
# Nearest to who: index, customizations, dojos, axiomatic, cortona, broadsword, sky, chojn,
# Nearest to while: elevation, sad, withdraw, puttnam, stoked, thanks, existence, strong,
# Nearest to from: marrying, wark, pen, sebastien, almost, turbojet, admission, recordable,
# Nearest to into: resolving, uspto, escapees, survival, generation, experience, constitutional, bcnf,
# Nearest to as: small, understood, tile, italy, whispers, an, long, napo,
# Nearest to during: equipment, antithesis, ramsey, partners, hotdog, avalon, custom, rate,
# Nearest to also: freezing, tournaments, terrace, bound, founds, sonny, pawl, promote,
# Nearest to its: spectral, necessarily, haunt, materialism, buffs, technological, handwriting, refute,
# Nearest to shows: can, further, funding, droit, recreational, on, shown, formatting,
# Nearest to bible: diced, hydroxide, decision, prone, rud, kissinger, astronomers, asatru,
# Nearest to test: retainers, torah, cocker, alcindor, sets, officialdom, prix, ewe,
# Nearest to engine: mainframe, delay, subfield, matter, staged, sorceress, billed, hispanics,
# Nearest to articles: tips, tilburg, accurate, danuta, signifying, great, brimstone, un,
# Nearest to instance: belmondo, performed, handel, probability, gagne, kasem, dewey, indispensable,
# Nearest to alternative: decidedly, joachim, one, solutions, workability, mercenary, unnamed, summaries,
# Nearest to consists: copyrighted, triangular, nullified, alphabets, chaerea, fao, baronies, ellsworth,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9563 0.3856 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9035 0.3802 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9077 0.3814 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8735 0.3805 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8343 0.3793 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8092 0.3817 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8038 0.3812 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8055 0.3788 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7943 0.3817 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7920 0.3798 sec/batch
# Nearest to who: index, axiomatic, customizations, sky, dojos, broadsword, shores, heavens,
# Nearest to while: withdraw, sad, elevation, puttnam, stoked, thanks, slides, seigneurial,
# Nearest to from: serbian, marrying, pen, duties, sebastien, wark, hatred, recordable,
# Nearest to into: resolving, generation, constitutional, harbor, escapees, atp, survival, uspto,
# Nearest to as: italy, tile, small, understood, markus, whispers, napo, arbitrarily,
# Nearest to during: equipment, antithesis, ramsey, custom, partners, avalon, perinatal, hotdog,
# Nearest to also: sonny, freezing, founds, tournaments, terrace, pawl, arrest, insular,
# Nearest to its: spectral, necessarily, haunt, materialism, buffs, technological, partisan, handwriting,
# Nearest to shows: can, funding, further, droit, uniform, maturity, famed, recreational,
# Nearest to bible: diced, hydroxide, decision, kissinger, astronomers, prone, rud, milestone,
# Nearest to test: torah, sets, prix, officialdom, retainers, alcindor, jewish, ewe,
# Nearest to engine: mainframe, delay, subfield, matter, staged, sorceress, billed, hispanics,
# Nearest to articles: accurate, tips, tilburg, signifying, great, brimstone, implementing, un,
# Nearest to instance: belmondo, handel, probability, glorified, saxons, performed, gagne, distributes,
# Nearest to alternative: decidedly, solutions, mercenary, summaries, unnamed, joachim, theorists, one,
# Nearest to consists: copyrighted, triangular, fao, alphabets, nullified, chaerea, ellsworth, handy,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8088 0.3844 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7845 0.3812 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6999 0.3806 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7099 0.3800 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7701 0.3847 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6900 0.3784 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7027 0.3814 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7406 0.3809 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6884 0.3817 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6565 0.3796 sec/batch
# Nearest to who: index, axiomatic, customizations, chojn, broadsword, heavens, lecturing, vermiculite,
# Nearest to while: sad, withdraw, puttnam, elevation, slides, doohan, stoked, pont,
# Nearest to from: serbian, marrying, sebastien, duties, dis, pen, hatred, wark,
# Nearest to into: resolving, escapees, harbor, schillinger, uspto, generation, atp, survival,
# Nearest to as: markus, whispers, tile, understood, small, italy, shattered, necklace,
# Nearest to during: equipment, antithesis, perinatal, ramsey, avalon, hotdog, freire, paganism,
# Nearest to also: founds, sonny, insular, tournaments, freezing, characterise, terrace, primed,
# Nearest to its: haunt, materialism, buffs, spectral, necessarily, aiding, vichy, nq,
# Nearest to shows: can, funding, rhee, astronomia, maturity, droit, nuke, further,
# Nearest to bible: diced, hydroxide, kissinger, astronomers, decision, privatdozent, enslaved, rud,
# Nearest to test: prix, alcindor, torah, officialdom, retainers, sets, cocker, jewish,
# Nearest to engine: mainframe, delay, subfield, matter, billed, sorceress, hispanics, augsburg,
# Nearest to articles: accurate, tips, tilburg, signifying, un, implementing, great, brimstone,
# Nearest to instance: belmondo, handel, performed, gagne, probability, distributes, saxons, glorified,
# Nearest to alternative: decidedly, solutions, unnamed, mercenary, joachim, workability, summaries, theorists,
# Nearest to consists: copyrighted, alphabets, fao, triangular, baronies, ellsworth, dunbar, handy,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6776 0.3862 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6651 0.3818 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6200 0.3792 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6441 0.3803 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6566 0.3834 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6324 0.3782 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5997 0.2622 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5696 0.3817 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5209 0.3835 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5125 0.3791 sec/batch
# Nearest to who: customizations, index, chojn, lecturing, amin, axiomatic, vermiculite, yorke,
# Nearest to while: sad, withdraw, puttnam, doohan, seigneurial, werther, slides, stoked,
# Nearest to from: serbian, sebastien, marrying, recordable, duties, hatred, turbojet, dis,
# Nearest to into: schillinger, blok, resolving, escapees, harbor, flung, consuls, atp,
# Nearest to as: markus, understood, whispers, tile, necklace, distro, small, shattered,
# Nearest to during: hotdog, perinatal, floated, ramsey, avalon, equipment, antithesis, stamper,
# Nearest to also: insular, characterise, sonny, founds, tournaments, terrace, primed, moderne,
# Nearest to its: materialism, buffs, haunt, necessarily, nq, aiding, spectral, hoche,
# Nearest to shows: can, astronomia, funding, herbivorous, nuke, maturity, lipscomb, morons,
# Nearest to bible: diced, kissinger, hydroxide, gospel, masjid, privatdozent, enslaved, wein,
# Nearest to test: alcindor, prix, officialdom, sets, cocker, torah, retainers, bovine,
# Nearest to engine: mainframe, delay, subfield, matter, billed, hispanics, sorceress, scribes,
# Nearest to articles: tilburg, signifying, tips, accurate, brimstone, un, doers, theoretic,
# Nearest to instance: belmondo, probability, handel, performed, gagne, distributes, code, scattering,
# Nearest to alternative: decidedly, solutions, mercenary, unnamed, summaries, theorists, joachim, workability,
# Nearest to consists: copyrighted, alphabets, dunbar, pledging, ellsworth, baronies, triangular, mech,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4969 0.3831 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4992 0.3851 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4548 0.3825 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4767 0.3779 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4914 0.3800 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4713 0.3825 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4468 0.3777 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4246 0.3807 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4531 0.3826 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3921 0.3792 sec/batch
# Nearest to who: amin, customizations, index, deviated, chojn, lecturing, houdini, axiomatic,
# Nearest to while: sad, withdraw, puttnam, doohan, werther, heaters, stoked, slides,
# Nearest to from: serbian, declares, sebastien, turbojet, sparsely, country, marrying, collecting,
# Nearest to into: blok, schillinger, escapees, approximately, resolving, surrender, discernible, unregistered,
# Nearest to as: understood, markus, whispers, tile, an, small, distro, mmu,
# Nearest to during: hotdog, perinatal, floated, equipment, flotilla, antithesis, avalon, fearful,
# Nearest to also: insular, characterise, founds, grammer, sonny, tournaments, foregoing, moderne,
# Nearest to its: nq, buffs, materialism, necessarily, haunt, hoche, polluted, vichy,
# Nearest to shows: can, herbivorous, astronomia, maturity, nuke, lipscomb, droit, aps,
# Nearest to bible: diced, gospel, anointed, masjid, doctrines, kissinger, enslaved, astronomers,
# Nearest to test: alcindor, prix, officialdom, sets, satirizes, bovine, annihilate, cocker,
# Nearest to engine: mainframe, delay, subfield, matter, hispanics, billed, input, sorceress,
# Nearest to articles: tilburg, tips, accurate, signifying, brimstone, un, doers, solano,
# Nearest to instance: belmondo, probability, performed, handel, distributes, code, gagne, scattering,
# Nearest to alternative: decidedly, solutions, theorists, summaries, unnamed, workability, mercenary, characterizing,
# Nearest to consists: copyrighted, pledging, alphabets, ellsworth, vanya, dunbar, baronies, triangular,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4182 0.3848 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4021 0.3814 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4272 0.3807 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4033 0.3811 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4014 0.3799 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4070 0.3804 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3645 0.3811 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3693 0.3804 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4150 0.3772 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3956 0.3806 sec/batch
# Nearest to who: amin, shay, deviated, index, chojn, customizations, houdini, lecturing,
# Nearest to while: puttnam, sad, withdraw, doohan, heaters, werther, stoked, slides,
# Nearest to from: serbian, turbojet, declares, tomahawk, sebastien, duties, recordable, sparsely,
# Nearest to into: blok, schillinger, escapees, bcnf, approximately, kreuzberg, discernible, atp,
# Nearest to as: understood, an, markus, whispers, tile, distro, small, mmu,
# Nearest to during: hotdog, flotilla, floated, perinatal, antithesis, stamper, freire, isdb,
# Nearest to also: insular, characterise, sonny, grammer, foregoing, founds, more, constructs,
# Nearest to its: buffs, nq, materialism, necessarily, polluted, technological, proliferation, haunt,
# Nearest to shows: can, astronomia, herbivorous, chlorophyll, nuke, aps, lipscomb, morons,
# Nearest to bible: gospel, diced, doctrines, anointed, masjid, teachings, sins, orthodox,
# Nearest to test: alcindor, prix, officialdom, sets, satirizes, bovine, instep, robison,
# Nearest to engine: mainframe, delay, input, subfield, matter, inadvertent, stopwatch, scribes,
# Nearest to articles: tilburg, doers, accurate, signifying, tips, theoretic, newsted, bara,
# Nearest to instance: probability, belmondo, curves, code, performed, scattering, workflow, distributes,
# Nearest to alternative: solutions, decidedly, theorists, characterizing, summaries, workability, explore, unnamed,
# Nearest to consists: copyrighted, alphabets, pledging, vanya, triangular, ellsworth, baronies, amplifiers,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3507 0.3857 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3621 0.3801 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3578 0.3797 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3484 0.3820 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3941 0.3829 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3496 0.3819 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3619 0.3788 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3795 0.3800 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3115 0.3811 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3409 0.3784 sec/batch
# Nearest to who: amin, fanshawe, decreed, customizations, shay, houdini, deviated, manifest,
# Nearest to while: withdraw, sad, doohan, puttnam, werther, dominions, slides, stoked,
# Nearest to from: serbian, tomahawk, turbojet, country, sparsely, declares, norah, screening,
# Nearest to into: blok, kreuzberg, schillinger, bcnf, eris, approximately, discernible, surrender,
# Nearest to as: understood, whispers, an, markus, rosary, tile, distro, necklace,
# Nearest to during: flotilla, floated, perinatal, hotdog, stamper, freire, isdb, attributing,
# Nearest to also: insular, graphite, more, mailing, foregoing, interactive, grammer, sonny,
# Nearest to its: nq, buffs, hoche, materialism, necessarily, polluted, partisan, proliferation,
# Nearest to shows: can, astronomia, herbivorous, nuke, chlorophyll, aps, morons, lipscomb,
# Nearest to bible: gospel, diced, teachings, anointed, doctrines, masjid, sins, orthodox,
# Nearest to test: alcindor, prix, satirizes, sets, officialdom, transmissive, instep, guggenheim,
# Nearest to engine: mainframe, delay, cylinder, input, engines, inadvertent, bearings, carelessly,
# Nearest to articles: tilburg, doers, tips, accurate, signifying, bara, newsted, crist,
# Nearest to instance: probability, belmondo, glorified, curves, code, handel, distributes, miscegenation,
# Nearest to alternative: solutions, theorists, decidedly, characterizing, workability, summaries, cabins, explore,
# Nearest to consists: alphabets, copyrighted, pledging, vanya, triangular, representation, baronies, amplifiers,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3428 0.3856 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2762 0.3812 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3596 0.3798 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3709 0.3800 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3764 0.3823 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2826 0.3824 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3225 0.3800 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3073 0.3802 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2118 0.3813 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3056 0.3821 sec/batch
# Nearest to who: amin, manifest, houdini, fanshawe, chojn, deviated, customizations, decreed,
# Nearest to while: withdraw, werther, dominions, doohan, sad, dampen, brooklynites, puttnam,
# Nearest to from: serbian, tomahawk, sparsely, country, declares, turbojet, norah, adware,
# Nearest to into: blok, kreuzberg, schillinger, bcnf, eris, escapees, surrender, approximately,
# Nearest to as: understood, an, rosary, chocolates, distro, whispers, markus, necklace,
# Nearest to during: flotilla, perinatal, hotdog, floated, attributing, freire, isdb, stamper,
# Nearest to also: insular, graphite, praia, more, founds, primed, sonny, grammer,
# Nearest to its: buffs, nq, hoche, polluted, materialism, proliferation, necessarily, technological,
# Nearest to shows: astronomia, can, herbivorous, aps, nuke, chlorophyll, lipscomb, maturity,
# Nearest to bible: gospel, teachings, diced, doctrines, anointed, masjid, mishnah, enslaved,
# Nearest to test: alcindor, transmissive, prix, officialdom, bovine, satirizes, robison, instep,
# Nearest to engine: mainframe, delay, engines, cylinder, bearings, inadvertent, input, rpm,
# Nearest to articles: doers, tilburg, tips, signifying, bara, accurate, solano, crist,
# Nearest to instance: probability, belmondo, curves, miscegenation, protea, indispensable, distributes, code,
# Nearest to alternative: solutions, theorists, workability, decidedly, characterizing, summaries, cabins, interrelated,
# Nearest to consists: alphabets, pledging, vanya, copyrighted, neutralist, representation, dunbar, baronies,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3018 0.3855 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2573 0.3796 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3647 0.1448 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2332 0.3797 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2258 0.3830 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1851 0.3811 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2315 0.3809 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2100 0.3796 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1858 0.3798 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1877 0.3839 sec/batch
# Nearest to who: manifest, amin, houdini, fanshawe, customizations, heavens, chojn, realm,
# Nearest to while: withdraw, sad, werther, doohan, dampen, dominions, lpga, thanks,
# Nearest to from: serbian, sparsely, declares, tomahawk, norah, adware, country, turbojet,
# Nearest to into: blok, schillinger, escapees, bcnf, discernible, eris, surrender, kreuzberg,
# Nearest to as: understood, distro, an, markus, rosary, chocolates, webcomic, necklace,
# Nearest to during: flotilla, floated, perinatal, hotdog, freire, favre, tibeto, hispania,
# Nearest to also: insular, grammer, mailing, graphite, moderne, founds, sonny, saffron,
# Nearest to its: polluted, buffs, nq, hoche, cashmere, materialism, motorways, weser,
# Nearest to shows: astronomia, morons, chlorophyll, aps, herbivorous, lipscomb, famed, runners,
# Nearest to bible: gospel, diced, teachings, anointed, doctrines, masjid, creeds, milestone,
# Nearest to test: alcindor, prix, transmissive, bovine, officialdom, sets, guggenheim, satirizes,
# Nearest to engine: mainframe, cylinder, engines, delay, bearings, inadvertent, iptv, rpm,
# Nearest to articles: doers, tilburg, signifying, tips, crist, bara, accurate, theoretic,
# Nearest to instance: probability, belmondo, bitstream, scattering, code, distributes, protea, workflow,
# Nearest to alternative: solutions, theorists, workability, interrelated, decidedly, explore, summaries, waleed,
# Nearest to consists: alphabets, pledging, vanya, copyrighted, representation, neutralist, surveying, dunbar,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2324 0.3877 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2072 0.3813 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2038 0.3799 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1330 0.3832 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1620 0.3810 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1344 0.3821 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1393 0.3827 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1517 0.3834 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1787 0.3818 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1560 0.3806 sec/batch
# Nearest to who: manifest, houdini, deviated, customizations, yorke, fanshawe, amin, dojos,
# Nearest to while: withdraw, sad, werther, dampen, doohan, slides, dominions, heaters,
# Nearest to from: tomahawk, sparsely, norah, recordable, adware, scaling, dak, turbojet,
# Nearest to into: blok, bcnf, discernible, schillinger, eris, escapees, kreuzberg, unregistered,
# Nearest to as: understood, an, distro, rosary, small, tile, markus, mmu,
# Nearest to during: flotilla, perinatal, floated, freire, hotdog, favre, enormous, stamper,
# Nearest to also: insular, mailing, more, graphite, praia, grammer, hexafluoride, middlesex,
# Nearest to its: polluted, nq, hoche, buffs, subtypes, necessarily, cashmere, some,
# Nearest to shows: astronomia, herbivorous, chlorophyll, aps, binky, overwrite, can, famed,
# Nearest to bible: gospel, diced, teachings, anointed, doctrines, masjid, creeds, mishnah,
# Nearest to test: alcindor, prix, transmissive, bovine, officialdom, hazardous, horizontally, guggenheim,
# Nearest to engine: mainframe, cylinder, engines, delay, bearings, rpm, stroke, iptv,
# Nearest to articles: doers, tilburg, crist, signifying, accurate, tips, theoretic, bara,
# Nearest to instance: probability, belmondo, code, bitstream, distributes, indispensable, scattering, protea,
# Nearest to alternative: theorists, solutions, workability, interrelated, explore, decidedly, summaries, waleed,
# Nearest to consists: alphabets, representation, pledging, copyrighted, neutralist, vanya, triangular, surveying,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1604 0.3861 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2128 0.3812 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1599 0.3797 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1634 0.3813 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1552 0.3816 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1768 0.3787 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1755 0.3806 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1150 0.3823 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1481 0.3812 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1495 0.3786 sec/batch
# Nearest to who: manifest, houdini, fanshawe, reporter, yorke, husband, realm, customizations,
# Nearest to while: withdraw, doohan, werther, slides, thanks, sad, puttnam, dominions,
# Nearest to from: tomahawk, dak, adware, sparsely, norah, recordable, scaling, toot,
# Nearest to into: kreuzberg, eris, bcnf, discernible, blok, xb, approximately, didi,
# Nearest to as: understood, rosary, an, distro, hyperactivity, majorca, tile, chocolates,
# Nearest to during: flotilla, perinatal, floated, hotdog, favre, enormous, freire, stamper,
# Nearest to also: insular, graphite, mailing, more, product, praia, sections, mobygames,
# Nearest to its: polluted, hoche, buffs, cashmere, nq, necessarily, technological, functionally,
# Nearest to shows: astronomia, herbivorous, happy, famed, mutharika, chlorophyll, binky, explicit,
# Nearest to bible: gospel, diced, mishnah, teachings, anointed, creeds, doctrines, masjid,
# Nearest to test: alcindor, transmissive, prix, hazardous, bovine, horizontally, officialdom, mascots,
# Nearest to engine: mainframe, engines, cylinder, delay, rpm, stopwatch, stroke, ds,
# Nearest to articles: tips, doers, tilburg, crist, accurate, theoretic, signifying, bara,
# Nearest to instance: probability, belmondo, bitstream, distributes, code, miscegenation, overlay, representing,
# Nearest to alternative: solutions, theorists, workability, interrelated, explore, decidedly, cabins, characterizing,
# Nearest to consists: alphabets, representation, copyrighted, pledging, neutralist, vanya, triangular, dummar,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1592 0.3847 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1775 0.3823 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1598 0.3823 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1828 0.3812 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1224 0.3789 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0902 0.3815 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1536 0.3787 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1171 0.3790 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1898 0.3840 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2174 0.3793 sec/batch
# Nearest to who: manifest, houdini, yorke, fanshawe, husband, reporter, decreed, amin,
# Nearest to while: withdraw, doohan, dominions, werther, sad, stoked, brooklynites, puttnam,
# Nearest to from: tomahawk, serbian, declares, asenath, sparsely, norah, duties, adware,
# Nearest to into: eris, kreuzberg, surrender, discernible, wavered, blok, escapees, consuls,
# Nearest to as: an, rosary, understood, markus, chocolates, wiik, mansi, distro,
# Nearest to during: flotilla, floated, perinatal, favre, hispania, dishonest, early, externalized,
# Nearest to also: insular, praia, graphite, more, mailing, founds, middlesex, mobygames,
# Nearest to its: hoche, buffs, polluted, nq, kau, weser, partisan, inglewood,
# Nearest to shows: herbivorous, astronomia, happy, famed, mutharika, explicit, overwrite, lipscomb,
# Nearest to bible: gospel, mishnah, anointed, diced, essene, teachings, masjid, yeshiva,
# Nearest to test: transmissive, alcindor, prix, bovine, hazardous, officialdom, guggenheim, penniless,
# Nearest to engine: mainframe, engines, cylinder, stroke, stopwatch, delay, rpm, gasoline,
# Nearest to articles: doers, tips, tilburg, crist, signifying, bara, vo, newsted,
# Nearest to instance: probability, belmondo, miscegenation, bitstream, hindustani, overlay, representing, protea,
# Nearest to alternative: solutions, theorists, workability, explore, interrelated, cabins, waleed, characterizing,
# Nearest to consists: alphabets, representation, pledging, neutralist, copyrighted, vanya, surveying, triangular,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1904 0.3842 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0932 0.3804 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1033 0.3811 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1216 0.3847 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0476 0.3792 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1148 0.3812 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1179 0.3813 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1057 0.3834 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1516 0.0267 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1262 0.3835 sec/batch
# Nearest to who: manifest, houdini, fanshawe, deviated, husband, reporter, yorke, amin,
# Nearest to while: withdraw, werther, doohan, sad, dominions, slides, dampen, thanks,
# Nearest to from: tomahawk, dak, sparsely, adware, recordable, herold, norah, declares,
# Nearest to into: eris, kreuzberg, discernible, surrender, bcnf, wavered, bisects, unregistered,
# Nearest to as: an, understood, chocolates, rosary, small, distro, shf, markus,
# Nearest to during: flotilla, floated, perinatal, favre, early, stamper, hispania, paganism,
# Nearest to also: insular, mobygames, praia, graphite, mailing, grammer, product, more,
# Nearest to its: polluted, buffs, hoche, inglewood, technological, unevenly, cashmere, nq,
# Nearest to shows: herbivorous, astronomia, happy, explicit, overwrite, aps, chlorophyll, famed,
# Nearest to bible: gospel, mishnah, essene, yeshiva, diced, teachings, tanakh, anointed,
# Nearest to test: transmissive, prix, hazardous, alcindor, bovine, officialdom, desertification, penniless,
# Nearest to engine: mainframe, engines, cylinder, stopwatch, rpm, stroke, bhp, gasoline,
# Nearest to articles: doers, crist, tips, newsted, signifying, tilburg, vo, yahoo,
# Nearest to instance: bitstream, probability, belmondo, code, protea, hindustani, representing, miscegenation,
# Nearest to alternative: solutions, theorists, workability, interrelated, explore, characterizing, waleed, invalidate,
# Nearest to consists: representation, alphabets, pledging, neutralist, surveying, vanya, dummar, copyrighted,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0405 0.3899 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0636 0.3781 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0772 0.3809 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0146 0.3821 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0267 0.3826 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9994 0.3782 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0634 0.3813 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0770 0.3811 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0592 0.3828 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0499 0.3782 sec/batch
# Nearest to who: manifest, houdini, yorke, husband, deviated, amin, realm, fanshawe,
# Nearest to while: withdraw, werther, sad, doohan, thanks, dampen, slides, dominions,
# Nearest to from: sparsely, declares, herold, dak, adware, tomahawk, recordable, enforces,
# Nearest to into: eris, kreuzberg, discernible, bcnf, surrender, unregistered, stool, lith,
# Nearest to as: an, understood, chocolates, rosary, markus, small, webcomic, the,
# Nearest to during: flotilla, floated, perinatal, early, hotdog, hispania, favre, enormous,
# Nearest to also: insular, mobygames, grammer, graphite, carbonated, more, product, teotihuacan,
# Nearest to its: polluted, inglewood, nq, some, from, cashmere, technological, sudski,
# Nearest to shows: herbivorous, astronomia, aps, famed, happy, overwrite, explicit, chlorophyll,
# Nearest to bible: gospel, tanakh, anointed, mishnah, essene, book, yeshiva, teachings,
# Nearest to test: transmissive, prix, alcindor, hazardous, bovine, officialdom, helton, lege,
# Nearest to engine: mainframe, engines, cylinder, stopwatch, bhp, powerplant, rpm, stroke,
# Nearest to articles: crist, doers, tilburg, tips, signifying, newsted, endl, vo,
# Nearest to instance: bitstream, probability, code, belmondo, hindustani, protea, representing, overlay,
# Nearest to alternative: solutions, theorists, workability, interrelated, explore, invalidate, characterizing, waleed,
# Nearest to consists: representation, alphabets, pledging, neutralist, vested, dummar, copyrighted, entities,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9852 0.3877 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9846 0.3836 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9816 0.3781 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0180 0.3809 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0220 0.3830 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0180 0.3819 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0207 0.3797 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0534 0.3809 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0556 0.3797 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0036 0.3828 sec/batch
# Nearest to who: manifest, houdini, yorke, husband, deviated, reporter, fanshawe, customizations,
# Nearest to while: withdraw, doohan, werther, puttnam, identifying, thanks, sad, slides,
# Nearest to from: sparsely, tomahawk, dak, herold, adware, scaling, recordable, declares,
# Nearest to into: eris, discernible, kreuzberg, bcnf, xb, stool, booms, bisects,
# Nearest to as: an, understood, chocolates, small, threaded, rosary, berries, the,
# Nearest to during: flotilla, floated, perinatal, early, favre, traces, externalized, hotdog,
# Nearest to also: insular, mobygames, graphite, more, grammer, praia, product, te,
# Nearest to its: polluted, functionally, some, unevenly, it, hoche, epistemological, implies,
# Nearest to shows: herbivorous, explicit, happy, overwrite, astronomia, famed, chlorophyll, aps,
# Nearest to bible: gospel, yeshiva, mishnah, essene, diced, anointed, tanakh, revised,
# Nearest to test: transmissive, prix, hazardous, alcindor, officialdom, bovine, sheppard, lege,
# Nearest to engine: engines, mainframe, cylinder, powerplant, stroke, bhp, stopwatch, gasoline,
# Nearest to articles: doers, tips, crist, tilburg, signifying, newsted, theoretic, bara,
# Nearest to instance: belmondo, bitstream, hindustani, probability, protea, code, representing, stylish,
# Nearest to alternative: solutions, theorists, workability, explore, interrelated, invalidate, characterizing, syndrome,
# Nearest to consists: representation, alphabets, pledging, neutralist, vested, dummar, vestalia, administratively,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0295 0.3848 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0541 0.3831 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0492 0.3820 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0226 0.3810 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0451 0.3821 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0078 0.3811 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0106 0.3842 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0677 0.3797 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0574 0.3810 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0471 0.3825 sec/batch
# Nearest to who: manifest, houdini, yorke, fanshawe, husband, avoided, deviated, reporter,
# Nearest to while: withdraw, doohan, dominions, thanks, puttnam, werther, stoked, brooklynites,
# Nearest to from: sparsely, tomahawk, herold, asenath, dak, adware, norah, in,
# Nearest to into: eris, kreuzberg, discernible, wavered, surrender, bcnf, xb, resolving,
# Nearest to as: an, rosary, understood, chocolates, wiik, albinus, conditionals, threaded,
# Nearest to during: flotilla, early, floated, disciplining, externalized, hispania, favre, perinatal,
# Nearest to also: graphite, mobygames, insular, product, more, praia, carbonated, grammer,
# Nearest to its: polluted, some, functionally, epistemological, hoche, partisan, sudski, has,
# Nearest to shows: herbivorous, explicit, overwrite, astronomia, aps, happy, famed, chlorophyll,
# Nearest to bible: gospel, mishnah, tanakh, yeshiva, nrsv, essene, anointed, milestone,
# Nearest to test: transmissive, hazardous, prix, alcindor, bovine, lege, sheppard, dumping,
# Nearest to engine: mainframe, engines, cylinder, bhp, stopwatch, powerplant, stroke, rpm,
# Nearest to articles: tips, doers, crist, tilburg, newsted, com, signifying, yahoo,
# Nearest to instance: hindustani, belmondo, protea, bitstream, tribulations, stylish, probability, code,
# Nearest to alternative: solutions, theorists, workability, explore, interrelated, invalidate, characterizing, syndrome,
# Nearest to consists: representation, alphabets, vested, pledging, neutralist, ilyas, riverfront, vestalia,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0087 0.3874 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9617 0.3791 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9722 0.3815 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0602 0.3801 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0256 0.3827 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1232 0.3817 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0790 0.3834 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0520 0.3825 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9679 0.3791 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0056 0.3811 sec/batch
# Nearest to who: manifest, yorke, fanshawe, deviated, houdini, secedes, husband, presbyterianism,
# Nearest to while: withdraw, doohan, stoked, werther, brooklynites, dominions, dampen, puttnam,
# Nearest to from: tomahawk, dak, sparsely, asenath, herold, norah, in, israelites,
# Nearest to into: eris, kreuzberg, surrender, discernible, bcnf, xb, wavered, bodyline,
# Nearest to as: an, understood, chocolates, rosary, mansi, touman, markus, threaded,
# Nearest to during: flotilla, early, floated, perinatal, favre, externalized, hispania, disciplining,
# Nearest to also: insular, mobygames, graphite, praia, founds, grammer, product, moderne,
# Nearest to its: polluted, functionally, sudski, kau, inglewood, unevenly, saraswati, hoche,
# Nearest to shows: herbivorous, explicit, aps, chlorophyll, happy, astronomia, overwrite, shown,
# Nearest to bible: gospel, milestone, mishnah, yeshiva, essene, tanakh, asatru, nrsv,
# Nearest to test: hazardous, transmissive, prix, desertification, dumping, alcindor, lege, bovine,
# Nearest to engine: engines, mainframe, cylinder, bhp, stopwatch, stroke, powerplant, rpm,
# Nearest to articles: crist, doers, tips, tilburg, signifying, com, keres, newsted,
# Nearest to instance: hindustani, protea, bitstream, belmondo, code, stylish, representing, probability,
# Nearest to alternative: solutions, theorists, workability, interrelated, explore, invalidate, characterizing, syndrome,
# Nearest to consists: representation, alphabets, vested, pledging, neutralist, unicameral, ilyas, modulations,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9988 0.3867 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9677 0.3829 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0097 0.3793 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9726 0.3828 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0172 0.3801 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0106 0.2879 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9704 0.3803 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9529 0.3819 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9682 0.3822 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9224 0.3785 sec/batch
# Nearest to who: manifest, yorke, fanshawe, husband, amaury, houdini, deviated, married,
# Nearest to while: withdraw, stoked, werther, teleoperation, doohan, brooklynites, kouchner, thanks,
# Nearest to from: sparsely, tomahawk, dak, adware, tanna, herold, asenath, its,
# Nearest to into: eris, discernible, bcnf, surrender, lith, xb, aphrodite, kreuzberg,
# Nearest to as: understood, rosary, an, chocolates, touman, mansi, wiik, markus,
# Nearest to during: early, flotilla, floated, favre, perinatal, externalized, disciplining, hispania,
# Nearest to also: graphite, insular, mobygames, product, praia, moderne, grammer, more,
# Nearest to its: polluted, from, functionally, plumes, saraswati, beretta, second, epistemological,
# Nearest to shows: herbivorous, explicit, aps, chlorophyll, overwrite, happy, suffect, mutharika,
# Nearest to bible: gospel, mishnah, milestone, essene, tanakh, nrsv, yeshiva, anointed,
# Nearest to test: transmissive, hazardous, prix, dumping, desertification, alcindor, okinawa, lege,
# Nearest to engine: engines, mainframe, cylinder, bhp, stopwatch, stroke, powerplant, petrol,
# Nearest to articles: crist, doers, tips, tilburg, signifying, endl, keres, solano,
# Nearest to instance: protea, belmondo, bitstream, stylish, hindustani, code, representing, vanquish,
# Nearest to alternative: solutions, theorists, workability, syndrome, invalidate, interrelated, explore, characterizing,
# Nearest to consists: representation, vested, pledging, unicameral, alphabets, chamber, neutralist, ilyas,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9490 0.3867 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8762 0.3788 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0199 0.3815 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9702 0.3794 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9642 0.3819 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9501 0.3818 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8709 0.3805 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9205 0.3808 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8836 0.3812 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9150 0.3832 sec/batch
# Nearest to who: manifest, husband, yorke, houdini, deviated, fanshawe, reporter, married,
# Nearest to while: withdraw, werther, teleoperation, identifying, stoked, slides, thanks, strong,
# Nearest to from: sparsely, adware, in, tomahawk, dak, tanna, recordable, its,
# Nearest to into: eris, bcnf, surrender, discernible, rise, booms, xb, stool,
# Nearest to as: an, understood, chocolates, rosary, berries, uncommon, markus, touman,
# Nearest to during: early, floated, flotilla, perinatal, favre, externalized, retrofit, carbines,
# Nearest to also: graphite, product, insular, mobygames, praia, more, wellness, hexafluoride,
# Nearest to its: polluted, club, from, saraswati, inglewood, in, functionally, plumes,
# Nearest to shows: herbivorous, explicit, chlorophyll, overwrite, binky, obvious, shown, aps,
# Nearest to bible: gospel, milestone, mishnah, yeshiva, sardonic, revised, nrsv, essene,
# Nearest to test: hazardous, transmissive, dumping, prix, desertification, okinawa, lege, alcindor,
# Nearest to engine: mainframe, engines, cylinder, bhp, stopwatch, stroke, powerplant, petrol,
# Nearest to articles: crist, tips, doers, tilburg, signifying, com, keres, accurate,
# Nearest to instance: protea, hindustani, belmondo, stylish, bitstream, representing, code, tribulations,
# Nearest to alternative: theorists, solutions, invalidate, interrelated, syndrome, explore, workability, langston,
# Nearest to consists: representation, vested, chamber, unicameral, pledging, entities, alphabets, evaporates,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9338 0.3863 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9737 0.3784 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9170 0.3799 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9510 0.3841 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0134 0.3799 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9112 0.3828 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9293 0.3803 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9712 0.3793 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9272 0.3809 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9560 0.3822 sec/batch
# Nearest to who: manifest, yorke, husband, fanshawe, presbyterianism, houdini, married, reporter,
# Nearest to while: withdraw, stoked, thanks, identifying, slides, rectangular, doohan, werther,
# Nearest to from: tomahawk, in, dak, sparsely, norah, adware, herold, recordable,
# Nearest to into: eris, discernible, bcnf, xb, kreuzberg, booms, surrender, stool,
# Nearest to as: an, understood, rosary, chocolates, foundries, markus, distro, passports,
# Nearest to during: early, floated, favre, flotilla, externalized, perinatal, era, retrofit,
# Nearest to also: mobygames, product, graphite, grammer, moderne, insular, praia, carbonated,
# Nearest to its: polluted, club, in, functionally, beretta, sudski, from, inglewood,
# Nearest to shows: herbivorous, explicit, shown, overwrite, binky, chlorophyll, obvious, mutharika,
# Nearest to bible: gospel, yeshiva, milestone, mishnah, essene, revised, nrsv, sardonic,
# Nearest to test: hazardous, transmissive, dumping, prix, desertification, lege, cosets, invoked,
# Nearest to engine: engines, mainframe, cylinder, bhp, stroke, stopwatch, petrol, powerplant,
# Nearest to articles: tips, crist, tilburg, com, yahoo, doers, signifying, accurate,
# Nearest to instance: protea, hindustani, belmondo, stylish, bitstream, representing, vanquish, inscrutable,
# Nearest to alternative: solutions, theorists, invalidate, interrelated, workability, syndrome, explore, cabins,
# Nearest to consists: representation, chamber, vested, unicameral, evaporates, pledging, ceremonial, abaddon,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9821 0.3873 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9571 0.3811 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9353 0.3801 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0052 0.3796 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9209 0.3811 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9528 0.3795 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9603 0.3815 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9282 0.3801 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9239 0.3805 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9393 0.3808 sec/batch
# Nearest to who: manifest, yorke, presbyterianism, husband, fanshawe, deviated, reporter, amaury,
# Nearest to while: withdraw, stoked, identifying, strong, thanks, lpga, werther, slides,
# Nearest to from: in, tomahawk, sparsely, dak, its, adware, and, the,
# Nearest to into: eris, surrender, bcnf, rise, kreuzberg, wavered, discernible, resolving,
# Nearest to as: an, understood, rosary, chocolates, the, touman, other, polypeptides,
# Nearest to during: early, flotilla, favre, floated, externalized, disciplining, era, perinatal,
# Nearest to also: mobygames, product, graphite, praia, grammer, insular, shamans, moderne,
# Nearest to its: it, in, has, polluted, functionally, from, epistemological, implies,
# Nearest to shows: herbivorous, explicit, aps, suffect, overwrite, events, binky, mutharika,
# ...
# Nearest to who: husband, married, fanshawe, together, diphosphate, they, yorke, householder,
# Nearest to while: identifying, and, have, edouard, stoked, mostly, withdraw, strong,
# Nearest to from: the, in, its, of, and, times, to, as,
# Nearest to into: antioxidants, rise, williamson, newly, sra, by, wavered, achaean,
# Nearest to as: the, to, often, other, an, including, for, in,
# Nearest to during: early, time, era, fleur, overflow, increased, decades, avocats,
# Nearest to also: mobygames, and, external, several, the, as, is, such,
# Nearest to its: in, from, the, is, has, it, of, with,
# Nearest to shows: suffect, show, shown, theater, obvious, iconoclasm, explicit, draws,
# Nearest to bible: permissions, sprinkling, milestone, passages, contents, effects, revised, fakes,
# Nearest to test: tests, dumping, hazardous, desertification, shri, mcc, fia, australia,
# Nearest to engine: engines, stroke, cylinder, mainframe, bhp, supercharger, stopwatch, turboprops,
# Nearest to articles: tilburg, crist, tips, websites, encyclopedias, sardis, com, doers,
# Nearest to instance: quotients, cana, stylish, overlay, inverse, extensionality, representing, tribulations,
# Nearest to alternative: solutions, invalidate, syndrome, langston, theorists, herc, cabins, auckland,
# Nearest to consists: representation, composed, serve, vestalia, executive, entities, wishart, chamber,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8162 0.3823 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7639 0.3763 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7602 0.3779 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8054 0.3790 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8653 0.3776 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.7691 0.3771 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7776 0.3778 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7812 0.3770 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8204 0.3772 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8118 0.3774 sec/batch
# Nearest to who: husband, together, fanshawe, diphosphate, married, avoided, yorke, was,
# Nearest to while: and, withdraw, stoked, identifying, mostly, strong, edouard, have,
# Nearest to from: the, in, of, and, its, to, times, between,
# Nearest to into: williamson, newly, antioxidants, atat, achaean, rise, the, by,
# Nearest to as: the, an, other, and, often, to, of, including,
# Nearest to during: early, time, era, flotilla, the, fleur, disciplining, increased,
# Nearest to also: and, mobygames, the, external, several, with, is, as,
# Nearest to its: in, the, from, is, has, of, to, with,
# Nearest to shows: suffect, show, shown, theater, iconoclasm, overwrite, obvious, explicit,
# Nearest to bible: permissions, milestone, passages, sprinkling, contents, above, doug, outgassing,
# Nearest to test: tests, hazardous, dumping, desertification, shri, cosets, mcc, fia,
# Nearest to engine: engines, cylinder, stroke, mainframe, bhp, supercharger, turboprops, stopwatch,
# Nearest to articles: tilburg, encyclopedias, tips, websites, com, crist, haag, lists,
# Nearest to instance: cana, quotients, stylish, overlay, inverse, tribulations, representing, protea,
# Nearest to alternative: solutions, invalidate, syndrome, langston, cabins, associated, theorists, herc,
# Nearest to consists: representation, serve, vestalia, composed, executive, entities, wishart, gunships,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7832 0.3817 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8299 0.3762 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7772 0.3773 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7460 0.3752 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8017 0.3771 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7832 0.3768 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.8776 0.3772 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8951 0.3780 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8540 0.3762 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7964 0.3768 sec/batch
# Nearest to who: husband, was, fanshawe, together, out, yorke, married, they,
# Nearest to while: and, stoked, mostly, withdraw, edouard, have, but, woolton,
# Nearest to from: in, the, and, of, its, to, times, as,
# Nearest to into: williamson, newly, by, atat, rise, antioxidants, rhetorically, achaean,
# Nearest to as: the, an, including, to, of, and, often, other,
# Nearest to during: early, time, the, era, increased, in, decades, flotilla,
# Nearest to also: and, external, the, mobygames, several, is, with, such,
# Nearest to its: the, in, from, is, has, to, with, of,
# Nearest to shows: suffect, theater, show, iconoclasm, shown, reunion, obvious, explicit,
# Nearest to bible: permissions, milestone, effects, sprinkling, above, contents, fakes, doug,
# Nearest to test: tests, dumping, hazardous, desertification, mcc, shri, cosets, lege,
# Nearest to engine: stroke, engines, cylinder, mainframe, bhp, supercharger, turboprops, stopwatch,
# Nearest to articles: tilburg, encyclopedias, haag, crist, com, tips, websites, lists,
# Nearest to instance: cana, stylish, quotients, overlay, inverse, protea, vanquish, hindustani,
# Nearest to alternative: solutions, invalidate, syndrome, langston, cabins, homeless, theorists, auckland,
# Nearest to consists: serve, vestalia, representation, composed, executive, entities, wishart, chamber,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7629 0.3813 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7922 0.3766 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.6959 0.3766 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8402 0.3782 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7854 0.3784 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7831 0.3776 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8514 0.0796 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8226 0.3762 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7908 0.3772 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8073 0.3777 sec/batch
# Nearest to who: husband, married, together, them, they, yorke, was, fanshawe,
# Nearest to while: and, stoked, mostly, edouard, have, but, identifying, withdraw,
# Nearest to from: in, of, the, and, its, to, as, when,
# Nearest to into: newly, williamson, antioxidants, by, achaean, rise, ronin, paragraphs,
# Nearest to as: the, of, to, an, in, including, and, other,
# Nearest to during: early, time, era, the, overflow, fleur, flotilla, disciplining,
# Nearest to also: and, the, is, several, external, mobygames, such, as,
# Nearest to its: the, in, from, is, has, it, part, with,
# Nearest to shows: suffect, show, theater, iconoclasm, shown, obvious, overwrite, reunion,
# Nearest to bible: milestone, permissions, sprinkling, passages, contents, above, fakes, effects,
# Nearest to test: tests, dumping, hazardous, launches, shri, mcc, fia, desertification,
# Nearest to engine: stroke, cylinder, engines, mainframe, supercharger, bhp, turboprops, stopwatch,
# Nearest to articles: tilburg, encyclopedias, crist, haag, sardis, com, doers, websites,
# Nearest to instance: stylish, cana, quotients, overlay, inverse, rearranging, protea, dough,
# Nearest to alternative: invalidate, solutions, syndrome, langston, cabins, homeless, auckland, theorists,
# Nearest to consists: serve, composed, executive, vestalia, representation, entities, wishart, vested,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7980 0.3824 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7513 0.3776 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7778 0.3767 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7404 0.3771 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8016 0.3762 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7866 0.3778 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8275 0.3768 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7068 0.3776 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.6996 0.3775 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7368 0.3772 sec/batch
# Nearest to who: husband, together, or, they, diphosphate, householder, married, yorke,
# Nearest to while: and, mostly, have, identifying, but, stoked, other, strong,
# Nearest to from: in, and, of, the, its, to, as, that,
# Nearest to into: antioxidants, newly, by, williamson, rise, and, paragraphs, sra,
# Nearest to as: the, to, and, of, an, other, often, for,
# Nearest to during: early, time, era, the, overflow, increased, fleur, this,
# Nearest to also: and, the, is, external, several, as, a, such,
# Nearest to its: the, in, from, is, it, to, of, which,
# Nearest to shows: suffect, show, theater, iconoclasm, shown, obvious, superfamily, overwrite,
# Nearest to bible: biblical, above, permissions, sprinkling, passages, contents, antidisestablishmentarianism, tanakh,
# Nearest to test: tests, hazardous, dumping, mcc, shri, desertification, launches, fia,
# Nearest to engine: stroke, engines, cylinder, mainframe, supercharger, bhp, turboprops, petrol,
# Nearest to articles: tilburg, encyclopedias, crist, haag, websites, com, accurate, carbonates,
# Nearest to instance: stylish, cana, quotients, overlay, representing, protea, inverse, rearranging,
# Nearest to alternative: solutions, invalidate, syndrome, cabins, auckland, langston, homeless, belated,
# Nearest to consists: composed, serve, vestalia, executive, representation, entities, wishart, appointed,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6825 0.3807 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7436 0.3771 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7705 0.3780 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7574 0.3766 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7735 0.3767 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.7944 0.3768 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7741 0.3775 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7715 0.3764 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7590 0.3763 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7872 0.3766 sec/batch
# Nearest to who: husband, together, they, diphosphate, married, or, householder, yorke,
# Nearest to while: and, mostly, stoked, but, have, identifying, other, strong,
# Nearest to from: in, and, the, of, its, to, that, times,
# Nearest to into: newly, antioxidants, williamson, by, and, the, paragraphs, rise,
# Nearest to as: the, to, an, other, and, in, often, a,
# Nearest to during: early, time, era, fleur, overflow, this, the, mnp,
# Nearest to also: and, the, is, as, external, several, a, such,
# Nearest to its: in, the, from, is, to, of, has, it,
# Nearest to shows: suffect, show, shown, iconoclasm, theater, this, obvious, presupposes,
# Nearest to bible: permissions, passages, contents, biblical, effects, sprinkling, fakes, milah,
# Nearest to test: tests, hazardous, dumping, mcc, cosets, shri, desertification, fia,
# Nearest to engine: stroke, engines, cylinder, supercharger, mainframe, bhp, turboprops, petrol,
# Nearest to articles: tilburg, encyclopedias, websites, crist, com, accurate, haag, iceland,
# Nearest to instance: stylish, cana, quotients, overlay, representing, dough, inverse, rearranging,
# Nearest to alternative: solutions, invalidate, syndrome, cabins, auckland, belated, theorists, homeless,
# Nearest to consists: composed, serve, vestalia, representation, entities, executive, wishart, chamber,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8195 0.3827 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7556 0.3769 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7845 0.3764 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7903 0.3767 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7644 0.3767 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7941 0.3779 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8117 0.3766 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8083 0.3775 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7719 0.3765 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7286 0.3767 sec/batch
# Nearest to who: husband, together, married, and, they, diphosphate, out, or,
# Nearest to while: and, mostly, identifying, but, other, stoked, have, eldorado,
# Nearest to from: and, the, in, of, to, its, that, when,
# Nearest to into: by, newly, the, antioxidants, and, williamson, paragraphs, atat,
# Nearest to as: the, to, an, of, in, and, other, often,
# Nearest to during: early, time, era, overflow, fleur, flotilla, throughout, roughly,
# Nearest to also: the, and, is, such, several, a, external, as,
# Nearest to its: the, in, is, from, of, to, has, it,
# Nearest to shows: suffect, show, shown, this, theater, iconoclasm, obvious, display,
# Nearest to bible: permissions, luftwaffe, passages, above, biblical, sprinkling, effects, milah,
# Nearest to test: tests, hazardous, dumping, mcc, shri, desertification, fia, launches,
# Nearest to engine: stroke, engines, cylinder, bhp, supercharger, mainframe, turboprops, petrol,
# Nearest to articles: tilburg, encyclopedias, crist, haag, lists, columnists, com, iceland,
# Nearest to instance: cana, stylish, overlay, quotients, representing, inverse, takes, dough,
# Nearest to alternative: solutions, invalidate, cabins, syndrome, earth, belated, homeless, auckland,
# Nearest to consists: composed, vestalia, representation, serve, executive, chamber, entities, wishart,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7496 0.3816 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7991 0.3769 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8580 0.3780 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8814 0.3775 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8613 0.3767 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7866 0.3793 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7413 0.3771 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7629 0.3769 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7156 0.3786 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7886 0.3757 sec/batch
# Nearest to who: husband, together, householder, married, diphosphate, was, they, and,
# Nearest to while: and, mostly, in, but, stoked, have, identifying, other,
# Nearest to from: the, in, and, of, its, to, that, a,
# Nearest to into: the, by, newly, antioxidants, williamson, and, paragraphs, rise,
# Nearest to as: to, the, an, including, and, often, other, in,
# Nearest to during: early, time, the, era, flotilla, this, decades, fleur,
# Nearest to also: the, and, external, a, is, such, several, as,
# Nearest to its: the, in, from, is, of, to, a, has,
# Nearest to shows: suffect, show, theater, shown, this, iconoclasm, obvious, reunion,
# Nearest to bible: biblical, permissions, fakes, luftwaffe, contents, passages, sprinkling, effects,
# Nearest to test: tests, dumping, hazardous, mcc, shri, desertification, fia, launches,
# Nearest to engine: stroke, engines, cylinder, bhp, supercharger, mainframe, turboprops, petrol,
# Nearest to articles: tilburg, encyclopedias, crist, haag, columnists, websites, accurate, com,
# Nearest to instance: stylish, cana, overlay, quotients, inverse, representing, rearranging, dough,
# Nearest to alternative: solutions, invalidate, syndrome, belated, langston, cabins, earth, homeless,
# Nearest to consists: composed, serve, representation, executive, vestalia, appointed, entities, gunships,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8055 0.3820 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7594 0.3769 sec/batch
# Epoch 10/10 Iteration: 46300 Avg. Training loss: 3.8226 0.3776 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
