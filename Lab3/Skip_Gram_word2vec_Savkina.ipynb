# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

# %%
import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

"""if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)"""

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
import re
words = utils.preprocess(text)
#words = re.sub('[^a-z0-9]+', ' ', text.lower()).split()
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

# %%
words_freq = Counter(words)

# %%
## Your code here
from math import sqrt
t = 10**(-6.5) #example
total = len(words)
subs_probs = [1 - sqrt( t / (words_freq[int_to_vocab[i]] / total) ) for i in int_words]
train_words = [int_words[i] for i in range(len(int_words)) if subs_probs[i] <= random.random()]
# The final subsampled word list

# %%
print( min(subs_probs), max(subs_probs), len(train_words))
print( words[subs_probs.index(min(subs_probs))] , words[subs_probs.index(max(subs_probs))])
# Out:
# 0.06237280350942065 0.9977707072802533 1146977
# culottes the

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = random.randint(1, window_size)
    res = words[max(0, idx - r):idx] + [min(len(words) - 1, idx+1):min(len(words), idx + r + 1)]
    return res

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32)
    labels = tf.placeholder(tf.int32, shape=(None, 1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.random_uniform(shape = (n_vocab, n_embedding), minval = -1, maxval = 1) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(params = embedding,  ids = inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random_normal([n_vocab, n_embedding]))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.random_normal([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights = softmax_w, biases = softmax_b, labels = labels, inputs = embed, num_sampled = n_sampled,
                                     num_classes = n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 19.7089 0.8251 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 19.6343 0.7198 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 19.6950 0.6774 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 19.5684 0.6943 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 19.5250 0.7469 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 19.5407 0.7710 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 19.4494 0.6993 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 19.3823 0.7881 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 19.4978 0.8255 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 19.3416 0.7544 sec/batch
# Nearest to new: interleaving, dred, deva, detention, aqdas, guilds, tonk, jammin,
# Nearest to their: reinstatement, exarchate, gilded, overstepped, propraetor, feldspar, forges, drawbridge,
# Nearest to american: row, celebes, ludus, xiao, undertakings, elective, icann, understandings,
# Nearest to about: splitter, grodd, extremadura, mutharika, stagnant, oath, reforestation, animism,
# Nearest to first: affirmative, jose, danson, proportional, langton, suffragan, jutish, sims,
# Nearest to in: fused, aquarists, mueller, baritone, robbers, abounding, reporter, equated,
# Nearest to its: elephantine, plebeians, exeter, degeneres, abstention, airstrip, fool, nasalized,
# Nearest to his: fractional, informed, stromata, receivers, sakae, revisionists, glasnevin, lago,
# Nearest to notes: scsi, baccal, microtubules, mistral, provision, adiabatic, cavalry, adolph,
# Nearest to event: lavin, checksums, cegep, dispensation, milgram, distributism, jus, relaxing,
# Nearest to universe: achiral, bower, institutionalization, maumoon, oxbridge, pelts, acquiesce, uber,
# Nearest to brother: screenwriter, pairs, allyn, lorica, agm, exp, pcd, tokens,
# Nearest to quite: hughie, ifr, brings, masnavi, wm, whorehouse, filo, ein,
# Nearest to animals: sect, pspace, subject, pia, landed, recursion, oversaw, hydrates,
# Nearest to centre: opportunity, array, flirtation, preset, mitnick, upright, cnica, liturgy,
# Nearest to mean: unspectacular, axopods, parabolic, social, legends, pbsuccess, large, lobby,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 19.2244 0.6988 sec/batch
# Epoch 2/10 Iteration: 1200 Avg. Training loss: 19.1979 0.3899 sec/batch
# Epoch 2/10 Iteration: 1300 Avg. Training loss: 19.1703 0.7532 sec/batch
# Epoch 2/10 Iteration: 1400 Avg. Training loss: 19.2244 0.7016 sec/batch
# Epoch 2/10 Iteration: 1500 Avg. Training loss: 19.0847 0.7300 sec/batch
# Epoch 2/10 Iteration: 1600 Avg. Training loss: 19.0820 0.7122 sec/batch
# Epoch 2/10 Iteration: 1700 Avg. Training loss: 19.0509 0.6838 sec/batch
# Epoch 2/10 Iteration: 1800 Avg. Training loss: 18.9918 0.6924 sec/batch
# Epoch 2/10 Iteration: 1900 Avg. Training loss: 19.0229 0.6780 sec/batch
# Epoch 2/10 Iteration: 2000 Avg. Training loss: 19.0108 0.7000 sec/batch
# Nearest to new: mcglynn, condensation, chillout, worshipper, sanity, pai, osamu, clueless,
# Nearest to their: tait, satara, automobile, electoral, coc, alumna, hints, borrowings,
# Nearest to american: shipowners, recreated, infertility, abbreviated, nov, sequencing, diwali, multiverses,
# Nearest to about: decades, stacey, finished, afforded, macgillivray, vito, projecting, pvt,
# Nearest to first: bk, painters, tanoana, bowen, untrained, fulvia, gluck, murakami,
# Nearest to in: discard, ansible, protestant, interferons, praises, curious, planets, html,
# Nearest to its: balkan, contemplating, itinerary, calmed, impoverishment, amf, notch, typecast,
# Nearest to his: reluctant, ghaznavid, roadmap, impi, isaias, zar, torch, carlos,
# Nearest to notes: gathering, enrichment, geospatial, contribute, conceptualize, clockwise, balder, bonetti,
# Nearest to event: niklas, bocce, bacterium, cutha, talleyrand, sacrificial, fleshy, mcgowan,
# Nearest to universe: radiography, puccini, deutschen, tagalog, oriental, dedham, frankston, cartouche,
# Nearest to brother: vse, blisters, sotho, quarreled, asymptotes, foerster, alveoli, hindrance,
# Nearest to quite: irving, game, pilsener, taner, rejecting, xxx, lunatics, loopholes,
# Nearest to animals: gatling, prohibition, newsforge, peasantry, lamellar, curse, shining, scrip,
# Nearest to centre: legendary, hippos, corrosive, foreknowledge, verifies, bradbury, typographical, hickson,
# Nearest to mean: cos, fontane, recipients, pathogenesis, polyvinyl, farnese, metheny, inauthentic,
# Epoch 2/10 Iteration: 2100 Avg. Training loss: 18.9581 0.7179 sec/batch
# Epoch 2/10 Iteration: 2200 Avg. Training loss: 18.9165 0.6758 sec/batch
# Epoch 3/10 Iteration: 2300 Avg. Training loss: 18.8541 0.0586 sec/batch
# Epoch 3/10 Iteration: 2400 Avg. Training loss: 18.7772 0.6882 sec/batch
# Epoch 3/10 Iteration: 2500 Avg. Training loss: 18.8113 0.7036 sec/batch
# Epoch 3/10 Iteration: 2600 Avg. Training loss: 18.8602 0.6860 sec/batch
# Epoch 3/10 Iteration: 2700 Avg. Training loss: 18.8076 0.7153 sec/batch
# Epoch 3/10 Iteration: 2800 Avg. Training loss: 18.7847 0.7060 sec/batch
# Epoch 3/10 Iteration: 2900 Avg. Training loss: 18.7493 0.6907 sec/batch
# Epoch 3/10 Iteration: 3000 Avg. Training loss: 18.6849 0.6977 sec/batch
# Nearest to new: cartman, amartya, superconductivity, neath, kali, brigid, hazmi, barbera,
# Nearest to their: negroponte, nicer, pts, negotiators, ides, ionosphere, contrastive, tropical,
# Nearest to american: lubavitch, zealander, lucid, apologies, goon, tms, cannibal, nausica,
# Nearest to about: tapwave, stimuli, batmobile, gul, biathletes, overblown, nimh, identities,
# Nearest to first: ern, cyclical, raping, unmanned, jambalaya, carnival, bertha, wolfhound,
# Nearest to in: follette, rijmen, shopping, rashtrakutas, zuse, ramp, somewhere, montenegrin,
# Nearest to its: kde, hearings, tuesday, xxviii, aerial, liguria, proscriptions, finlandia,
# Nearest to his: rostra, schillinger, pro, archetype, ghana, nutt, christianised, jubilees,
# Nearest to notes: tolerable, jorge, ending, eminem, laptops, hmg, cumings, cetus,
# Nearest to event: tove, hypothesized, estrogen, apr, exhibit, norma, molarity, canoe,
# Nearest to universe: observatories, ballistics, peseta, angles, acetaminophen, signifies, emrys, manifesting,
# Nearest to brother: serpents, autoroute, diplomat, capability, quail, bactria, maximal, transcends,
# Nearest to quite: trace, deconstructionists, barely, multiparty, hexameter, hansie, sepultura, toni,
# Nearest to animals: arabidopsis, juventus, ncr, watergate, pending, hans, ralf, sideman,
# Nearest to centre: louisbourg, dundurn, chief, volcano, bastions, gracefully, librorum, highbrow,
# Nearest to mean: squads, naqada, toasted, ascended, mesocricetus, bilinear, succulent, ingersoll,
# Epoch 3/10 Iteration: 3100 Avg. Training loss: 18.6573 0.6905 sec/batch
# Epoch 3/10 Iteration: 3200 Avg. Training loss: 18.6770 0.6625 sec/batch
# Epoch 3/10 Iteration: 3300 Avg. Training loss: 18.5596 0.6774 sec/batch
# Epoch 3/10 Iteration: 3400 Avg. Training loss: 18.5550 0.6460 sec/batch
# Epoch 4/10 Iteration: 3500 Avg. Training loss: 18.4469 0.3998 sec/batch
# Epoch 4/10 Iteration: 3600 Avg. Training loss: 18.4890 0.6435 sec/batch
# Epoch 4/10 Iteration: 3700 Avg. Training loss: 18.5245 0.6476 sec/batch
# Epoch 4/10 Iteration: 3800 Avg. Training loss: 18.5261 0.6477 sec/batch
# Epoch 4/10 Iteration: 3900 Avg. Training loss: 18.4067 0.6549 sec/batch
# Epoch 4/10 Iteration: 4000 Avg. Training loss: 18.4314 0.6463 sec/batch
# Nearest to new: overpasses, fannish, lucid, fetish, gonz, reconciled, speedometer, implored,
# Nearest to their: chubut, premarital, hypothermia, simplified, snoop, discount, obituaries, municipally,
# Nearest to american: remit, tetrachloride, incurring, unsubstantiated, shah, dyslexia, kitagawa, sejm,
# Nearest to about: indigenous, restlessness, parsons, responsive, nomads, tissues, celebrating, lindo,
# Nearest to first: conglomerates, monos, invests, circus, aksai, carbon, wilmot, platelets,
# Nearest to in: leninist, congressman, shame, bw, paces, histology, dungy, bowker,
# Nearest to its: surmised, amore, firearm, creativity, equinoctial, luria, iaido, nermal,
# Nearest to his: telford, husk, despised, minucius, transcendence, gedaliah, bengal, hagelin,
# Nearest to notes: bps, merciless, mycoplasma, lawlessness, pac, alphabets, lct, slit,
# Nearest to event: knut, pastel, defensively, ithaca, machina, harkness, leaf, ninlil,
# Nearest to universe: chongqing, halving, vail, yau, crossfire, discernible, ronny, tpvgames,
# Nearest to brother: kahuna, trice, arene, caliphate, garb, decompressed, endowments, cranial,
# Nearest to quite: hanyu, lal, chojnice, patty, pennock, disintegrate, compile, paphos,
# Nearest to animals: compaq, satisfiability, pineapples, marienburg, mets, nightmarish, esper, lox,
# Nearest to centre: nuke, olivier, courting, jasper, ponens, highbury, mollusk, nth,
# Nearest to mean: akimbo, gallium, venerating, members, girolamo, luminiferous, ducks, wicked,
# Epoch 4/10 Iteration: 4100 Avg. Training loss: 18.4808 0.6983 sec/batch
# Epoch 4/10 Iteration: 4200 Avg. Training loss: 18.3697 0.6815 sec/batch
# Epoch 4/10 Iteration: 4300 Avg. Training loss: 18.4295 0.6599 sec/batch
# Epoch 4/10 Iteration: 4400 Avg. Training loss: 18.3361 3.3809 sec/batch
# Epoch 4/10 Iteration: 4500 Avg. Training loss: 18.3087 0.8098 sec/batch
# Epoch 5/10 Iteration: 4600 Avg. Training loss: 18.3239 0.1139 sec/batch
# Epoch 5/10 Iteration: 4700 Avg. Training loss: 18.1541 0.8685 sec/batch
# Epoch 5/10 Iteration: 4800 Avg. Training loss: 18.2126 0.7985 sec/batch
# Epoch 5/10 Iteration: 4900 Avg. Training loss: 18.2427 0.7712 sec/batch
# Epoch 5/10 Iteration: 5000 Avg. Training loss: 18.2086 0.7817 sec/batch
# Nearest to new: number, artchive, circulation, auditioning, allston, alds, chiang, servlet,
# Nearest to their: dyck, curly, writ, saraswati, chapel, asw, teardrop, doran,
# Nearest to american: nyc, melanin, illawarra, ntp, inertia, wolfhound, pence, frist,
# Nearest to about: hotelier, flagstaff, flushing, pyramidal, discharge, reconfigured, moncton, uns,
# Nearest to first: apocalypse, outsider, kandy, caterina, zi, telephones, fashion, busters,
# Nearest to in: expect, martinez, auf, desktops, lastly, idi, suggest, females,
# Nearest to its: otis, ptl, sinuous, likeness, person, warhead, lifesaving, dignified,
# Nearest to his: clipping, jen, recoup, supercomputing, shinji, aegina, mobilized, solvers,
# Nearest to notes: bloc, napoleonic, spelling, anxiously, backus, aimed, miocene, performance,
# Nearest to event: pinscher, malfunctions, practice, bahasa, guin, pnh, wodehouse, zambian,
# Nearest to universe: skeeter, waxy, entangle, inflationary, iasi, smugglers, ashdown, pistol,
# Nearest to brother: castillo, gathers, unseemly, danilo, colle, chihuly, broomstick, impolite,
# Nearest to quite: bovine, domitian, macrolide, isle, taranto, ambition, env, traceable,
# Nearest to animals: deserved, cotopaxi, bowyer, knightsbridge, nemanja, kills, brick, pirate,
# Nearest to centre: connolly, beget, sandwiches, instantly, carlson, polar, walken, conventionally,
# Nearest to mean: erectile, crowley, relaxation, oem, testified, kur, portability, superiore,
# Epoch 5/10 Iteration: 5100 Avg. Training loss: 18.1344 0.8770 sec/batch
# Epoch 5/10 Iteration: 5200 Avg. Training loss: 18.1424 0.8311 sec/batch
# Epoch 5/10 Iteration: 5300 Avg. Training loss: 18.2029 0.8557 sec/batch
# Epoch 5/10 Iteration: 5400 Avg. Training loss: 18.0997 0.8902 sec/batch
# Epoch 5/10 Iteration: 5500 Avg. Training loss: 18.1631 0.8632 sec/batch
# Epoch 5/10 Iteration: 5600 Avg. Training loss: 18.0611 0.8266 sec/batch
# Epoch 5/10 Iteration: 5700 Avg. Training loss: 18.1679 0.8590 sec/batch
# Epoch 6/10 Iteration: 5800 Avg. Training loss: 17.9604 0.6136 sec/batch
# Epoch 6/10 Iteration: 5900 Avg. Training loss: 18.0085 0.8708 sec/batch
# Epoch 6/10 Iteration: 6000 Avg. Training loss: 18.0111 0.8425 sec/batch
# Nearest to new: proclaiming, fermions, hitchhiker, spore, battlecruiser, masterminded, lullaby, dsl,
# Nearest to their: transducer, zech, truer, foy, kindergarten, cetus, populate, trotting,
# Nearest to american: flavoured, statehouse, kislev, launcher, biblioth, engineered, presse, debunking,
# Nearest to about: deference, mistreated, whammy, petticoat, bopp, correlation, texans, hyacinth,
# Nearest to first: charterer, zygmunt, paternal, vm, preying, bcc, ersatz, il,
# Nearest to in: marvels, pianist, occupational, irregularity, stahl, raspy, ethology, teslas,
# Nearest to its: symington, buttocks, cantus, gerardo, refrigerant, surfing, cockroaches, politburo,
# Nearest to his: vorticity, boingo, luoyang, lfhild, governmental, utilize, shoulder, craters,
# Nearest to notes: operatives, floors, teng, neuroscientist, unhelpful, sultans, malawian, meant,
# Nearest to event: pinto, depressions, decorating, codasyl, priesthoods, emplaced, disassembled, barbed,
# Nearest to universe: sahib, arterioles, mist, pipe, mauryans, comforts, gabba, griffiths,
# Nearest to brother: communities, luminous, render, somalis, cosell, bohemia, esmeraldas, rune,
# Nearest to quite: inhuman, addis, otmar, ewen, bamileke, ambulances, username, hayat,
# Nearest to animals: infanta, nomo, windings, nonzero, fusing, arrow, insurmountable, dash,
# Nearest to centre: athaliah, kind, authorizes, xlr, machinery, teague, sleepy, lesh,
# Nearest to mean: scivias, bottle, michael, herefordshire, regimes, antoinette, dreadful, polynesians,
# Epoch 6/10 Iteration: 6100 Avg. Training loss: 18.0385 0.8638 sec/batch
# Epoch 6/10 Iteration: 6200 Avg. Training loss: 17.9513 0.8056 sec/batch
# Epoch 6/10 Iteration: 6300 Avg. Training loss: 17.9934 0.7866 sec/batch
# Epoch 6/10 Iteration: 6400 Avg. Training loss: 17.8159 0.8096 sec/batch
# Epoch 6/10 Iteration: 6500 Avg. Training loss: 17.9945 0.8159 sec/batch
# Epoch 6/10 Iteration: 6600 Avg. Training loss: 17.8630 0.7667 sec/batch
# Epoch 6/10 Iteration: 6700 Avg. Training loss: 17.8214 0.8065 sec/batch
# Epoch 6/10 Iteration: 6800 Avg. Training loss: 17.8558 0.7676 sec/batch
# Epoch 7/10 Iteration: 6900 Avg. Training loss: 17.7586 0.1946 sec/batch
# Epoch 7/10 Iteration: 7000 Avg. Training loss: 17.7394 0.7213 sec/batch
# Nearest to new: lars, raya, entitle, occident, wavy, jeanneret, novum, orchid,
# Nearest to their: coaxial, aide, commentary, commissars, awami, syrup, antigua, paranoid,
# Nearest to american: hiram, tarantino, baronies, indeterminate, sahib, bird, teasing, onscreen,
# Nearest to about: pennyworth, kpc, clubs, classic, pentafluoride, cord, feroze, levitated,
# Nearest to first: scarborough, prospect, bunk, hoyt, conductive, gamsakhurdia, toured, nucleus,
# Nearest to in: globin, rousing, fullerene, lobes, nsson, suites, mosfet, sues,
# Nearest to its: reading, lintels, severing, homogenous, barristers, arbitrage, miracle, illustrative,
# Nearest to his: artwork, gravimeters, weekly, riskin, tammany, kinderhook, suddenly, lebanon,
# Nearest to notes: ducati, bolo, occidentalis, autocracy, osten, impersonation, jay, tricked,
# Nearest to event: excuse, roda, doon, janie, homicidal, screams, cascade, chromaticism,
# Nearest to universe: caltech, gershwin, searing, bequeathed, disband, usda, ystem, wollaston,
# Nearest to brother: barite, gallant, bedridden, lysine, mistranslation, durians, habitable, injectors,
# Nearest to quite: voivodship, nuremberg, blessing, acquis, eugen, natur, duplicating, authority,
# Nearest to animals: setback, swerve, overlaps, por, iambic, melisende, bacteria, logic,
# Nearest to centre: bellow, evangelism, brunt, tanner, rectifiers, ddo, ebooks, medicis,
# Nearest to mean: piecemeal, amplifying, impact, age, moved, fairclough, propanol, aukrust,
# Epoch 7/10 Iteration: 7100 Avg. Training loss: 17.7434 0.7506 sec/batch
# Epoch 7/10 Iteration: 7200 Avg. Training loss: 17.8607 0.7131 sec/batch
# Epoch 7/10 Iteration: 7300 Avg. Training loss: 17.6205 0.7135 sec/batch
# Epoch 7/10 Iteration: 7400 Avg. Training loss: 17.6920 0.6885 sec/batch
# Epoch 7/10 Iteration: 7500 Avg. Training loss: 17.6586 0.6773 sec/batch
# Epoch 7/10 Iteration: 7600 Avg. Training loss: 17.6647 0.7032 sec/batch
# Epoch 7/10 Iteration: 7700 Avg. Training loss: 17.6522 0.6802 sec/batch
# Epoch 7/10 Iteration: 7800 Avg. Training loss: 17.6091 0.6434 sec/batch
# Epoch 7/10 Iteration: 7900 Avg. Training loss: 17.5457 0.6692 sec/batch
# Epoch 7/10 Iteration: 8000 Avg. Training loss: 17.5467 0.7042 sec/batch
# Nearest to new: bookchin, amperes, future, lenten, bcc, sorties, daily, painful,
# Nearest to their: mensch, callistus, knitters, padre, realised, gods, bingo, gtk,
# Nearest to american: ottavio, uncommonly, taboo, snow, poee, caen, ohr, loa,
# Nearest to about: edward, contemplated, instrumentals, adamantium, mitsotakis, attends, aol, site,
# Nearest to first: carbonates, baghdad, neurotransmitter, pitts, mather, wolfman, international, strachey,
# Nearest to in: dreadnought, jolly, flung, abnormalities, studied, wilf, metohija, joanie,
# Nearest to its: hail, beverage, billed, appalachian, biollante, manitou, scents, folies,
# Nearest to his: unsurprisingly, balance, faggot, istrian, oahu, ntr, castellano, mammalia,
# Nearest to notes: inventing, eelam, dirham, transfers, nor, kubrick, capstone, lars,
# Nearest to event: ironwood, saros, adrenal, malory, ilinden, lighters, monet, softness,
# Nearest to universe: confesses, horthy, mlb, destabilization, ascends, platte, harrelson, jazzy,
# Nearest to brother: cynicism, villanueva, sugar, geodesics, ser, preliminary, jumaada, irulan,
# Nearest to quite: raphus, darker, bow, sluzhba, ecclesiastica, flatland, doorstep, granville,
# Nearest to animals: wedding, aller, guderian, nominate, immediate, reine, beauharnais, dowager,
# Nearest to centre: convoy, animal, subdiscipline, debating, websites, alcide, reproduce, kesey,
# Nearest to mean: contribute, environment, onset, treaties, reusability, table, gull, dakar,
# Epoch 8/10 Iteration: 8100 Avg. Training loss: 17.4891 0.5206 sec/batch
# Epoch 8/10 Iteration: 8200 Avg. Training loss: 17.5143 0.6703 sec/batch
# Epoch 8/10 Iteration: 8300 Avg. Training loss: 17.4789 0.6840 sec/batch
# Epoch 8/10 Iteration: 8400 Avg. Training loss: 17.5319 0.6673 sec/batch
# Epoch 8/10 Iteration: 8500 Avg. Training loss: 17.4366 0.6222 sec/batch
# Epoch 8/10 Iteration: 8600 Avg. Training loss: 17.4258 0.6256 sec/batch
# Epoch 8/10 Iteration: 8700 Avg. Training loss: 17.3722 0.6228 sec/batch
# Epoch 8/10 Iteration: 8800 Avg. Training loss: 17.4392 0.6332 sec/batch
# Epoch 8/10 Iteration: 8900 Avg. Training loss: 17.3728 0.6377 sec/batch
# Epoch 8/10 Iteration: 9000 Avg. Training loss: 17.3134 0.6309 sec/batch
# Nearest to new: recruitment, dreyfus, writ, simultaneously, cante, historiographical, badougi, luf,
# Nearest to their: burrito, lesbians, smarteiffel, castello, hallowed, mande, mirza, swimming,
# Nearest to american: reginald, toasting, austroasiatic, intentions, subpage, diglossia, kayak, folsom,
# Nearest to about: nodal, horne, ewes, axel, intermixed, endosperm, narrowest, cajon,
# Nearest to first: foregrip, almanacs, opt, diocesan, inviting, brine, arcs, serpentine,
# Nearest to in: inuit, wildfires, indonesian, tx, horch, theroux, khalq, anarcho,
# Nearest to its: remastered, teenage, novalis, cosines, utterances, neurotoxins, industrialists, erimus,
# Nearest to his: malleson, started, ferret, pubs, talkative, ich, vicinity, vicenza,
# Nearest to notes: biologist, traumatic, casinos, interference, overruled, antarctic, postures, meridians,
# Nearest to event: octahedron, stitched, produces, dielectric, transnistria, falconer, wertham, subcultures,
# Nearest to universe: immersion, lamarr, bawerk, linden, approximations, localities, feuchtwanger, haganah,
# Nearest to brother: clients, fast, faroes, hertz, playback, abdicate, jordan, addams,
# Nearest to quite: imported, aerodynamics, paulus, copland, maximums, pers, complementary, vicarage,
# Nearest to animals: unpleasantly, chivalry, daubert, abeken, bashing, ulf, reflex, delgado,
# Nearest to centre: neue, veeck, overtures, androgen, hippie, miko, beneath, bassett,
# Nearest to mean: inflaton, titular, krakatoa, disbands, pln, rationalist, mascarene, cancels,
# Epoch 8/10 Iteration: 9100 Avg. Training loss: 17.3161 0.6392 sec/batch
# Epoch 9/10 Iteration: 9200 Avg. Training loss: 17.4030 0.2035 sec/batch
# Epoch 9/10 Iteration: 9300 Avg. Training loss: 17.2033 0.6236 sec/batch
# Epoch 9/10 Iteration: 9400 Avg. Training loss: 17.2642 0.6342 sec/batch
# Epoch 9/10 Iteration: 9500 Avg. Training loss: 17.3283 7.8969 sec/batch
# Epoch 9/10 Iteration: 9600 Avg. Training loss: 17.2391 0.7374 sec/batch
# Epoch 9/10 Iteration: 9700 Avg. Training loss: 17.2344 0.6693 sec/batch
# Epoch 9/10 Iteration: 9800 Avg. Training loss: 17.2319 0.7361 sec/batch
# Epoch 9/10 Iteration: 9900 Avg. Training loss: 17.2539 0.7521 sec/batch
# Epoch 9/10 Iteration: 10000 Avg. Training loss: 17.1773 0.7994 sec/batch
# Nearest to new: bbc, gbl, shining, engle, zucker, grunge, gratified, navarre,
# Nearest to their: sinaltrainal, crofts, konkani, cleft, bankhead, stagnation, kudrow, pontine,
# Nearest to american: reduction, minim, jobs, adsorbed, agave, syd, ganesh, enactment,
# Nearest to about: speculations, sole, breeze, primates, bretwalda, englishmen, weighing, tellingly,
# Nearest to first: cheerleaders, frente, cantillation, subfamily, botanicals, observatories, minkowski, ega,
# Nearest to in: seamanship, cleaves, adf, mistake, lasting, hawaiians, curtailing, proposing,
# Nearest to its: od, infused, sprite, td, evenly, bk, keywords, muons,
# Nearest to his: contract, stefano, bono, manganese, daf, kashima, marsalis, rahula,
# Nearest to notes: disturbs, visa, facts, shir, apologized, theatrum, lrv, tone,
# Nearest to event: epigram, preparation, culpability, nagano, seiya, swadesh, vipers, lytic,
# Nearest to universe: budgets, quartier, excepting, christophe, hironaka, statute, infused, forecast,
# Nearest to brother: leszek, suo, sulfuric, versus, programmability, recitative, flushing, thrashing,
# Nearest to quite: tigrinya, aniston, peta, congresswoman, conditioner, marginal, mithraeum, plaidy,
# Nearest to animals: bureaucrat, transgress, pathologist, detailing, repented, hushed, destabilizing, auxiliaries,
# Nearest to centre: octavia, whitehall, livre, hyde, textual, delegations, isolated, leafy,
# Nearest to mean: connective, kodiak, minkowski, insulator, protege, weds, bishkek, bots,
# Epoch 9/10 Iteration: 10100 Avg. Training loss: 17.0517 0.8059 sec/batch
# Epoch 9/10 Iteration: 10200 Avg. Training loss: 17.1231 0.7925 sec/batch
# Epoch 9/10 Iteration: 10300 Avg. Training loss: 17.0057 0.8074 sec/batch
# Epoch 10/10 Iteration: 10400 Avg. Training loss: 16.9657 0.7384 sec/batch
# Epoch 10/10 Iteration: 10500 Avg. Training loss: 16.9879 0.8580 sec/batch
# Epoch 10/10 Iteration: 10600 Avg. Training loss: 17.1259 0.8566 sec/batch
# Epoch 10/10 Iteration: 10700 Avg. Training loss: 17.0098 0.8574 sec/batch
# Epoch 10/10 Iteration: 10800 Avg. Training loss: 17.0059 0.8552 sec/batch
# Epoch 10/10 Iteration: 10900 Avg. Training loss: 17.0338 0.7742 sec/batch
# Epoch 10/10 Iteration: 11000 Avg. Training loss: 16.9159 0.7565 sec/batch
# Nearest to new: story, encyclop, subpixel, easiest, kripke, dissenter, manhunter, snail,
# Nearest to their: hochschild, cohesive, lifeboats, veneziano, originate, fulbright, factorials, cramped,
# Nearest to american: tyrone, tyrant, miniszt, cuyp, climbers, rifling, preparedness, ctv,
# Nearest to about: lolf, depress, aleichem, hermetic, bharatiya, haryana, coven, frontiers,
# Nearest to first: likewise, gladio, severely, fiore, robbie, nephi, affiliates, integrins,
# Nearest to in: autobahn, paine, surprises, agency, armchair, adaption, rationalized, bridgehead,
# Nearest to its: caveat, pinguinus, bro, pavlova, leucippus, praise, hava, probabilities,
# Nearest to his: sickness, uh, guyane, megillat, pira, unselfish, diego, mb,
# Nearest to notes: sensors, zoroastrian, concedes, flavius, yonkers, estis, tammuz, wynne,
# Nearest to event: dangrek, relevant, aclu, steppe, truthfully, applicants, cowen, zhuyin,
# Nearest to universe: indonesian, mataram, collapse, declining, telepaths, lever, holst, gairy,
# Nearest to brother: phagocytosis, impressive, sidelines, stereochemistry, ecclesiastics, bomis, hsieh, amarok,
# Nearest to quite: spotless, taca, slides, navigators, salad, lemurs, abhorrent, pernicious,
# Nearest to animals: liban, labial, kabuki, cinque, rantissi, peerages, mychal, contraception,
# Nearest to centre: heliogabalus, jacketed, nay, boomer, lubavitch, brion, tuvalu, cretan,
# Nearest to mean: corman, unloading, werewolf, subkey, benches, daiquiri, mc, swinging,
# Epoch 10/10 Iteration: 11100 Avg. Training loss: 16.8836 0.7746 sec/batch
# Epoch 10/10 Iteration: 11200 Avg. Training loss: 16.9429 0.7650 sec/batch
# Epoch 10/10 Iteration: 11300 Avg. Training loss: 16.9003 0.8282 sec/batch
# Epoch 10/10 Iteration: 11400 Avg. Training loss: 16.7976 0.8037 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
