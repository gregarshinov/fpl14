# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random
threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size):
    if min(idx, len(words) - idx - 1) < window_size or window_size <=0:
        window_size = min(idx,len(words) - idx - 1)
    w = 1
    if window_size > 1:
        w = random.randint(1,window_size)
    l = words[idx - w:idx]
    l.extend(words[idx+1:idx+w+1])
    return l

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) 
    softmax_b = tf.Variable(tf.zeros(n_vocab), name="softmax_bias")
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w,
        biases=softmax_b,
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5838 5.4663 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5874 0.4485 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4744 0.4544 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5075 0.4664 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4861 0.4731 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5041 0.4683 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4961 0.4741 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4799 0.4777 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4251 0.4613 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3912 0.4586 sec/batch
# Nearest to often: hazlitt, shaivism, pacifism, clearwater, unam, tyrell, snowstorm, melodically,
# Nearest to it: konkani, manat, bp, disruption, faithful, subgenres, example, pyridine,
# Nearest to seven: prentice, prus, idiocy, strove, ndebele, kopp, keepers, chop,
# Nearest to eight: qualifications, charenton, thoroughbred, rshavn, pattern, muso, emperor, confronted,
# Nearest to only: scrotum, bogota, qed, reclusive, unconnected, apev, gnome, this,
# Nearest to had: pamphlets, sheba, unprovable, board, readability, conservatives, amazonia, prisoners,
# Nearest to about: orexin, intimacy, galilei, satara, foreskin, arousal, stewie, median,
# Nearest to states: misidentification, machu, trace, elphinstone, julian, bake, flour, juxtaposition,
# Nearest to question: macneille, chadwick, stranded, jimi, dynastic, anchors, lodges, hoche,
# Nearest to http: miao, ibaraki, warmly, cherry, unn, lonergan, kgf, underemployed,
# Nearest to institute: rasmussen, palpatine, charming, megalon, mirror, sondheim, superstring, major,
# Nearest to applied: land, armando, oj, managing, rammed, ganesh, images, scant,
# Nearest to bible: flavianum, marini, growing, superstar, kh, optic, headings, trolley,
# Nearest to paris: maori, grizzly, sci, intoxicating, practical, blister, hardwired, sabor,
# Nearest to orthodox: hearst, scolded, lizzie, halogens, loka, fortresses, jammin, therapeutics,
# Nearest to alternative: ramone, ddd, subordo, dumpster, misses, ivan, flops, roadster,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4298 0.4856 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3759 0.5363 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3288 0.5254 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2169 0.5159 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1657 0.5101 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1320 0.5209 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0862 0.5029 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0403 0.5185 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0122 0.5157 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0043 0.5129 sec/batch
# Nearest to often: hazlitt, shaivism, represent, pacifism, unam, merits, euclidean, tyrell,
# Nearest to it: konkani, bp, example, faithful, disruption, manat, traded, subgenres,
# Nearest to seven: prentice, prus, recently, idiocy, strove, thereto, ignorant, vital,
# Nearest to eight: qualifications, emperor, pattern, acquired, confronted, becoming, max, sectors,
# Nearest to only: this, bogota, scrotum, amount, achieve, several, schneier, tolbert,
# Nearest to had: pamphlets, sheba, board, unprovable, prisoners, conservatives, copy, comprised,
# Nearest to about: orexin, median, show, intimacy, invented, satara, balanced, indefinite,
# Nearest to states: misidentification, trace, passed, propaganda, bake, styles, julian, felt,
# Nearest to question: stranded, chadwick, macneille, hoche, ranked, grinch, lodges, anchors,
# Nearest to http: miao, warmly, ibaraki, cherry, malpighi, strengthen, directing, lonergan,
# Nearest to institute: major, after, activities, injuries, rasmussen, superstring, hope, charming,
# Nearest to applied: land, armando, guo, oj, managing, rammed, images, fine,
# Nearest to bible: flavianum, superstar, growing, marini, trolley, kh, markets, prescribes,
# Nearest to paris: maori, sci, intoxicating, practical, grizzly, smuggler, sukkot, blister,
# Nearest to orthodox: hearst, scolded, lizzie, clean, loka, intimate, divinities, lost,
# Nearest to alternative: ddd, claude, dumpster, recordings, flops, span, misses, parkinson,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9460 0.5096 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9093 0.5146 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8628 0.5062 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8928 0.4975 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8078 0.4977 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8178 0.4978 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8298 0.4893 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7843 0.5032 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8174 0.5137 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8067 0.5091 sec/batch
# Nearest to often: hazlitt, pacifism, tyrell, represent, clearwater, merits, snowstorm, unam,
# Nearest to it: bp, konkani, faithful, manat, disruption, subgenres, example, coronation,
# Nearest to seven: prentice, prus, strove, thereto, idiocy, recently, vital, revolutionary,
# Nearest to eight: emperor, qualifications, expectancy, confronted, max, salvador, pattern, penchant,
# Nearest to only: bogota, this, scrotum, expedients, achieve, elsewhere, amount, reformed,
# Nearest to had: pamphlets, sheba, board, unprovable, readability, farm, concentration, conservatives,
# Nearest to about: orexin, median, intimacy, invented, show, balanced, satara, galilei,
# Nearest to states: misidentification, propaganda, trace, julian, passed, styles, misnomer, ageing,
# Nearest to question: chadwick, stranded, macneille, lodges, ranked, grinch, hoche, dynastic,
# Nearest to http: miao, warmly, directing, strengthen, refugees, cherry, deliberately, malpighi,
# Nearest to institute: charming, rasmussen, injuries, major, hope, activities, returned, stan,
# Nearest to applied: land, armando, images, managing, guo, oj, rammed, fine,
# Nearest to bible: flavianum, superstar, growing, kh, headings, trolley, marini, thieves,
# Nearest to paris: sci, maori, practical, intoxicating, grizzly, sukkot, parliamentarism, blister,
# Nearest to orthodox: scolded, hearst, lizzie, clean, frontiers, fortresses, divinities, loka,
# Nearest to alternative: misses, flops, ddd, span, claude, dumpster, recordings, parkinson,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7789 0.5093 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7612 0.5234 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7161 0.5098 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7097 0.5168 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7589 0.5383 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7211 0.5103 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7046 0.5137 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7175 0.5312 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7097 0.5282 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6350 0.5171 sec/batch
# Nearest to often: hazlitt, snowstorm, tyrell, simile, clearwater, pancreas, forelimbs, unam,
# Nearest to it: bp, konkani, subgenres, faithful, manat, disruption, example, coronation,
# Nearest to seven: prentice, prus, thereto, phillips, idiocy, measles, strove, jacobite,
# Nearest to eight: expectancy, emperor, shari, max, penchant, salvador, confronted, nine,
# Nearest to only: bogota, this, scrotum, reformed, tolbert, expedients, qed, gnome,
# Nearest to had: pamphlets, sheba, unprovable, board, conservatives, shanahan, gaon, prisoners,
# Nearest to about: orexin, intimacy, median, show, invented, arousal, dione, arriving,
# Nearest to states: misidentification, propaganda, machu, rubens, nitz, unsuccessfully, julian, ageing,
# Nearest to question: chadwick, stranded, macneille, ipv, jimi, grinch, hoche, dinner,
# Nearest to http: miao, warmly, ibaraki, malpighi, cherry, gauze, directing, underemployed,
# Nearest to institute: rasmussen, charming, sondheim, injuries, hope, attracts, mirror, stan,
# Nearest to applied: land, armando, guo, images, scant, managing, rammed, oj,
# Nearest to bible: flavianum, superstar, kh, headings, growing, thieves, trolley, angry,
# Nearest to paris: maori, sci, intoxicating, grizzly, byron, practical, sukkot, blister,
# Nearest to orthodox: scolded, lizzie, hearst, fortresses, clean, frontiers, divinities, loka,
# Nearest to alternative: misses, ddd, dumpster, flops, parkinson, graphical, claude, mistakes,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6737 0.5035 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6948 0.5287 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6099 0.5292 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6677 0.5536 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6561 0.5561 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6201 0.5650 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6305 0.3971 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5703 0.5386 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5131 0.5666 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4768 0.5134 sec/batch
# Nearest to often: hazlitt, pancreas, simile, snowstorm, forelimbs, tyrell, papert, unam,
# Nearest to it: konkani, subgenres, bp, manat, example, faithful, mortals, firefighting,
# Nearest to seven: prentice, prus, buchan, measles, phillips, actress, thereto, earl,
# Nearest to eight: expectancy, politician, earl, katz, emperor, shari, de, nine,
# Nearest to only: bogota, this, scrotum, qed, tolbert, unconnected, nonzero, reformed,
# Nearest to had: pamphlets, sheba, shanahan, conservatives, board, unprovable, gaon, farm,
# Nearest to about: orexin, dione, intimacy, invented, arousal, median, galilei, foreskin,
# Nearest to states: misidentification, propaganda, nitz, resumption, machu, rubens, minister, homestead,
# Nearest to question: chadwick, stranded, macneille, ipv, grinch, jimi, hoche, intercepting,
# Nearest to http: miao, warmly, ibaraki, malpighi, cherry, smiles, gauze, underemployed,
# Nearest to institute: sondheim, rasmussen, charming, stan, hope, mirror, injuries, spectrometers,
# Nearest to applied: armando, land, scant, guo, rammed, images, oj, ganesh,
# Nearest to bible: flavianum, kh, superstar, headings, thieves, angry, malawi, tsang,
# Nearest to paris: maori, sci, freemasons, grizzly, sukkot, repairs, intoxicating, byron,
# Nearest to orthodox: scolded, lizzie, hearst, fortresses, divinities, loka, moderates, newburgh,
# Nearest to alternative: misses, graphical, dumpster, flops, ddd, parkinson, mistakes, compaor,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5048 0.5653 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4897 0.5333 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4441 0.5950 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5142 0.5723 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4987 0.5674 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4557 0.5462 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4545 0.5629 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3856 0.5608 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4509 0.5587 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4446 0.5998 sec/batch
# Nearest to often: hazlitt, simile, pancreas, snowstorm, forelimbs, flu, papert, zainab,
# Nearest to it: bp, konkani, manat, subgenres, mortals, example, inconceivable, breeds,
# Nearest to seven: prentice, prus, buchan, measles, idiocy, sensationalism, thereto, phillips,
# Nearest to eight: expectancy, katz, zero, salvador, chronicler, shari, de, eddie,
# Nearest to only: this, bogota, scrotum, nonzero, qed, tolbert, unconnected, amount,
# Nearest to had: pamphlets, sheba, shanahan, conservatives, board, gaon, unprovable, prisoners,
# Nearest to about: orexin, dione, intimacy, median, invented, arousal, foreskin, finesse,
# Nearest to states: misidentification, nitz, overgrazing, resumption, machu, homestead, rubens, propaganda,
# Nearest to question: chadwick, stranded, ipv, macneille, jimi, grinch, multiplying, hoche,
# Nearest to http: miao, ibaraki, malpighi, warmly, cherry, underemployed, smiles, external,
# Nearest to institute: sondheim, rasmussen, hope, kiss, injuries, stan, arsenio, mirror,
# Nearest to applied: land, armando, scant, guo, oj, ganesh, otherworldly, rammed,
# Nearest to bible: flavianum, kh, superstar, angry, headings, tsang, temple, malawi,
# Nearest to paris: maori, sci, freemasons, grizzly, sukkot, byron, parliamentarism, blister,
# Nearest to orthodox: scolded, lizzie, divinities, fortresses, moderates, protestant, frontiers, pentecostals,
# Nearest to alternative: graphical, flops, misses, dumpster, ddd, mistakes, inactive, compaor,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4240 0.5819 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4167 0.5434 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4291 0.5495 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3566 0.5588 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4255 0.5501 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4341 0.5146 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3654 0.6187 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4046 0.8568 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4350 0.9457 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4072 1.0346 sec/batch
# Nearest to often: pancreas, simile, zainab, snowstorm, forelimbs, flu, myoglobin, enosis,
# Nearest to it: bp, konkani, manat, mortals, exploited, subgenres, example, reasonable,
# Nearest to seven: prentice, prus, buchan, measles, sensationalism, actress, idiocy, hines,
# Nearest to eight: expectancy, zero, katz, eddie, kathy, de, salvador, eds,
# Nearest to only: this, bogota, scrotum, nonzero, qed, tolbert, unconnected, amount,
# Nearest to had: pamphlets, sheba, shanahan, board, conservatives, prisoners, gaon, ritualised,
# Nearest to about: orexin, dione, median, foreskin, intimacy, jeffries, invented, arriving,
# Nearest to states: misidentification, nitz, resumption, homestead, overgrazing, machu, spokes, pedagogic,
# Nearest to question: chadwick, stranded, ipv, macneille, jimi, abbr, grinch, multiplying,
# Nearest to http: miao, external, htm, malpighi, underemployed, warmly, ibaraki, smiles,
# Nearest to institute: sondheim, rasmussen, programmes, stroll, stan, hope, charming, arsenio,
# Nearest to applied: land, armando, oj, scant, otherworldly, ganesh, guo, ferroelectric,
# Nearest to bible: flavianum, kh, temple, superstar, headings, angry, faith, tsang,
# Nearest to paris: maori, sci, freemasons, sukkot, grizzly, parliamentarism, byron, repairs,
# Nearest to orthodox: protestant, scolded, council, lizzie, divinities, church, albanian, catholic,
# Nearest to alternative: dumpster, graphical, flops, ddd, misses, mistakes, cercozoa, roadster,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3702 1.0445 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3887 1.0209 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3500 0.7257 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3605 0.5294 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3816 0.9782 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3824 0.8255 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3880 0.7660 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3689 0.8195 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3310 0.9092 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3272 1.0776 sec/batch
# Nearest to often: simile, pancreas, flu, zainab, enosis, forelimbs, snowstorm, myoglobin,
# Nearest to it: bp, konkani, manat, mortals, is, subgenres, inconceivable, exploited,
# Nearest to seven: prentice, prus, buchan, sensationalism, measles, six, one, capita,
# Nearest to eight: expectancy, zero, six, katz, salvador, sectors, kathy, wyclif,
# Nearest to only: this, bogota, nonzero, muppet, qed, scrotum, polices, amount,
# Nearest to had: pamphlets, sheba, conservatives, shanahan, board, ritualised, prisoners, farm,
# Nearest to about: orexin, dione, median, intimacy, arriving, sheds, foreskin, jeffries,
# Nearest to states: misidentification, between, remuneration, resumption, nitz, homestead, constitution, overgrazing,
# Nearest to question: stranded, ipv, chadwick, macneille, multiplying, jimi, abbr, prophesied,
# Nearest to http: external, htm, miao, ibaraki, malpighi, underemployed, com, www,
# Nearest to institute: sondheim, rasmussen, stroll, graduate, programmes, arsenio, chit, schools,
# Nearest to applied: land, armando, oj, ganesh, ferroelectric, scant, images, guo,
# Nearest to bible: flavianum, temple, superstar, kh, tsang, faith, angry, jerusalem,
# Nearest to paris: maori, sci, sukkot, freemasons, parliamentarism, grizzly, repairs, byron,
# Nearest to orthodox: scolded, protestant, divinities, word, nicaea, pentecostals, lizzie, albanian,
# Nearest to alternative: dumpster, ddd, misses, graphical, flops, roadster, cercozoa, subordo,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3329 0.9924 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2871 1.0264 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3577 1.1126 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3521 1.1580 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3922 1.1748 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2654 1.1238 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2841 1.1295 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3249 1.2653 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2129 1.3431 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2924 1.3956 sec/batch
# Nearest to often: flu, pancreas, simile, snowstorm, forelimbs, zainab, enosis, strawberry,
# Nearest to it: bp, is, konkani, mortals, manat, subgenres, inconceivable, mcluhan,
# Nearest to seven: prentice, one, prus, buchan, six, measles, marquis, sensationalism,
# Nearest to eight: zero, six, nine, katz, kathy, four, one, expectancy,
# Nearest to only: this, muppet, bogota, nonzero, polices, qed, scrotum, sogdian,
# Nearest to had: pamphlets, sheba, shanahan, conservatives, but, board, ritualised, farm,
# Nearest to about: orexin, dione, intimacy, foreskin, arriving, median, understated, galilei,
# Nearest to states: between, resumption, nitz, homestead, remuneration, overgrazing, misidentification, pedagogic,
# Nearest to question: stranded, ipv, chadwick, multiplying, macneille, abbr, jimi, prophesied,
# Nearest to http: external, htm, www, com, ibaraki, org, edu, miao,
# Nearest to institute: sondheim, rasmussen, graduate, stroll, programmes, school, student, schools,
# Nearest to applied: land, armando, ferroelectric, oj, guo, upsetting, scant, ganesh,
# Nearest to bible: flavianum, temple, superstar, headings, translation, kh, tsang, divinity,
# Nearest to paris: maori, parliamentarism, freemasons, sci, repairs, sukkot, byron, grizzly,
# Nearest to orthodox: scolded, word, congregations, divinities, protestant, davidic, pentecostals, nicaea,
# Nearest to alternative: dumpster, graphical, ddd, misses, flops, cercozoa, inactive, mistakes,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2865 1.2704 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2704 1.4482 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3054 0.6743 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2538 1.3523 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2077 1.4111 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2010 1.4051 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1970 1.4006 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2134 1.4069 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1880 1.4050 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1444 1.3415 sec/batch
# Nearest to often: pancreas, simile, flu, snowstorm, zainab, forelimbs, denial, myoglobin,
# Nearest to it: bp, is, mortals, manat, konkani, wiggins, mcluhan, spontaneous,
# Nearest to seven: prentice, one, buchan, prus, six, sensationalism, whipple, marquis,
# Nearest to eight: zero, six, expectancy, kathy, katz, nine, scriptwriter, four,
# Nearest to only: this, muppet, bogota, nonzero, polices, qed, scrotum, cornhuskers,
# Nearest to had: pamphlets, sheba, conservatives, shanahan, was, but, board, concede,
# Nearest to about: dione, orexin, median, arriving, intimacy, concentric, qatar, arousal,
# Nearest to states: between, resumption, homestead, remuneration, nitz, overgrazing, pedagogic, misidentification,
# Nearest to question: stranded, ipv, abbr, ought, chadwick, socio, loyalty, multiplying,
# Nearest to http: htm, external, org, www, com, edu, miao, links,
# Nearest to institute: graduate, schools, rasmussen, school, education, sondheim, stroll, student,
# Nearest to applied: land, armando, ferroelectric, upsetting, oj, guo, ganesh, monopolized,
# Nearest to bible: flavianum, headings, translation, gentiles, tanakh, kh, temple, superstar,
# Nearest to paris: maori, freemasons, parliamentarism, sukkot, repairs, sybil, sci, berwick,
# Nearest to orthodox: scolded, congregations, word, protestant, pentecostals, divinities, nicaea, davidic,
# Nearest to alternative: dumpster, graphical, ddd, flops, cercozoa, misses, mistakes, roadster,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.1923 1.3077 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2032 1.3915 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2167 1.1539 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1229 1.1734 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1599 1.1198 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1441 1.2158 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.0994 0.8513 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1649 0.8747 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1654 1.1172 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1520 1.0449 sec/batch
# Nearest to often: pancreas, simile, flu, snowstorm, zainab, injections, myoglobin, denial,
# Nearest to it: is, bp, mortals, konkani, wiggins, mcluhan, reasonable, example,
# Nearest to seven: prentice, one, buchan, prus, six, sensationalism, whipple, hines,
# Nearest to eight: zero, six, expectancy, four, katz, nine, two, scriptwriter,
# Nearest to only: this, muppet, polices, qed, nonzero, cornhuskers, bogota, scrotum,
# Nearest to had: pamphlets, sheba, conservatives, was, shanahan, farm, but, docklands,
# Nearest to about: dione, orexin, concentric, arriving, intimacy, median, sheds, characterized,
# Nearest to states: homestead, between, remuneration, resumption, overgrazing, nitz, pedagogic, processing,
# Nearest to question: stranded, ipv, ought, abbr, socio, loyalty, sedating, prophesied,
# Nearest to http: htm, external, org, www, edu, comprehensive, com, miao,
# Nearest to institute: graduate, schools, education, school, research, student, rasmussen, institutes,
# Nearest to applied: land, ferroelectric, upsetting, armando, oj, guo, ganesh, foundational,
# Nearest to bible: flavianum, headings, gentiles, tanakh, translation, translations, temple, deuteronomy,
# Nearest to paris: maori, freemasons, sukkot, parliamentarism, repairs, sci, berwick, sybil,
# Nearest to orthodox: scolded, word, congregations, pentecostals, davidic, albanian, divinities, nicaea,
# Nearest to alternative: dumpster, graphical, flops, ddd, cercozoa, mistakes, inactive, roadster,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1471 1.1838 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1772 1.2931 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1611 1.1977 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1262 1.3506 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1678 1.3968 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1531 1.3377 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1902 1.3990 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0978 1.3998 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1173 1.3516 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1781 1.3981 sec/batch
# Nearest to often: simile, flu, pancreas, zainab, injections, myoglobin, snowstorm, morphemes,
# Nearest to it: is, bp, mortals, wiggins, konkani, mcluhan, torii, contrary,
# Nearest to seven: prentice, one, six, buchan, three, prus, hines, zero,
# Nearest to eight: six, zero, nine, expectancy, four, two, one, five,
# Nearest to only: this, muppet, nonzero, polices, cornhuskers, qed, podium, graced,
# Nearest to had: pamphlets, sheba, conservatives, shanahan, was, ritualised, prisoners, concede,
# Nearest to about: dione, orexin, arriving, concentric, median, intimacy, characterized, jeffries,
# Nearest to states: remuneration, between, pedagogic, congress, processing, constitution, resumption, overgrazing,
# Nearest to question: stranded, ipv, ought, loyalty, crimes, socio, abbr, questions,
# Nearest to http: htm, external, www, org, edu, links, comprehensive, miao,
# Nearest to institute: graduate, education, schools, research, school, student, humanities, institutes,
# Nearest to applied: land, ferroelectric, upsetting, armando, foundational, guo, oj, monopolized,
# Nearest to bible: headings, flavianum, deuteronomy, gentiles, kh, translation, tanakh, prescribes,
# Nearest to paris: maori, sukkot, parliamentarism, robotics, berwick, sybil, repairs, practical,
# Nearest to orthodox: congregations, scolded, albanian, davidic, nicaea, pentecostals, canons, word,
# Nearest to alternative: dumpster, graphical, flops, inactive, ddd, mistakes, thinkers, emphasis,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1884 1.0671 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1577 0.7239 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1539 0.7422 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1693 0.6923 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1152 0.5417 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0876 0.5590 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1623 0.6087 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1140 0.6331 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1721 0.5670 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2107 0.5898 sec/batch
# Nearest to often: zainab, simile, flu, injections, snowstorm, strawberry, mokhehle, pancreas,
# Nearest to it: is, bp, mcluhan, torii, wiggins, konkani, mortals, subgenres,
# Nearest to seven: one, prentice, six, buchan, eight, three, marquis, zero,
# Nearest to eight: six, zero, four, one, nine, two, seven, five,
# Nearest to only: this, muppet, polices, podium, graced, cornhuskers, qed, nomination,
# Nearest to had: pamphlets, sheba, was, conservatives, farm, but, shanahan, ritualised,
# Nearest to about: orexin, dione, arriving, intimacy, jeffries, median, qatar, endogamy,
# Nearest to states: between, remuneration, pedagogic, constitution, congress, nitz, homestead, resumption,
# Nearest to question: stranded, ought, ipv, metternich, questions, abbr, socio, femur,
# Nearest to http: htm, external, www, org, edu, com, ibaraki, comprehensive,
# Nearest to institute: graduate, education, research, humanities, school, schools, student, institutes,
# Nearest to applied: ferroelectric, armando, land, upsetting, foundational, oj, ganesh, guo,
# Nearest to bible: flavianum, prescribes, deuteronomy, headings, kh, translation, superstar, temple,
# Nearest to paris: maori, parliamentarism, practical, robotics, repairs, sukkot, sybil, shine,
# Nearest to orthodox: congregations, scolded, davidic, albanian, nicaea, pentecostals, other, tractates,
# Nearest to alternative: dumpster, graphical, inactive, flops, emphasis, thinkers, ddd, mistakes,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2174 0.5898 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1270 0.4827 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1074 0.5227 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1113 0.6009 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0119 0.4925 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1373 0.5339 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1190 0.5555 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1020 0.5223 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1521 0.0989 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0821 0.4827 sec/batch
# Nearest to often: zainab, flu, simile, injections, musical, snowstorm, reabsorption, morphemes,
# Nearest to it: is, bp, mcluhan, wiggins, konkani, torii, subgenres, scenery,
# Nearest to seven: one, prentice, six, three, buchan, zero, marquis, eight,
# Nearest to eight: zero, six, four, one, two, nine, expectancy, three,
# Nearest to only: this, muppet, qed, cornhuskers, nonzero, podium, graced, polices,
# Nearest to had: pamphlets, sheba, was, farm, shanahan, conservatives, but, lenient,
# Nearest to about: dione, orexin, arriving, median, intimacy, concentric, characterized, endogamy,
# Nearest to states: between, remuneration, pedagogic, homestead, processing, united, congress, resumption,
# Nearest to question: stranded, ought, ipv, metternich, questions, sedating, socio, multiplying,
# Nearest to http: htm, external, www, org, edu, com, comprehensive, links,
# Nearest to institute: graduate, humanities, education, research, school, institutes, schools, student,
# Nearest to applied: ferroelectric, upsetting, land, armando, deutsche, oj, foundational, monopolized,
# Nearest to bible: flavianum, prescribes, headings, deuteronomy, kh, translation, superstar, temple,
# Nearest to paris: maori, parliamentarism, robotics, sukkot, practical, sybil, repairs, berwick,
# Nearest to orthodox: congregations, albanian, davidic, scolded, nicaea, tractates, pentecostals, loka,
# Nearest to alternative: dumpster, ddd, emphasis, graphical, inactive, flops, cercozoa, readability,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0754 0.4909 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0359 0.5281 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0675 0.5429 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0420 0.5294 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0421 0.5135 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0057 0.5255 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0738 0.4790 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0661 0.5339 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0910 0.5509 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0032 0.5300 sec/batch
# Nearest to often: flu, simile, zainab, strawberry, reabsorption, snowstorm, myoglobin, injections,
# Nearest to it: is, bp, wiggins, mcluhan, torii, konkani, cavern, of,
# Nearest to seven: prentice, one, six, three, buchan, eight, zero, marquis,
# Nearest to eight: zero, six, four, one, expectancy, three, two, nine,
# Nearest to only: muppet, this, cornhuskers, podium, polices, qed, graced, nomination,
# Nearest to had: pamphlets, was, sheba, conservatives, farm, but, shanahan, ritualised,
# Nearest to about: arriving, dione, orexin, median, qatar, characterized, yana, intimacy,
# Nearest to states: between, remuneration, processing, homestead, resumption, united, ngg, overgrazing,
# Nearest to question: ipv, stranded, ought, questions, metternich, socio, sedating, multiplying,
# Nearest to http: htm, external, www, org, comprehensive, edu, com, links,
# Nearest to institute: graduate, humanities, education, school, research, institutes, student, schools,
# Nearest to applied: ferroelectric, upsetting, land, armando, deutsche, monopolized, oj, foundational,
# Nearest to bible: headings, judaica, deuteronomy, translations, tanakh, flavianum, prescribes, easton,
# Nearest to paris: parliamentarism, maori, berwick, robotics, une, practical, shine, repairs,
# Nearest to orthodox: congregations, albanian, pentecostals, davidic, scolded, canons, tractates, catholic,
# Nearest to alternative: dumpster, flops, graphical, emphasis, inactive, ddd, cercozoa, readability,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9924 0.4715 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9991 0.5055 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9488 0.5765 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0218 0.5731 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0329 0.5497 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0427 0.5626 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0263 0.5174 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0703 0.5200 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0317 0.5384 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0062 0.5323 sec/batch
# Nearest to often: myoglobin, espouses, injections, flu, zainab, morphemes, simile, reabsorption,
# Nearest to it: is, bp, mcluhan, torii, konkani, cavern, wiggins, carbohydrates,
# Nearest to seven: one, prentice, six, three, eight, buchan, zero, marquis,
# Nearest to eight: six, zero, one, four, two, nine, expectancy, three,
# Nearest to only: this, muppet, cornhuskers, podium, qed, polices, graced, csx,
# Nearest to had: pamphlets, was, sheba, farm, but, ritualised, shanahan, conservatives,
# Nearest to about: arriving, orexin, dione, median, characterized, show, galilei, jeffries,
# Nearest to states: between, united, remuneration, processing, congress, pedagogic, resumption, ngg,
# Nearest to question: ought, questions, stranded, ipv, metternich, socio, genotype, sedating,
# Nearest to http: htm, external, www, org, edu, comprehensive, links, com,
# Nearest to institute: graduate, humanities, education, research, school, institutes, schools, student,
# Nearest to applied: ferroelectric, upsetting, deutsche, oj, armando, monopolized, foundational, land,
# Nearest to bible: headings, deuteronomy, prescribes, judaica, tanakh, flavianum, easton, translations,
# Nearest to paris: shine, une, maori, parliamentarism, berwick, repairs, robotics, sybil,
# Nearest to orthodox: congregations, albanian, scolded, davidic, canons, pentecostals, nicaea, tractates,
# Nearest to alternative: dumpster, emphasis, inactive, flops, ddd, mistakes, graphical, refurbishment,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0240 0.5326 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0666 0.5219 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0515 0.5217 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9856 0.5227 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0264 0.4778 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0064 0.4868 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0198 0.5384 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0482 0.5453 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0458 0.5384 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0436 0.5173 sec/batch
# Nearest to often: zainab, simile, reabsorption, flu, morphemes, musical, strawberry, espouses,
# Nearest to it: is, bp, torii, mcluhan, konkani, cavern, wiggins, from,
# Nearest to seven: one, six, three, prentice, zero, eight, two, buchan,
# Nearest to eight: zero, six, four, one, two, nine, three, expectancy,
# Nearest to only: this, muppet, podium, polices, cornhuskers, graced, vav, nomination,
# Nearest to had: was, pamphlets, sheba, farm, but, alexander, conservatives, ritualised,
# Nearest to about: orexin, dione, arriving, characterized, galilei, median, endtime, jeffries,
# Nearest to states: between, united, resumption, congress, remuneration, pedagogic, processing, ngg,
# Nearest to question: ought, metternich, questions, stranded, ipv, socio, sedating, genotype,
# Nearest to http: htm, www, external, org, com, edu, comprehensive, index,
# Nearest to institute: graduate, humanities, education, research, institutes, school, postgraduate, schools,
# Nearest to applied: upsetting, ferroelectric, deutsche, foundational, monopolized, oj, armando, land,
# Nearest to bible: headings, prescribes, deuteronomy, judaica, easton, tanakh, flavianum, translations,
# Nearest to paris: une, shine, parliamentarism, maori, berwick, practical, repairs, sybil,
# Nearest to orthodox: congregations, albanian, canons, scolded, davidic, loka, nicaea, tractates,
# Nearest to alternative: ddd, dumpster, inactive, emphasis, flops, readability, refurbishment, cercozoa,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0340 0.5333 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9714 0.5321 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9833 0.5033 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0363 0.5147 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0597 0.4532 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1019 0.4518 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0956 0.4561 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0277 0.4434 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9885 0.4192 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0255 0.4181 sec/batch
# Nearest to often: zainab, reabsorption, simile, flu, strawberry, musical, injections, morphemes,
# Nearest to it: is, bp, mcluhan, torii, cavern, wiggins, noli, scenery,
# Nearest to seven: six, one, three, prentice, zero, eight, buchan, two,
# Nearest to eight: zero, six, four, one, two, nine, expectancy, three,
# Nearest to only: this, muppet, podium, nomination, cornhuskers, polices, vav, annal,
# Nearest to had: sheba, pamphlets, was, farm, but, shanahan, ritualised, lenient,
# Nearest to about: arriving, dione, orexin, median, qatar, endtime, olmec, characterized,
# Nearest to states: united, between, resumption, congress, remuneration, pedagogic, processing, homestead,
# Nearest to question: ought, stranded, questions, ipv, metternich, genotype, sedating, socio,
# Nearest to http: htm, www, external, org, edu, com, comprehensive, html,
# Nearest to institute: humanities, graduate, education, research, institutes, school, postgraduate, sciences,
# Nearest to applied: ferroelectric, upsetting, deutsche, foundational, armando, monopolized, oj, hints,
# Nearest to bible: headings, prescribes, easton, flavianum, deuteronomy, tanakh, judaica, ort,
# Nearest to paris: une, parliamentarism, maori, sybil, shine, repairs, robotics, practical,
# Nearest to orthodox: congregations, albanian, scolded, loka, nicaea, tractates, canons, davidic,
# Nearest to alternative: ddd, inactive, dumpster, readability, refurbishment, emphasis, cercozoa, friulian,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9299 0.4579 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9870 0.4921 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9914 0.5019 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9943 0.5391 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0445 0.5116 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0170 0.5301 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9907 0.5567 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9503 0.5809 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9488 0.5861 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9426 0.5267 sec/batch
# Nearest to often: zainab, morphemes, flu, espouses, snowstorm, reabsorption, simile, strawberry,
# Nearest to it: is, mcluhan, bp, from, of, cavern, jutland, wiggins,
# Nearest to seven: one, three, six, zero, prentice, eight, two, four,
# Nearest to eight: zero, six, one, four, nine, two, three, five,
# Nearest to only: muppet, this, podium, polices, cornhuskers, annal, nomination, vav,
# Nearest to had: was, sheba, pamphlets, farm, but, alexander, lenient, conservatives,
# Nearest to about: arriving, orexin, dione, median, olmec, characterized, endtime, kook,
# Nearest to states: united, resumption, processing, homestead, between, congress, pedagogic, does,
# Nearest to question: questions, stranded, ought, metternich, ipv, socio, genotype, sedating,
# Nearest to http: htm, www, org, external, edu, com, html, comprehensive,
# Nearest to institute: humanities, graduate, institutes, education, research, school, postgraduate, sciences,
# Nearest to applied: ferroelectric, upsetting, deutsche, foundational, ashur, monopolized, oj, hints,
# Nearest to bible: deuteronomy, prescribes, easton, flavianum, headings, tanakh, judaica, ort,
# Nearest to paris: une, parliamentarism, shine, repairs, maori, sybil, practical, robotics,
# Nearest to orthodox: congregations, albanian, scolded, nicaea, tractates, loka, davidic, lizzie,
# Nearest to alternative: inactive, ddd, dumpster, refurbishment, emphasis, mistakes, readability, cercozoa,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9567 0.5443 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9130 0.5723 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9828 0.5465 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0022 0.5370 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9836 0.4638 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9533 0.4989 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9046 0.5215 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.8975 0.5034 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8863 0.4993 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9352 0.5397 sec/batch
# Nearest to often: zainab, flu, morphemes, reabsorption, simile, espouses, myoglobin, injections,
# Nearest to it: is, bp, from, carbohydrates, mcluhan, jutland, that, cavern,
# Nearest to seven: one, three, six, prentice, zero, eight, two, four,
# Nearest to eight: zero, six, four, one, two, nine, three, seven,
# Nearest to only: this, muppet, podium, cornhuskers, polices, vav, graced, annal,
# Nearest to had: was, sheba, farm, pamphlets, alexander, twenty, mckechnie, shanahan,
# Nearest to about: orexin, median, arriving, dione, characterized, endogamy, kook, poached,
# Nearest to states: united, resumption, processing, homestead, ngg, between, congress, does,
# Nearest to question: questions, ought, stranded, metternich, socio, ipv, sedating, genotype,
# Nearest to http: htm, www, org, external, com, edu, html, comprehensive,
# Nearest to institute: humanities, graduate, institutes, education, research, school, postgraduate, sciences,
# Nearest to applied: deutsche, ferroelectric, upsetting, ashur, foundational, monopolized, oj, fine,
# Nearest to bible: headings, easton, prescribes, flavianum, deuteronomy, judaica, tanakh, translations,
# Nearest to paris: une, parliamentarism, shine, practical, maori, robotics, repairs, sybil,
# Nearest to orthodox: congregations, albanian, tractates, scolded, nicaea, canons, davidic, catholic,
# Nearest to alternative: ddd, refurbishment, inactive, dumpster, carbohydrates, grunge, flops, readability,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9324 0.5064 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9828 0.4903 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9216 0.4778 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9494 0.4689 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0389 0.4736 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9217 0.5111 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9715 0.5265 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9832 0.5275 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9608 0.5009 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9434 0.5289 sec/batch
# Nearest to often: zainab, morphemes, reabsorption, musical, myoglobin, flu, espouses, simile,
# Nearest to it: is, that, from, bp, cavern, begin, mcluhan, of,
# Nearest to seven: one, six, three, eight, zero, prentice, four, two,
# Nearest to eight: six, zero, one, four, nine, two, three, seven,
# Nearest to only: muppet, this, podium, cornhuskers, polices, qed, vav, annal,
# Nearest to had: was, sheba, farm, pamphlets, nursed, mckechnie, but, shanahan,
# Nearest to about: orexin, median, dione, arriving, endtime, terrors, show, characterized,
# Nearest to states: united, resumption, between, congress, processing, kitzmiller, ngg, homestead,
# Nearest to question: questions, ought, stranded, metternich, socio, sedating, ipv, psychometric,
# Nearest to http: htm, www, org, com, edu, external, html, comprehensive,
# Nearest to institute: humanities, graduate, research, postgraduate, institutes, school, education, sciences,
# Nearest to applied: ferroelectric, foundational, upsetting, deutsche, monopolized, oj, ashur, hints,
# Nearest to bible: easton, headings, deuteronomy, flavianum, prescribes, tanakh, judaica, translations,
# Nearest to paris: une, parliamentarism, practical, robotics, repairs, maori, shine, supervision,
# Nearest to orthodox: congregations, albanian, canons, nicaea, scolded, davidic, within, diocese,
# Nearest to alternative: refurbishment, ddd, readability, emphasis, dumpster, inactive, grunge, violations,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9553 0.5227 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9461 0.5420 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9190 0.5421 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9597 0.4585 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9708 0.4584 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9564 0.4581 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9141 0.4552 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9213 0.4536 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9293 0.4576 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0171 0.4548 sec/batch
# Nearest to often: zainab, as, reabsorption, strawberry, mokhehle, musical, espouses, morphemes,
# Nearest to it: is, that, bp, mcluhan, from, of, begin, cavern,
# Nearest to seven: one, three, six, eight, zero, four, prentice, two,
# Nearest to eight: six, zero, one, four, nine, three, two, five,
# Nearest to only: this, muppet, podium, cornhuskers, polices, annal, nomination, graced,
# Nearest to had: was, sheba, farm, pamphlets, alexander, but, mckechnie, detail,
# Nearest to about: orexin, dione, arriving, median, endtime, show, endogamy, kook,
# Nearest to states: united, resumption, between, congress, processing, u, ngg, passed,
# Nearest to question: questions, ipv, stranded, metternich, psychometric, ought, subscripts, sedating,
# Nearest to http: htm, www, org, com, external, edu, html, links,
# Nearest to institute: humanities, graduate, institutes, postgraduate, research, neurobiology, education, school,
# Nearest to applied: upsetting, deutsche, ferroelectric, ashur, foundational, hints, oj, monopolized,
# Nearest to bible: easton, headings, deuteronomy, prescribes, flavianum, judaica, tanakh, card,
# Nearest to paris: une, practical, parliamentarism, robotics, shine, sybil, repairs, maori,
# Nearest to orthodox: congregations, albanian, canons, nicaea, scolded, within, davidic, tractates,
# Nearest to alternative: refurbishment, ddd, grunge, alles, readability, inactive, cercozoa, dumpster,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9251 0.4593 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0770 0.4579 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9825 0.4571 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 3.9783 0.4584 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9045 0.4615 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.8791 0.4638 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9468 0.4572 sec/batch
# ...
# Nearest to often: as, usually, considered, throbbing, severity, sometimes, a, aborigines,
# Nearest to it: is, of, the, that, from, was, a, in,
# Nearest to seven: one, three, six, four, eight, five, zero, two,
# Nearest to eight: one, six, four, nine, zero, two, three, five,
# Nearest to only: this, at, that, muppet, annal, a, podium, to,
# Nearest to had: was, were, but, before, made, the, that, early,
# Nearest to about: news, terrors, greatest, utilise, poached, median, sealand, orexin,
# Nearest to states: united, u, congress, pennsylvania, state, refer, resumption, retitled,
# Nearest to question: questions, psychometric, stranded, ought, come, shadowing, what, debate,
# Nearest to http: htm, www, org, edu, com, html, ahn, earthlink,
# Nearest to institute: humanities, institutes, graduate, education, research, nascar, postgraduate, mcm,
# Nearest to applied: ferroelectric, demonstration, sometimes, lithography, kinematics, nucleophile, monopolized, monoids,
# Nearest to bible: flavianum, easton, headings, prescribes, marini, superstar, deuteronomy, graeca,
# Nearest to paris: montparnasse, conservatoire, ais, une, mie, cimeti, lit, fontana,
# Nearest to orthodox: nicaea, orthodoxy, oriental, albanian, judaean, archive, davidic, unaccountable,
# Nearest to alternative: grunge, refurbishment, aldermen, alles, costs, labels, friulian, peninsula,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7669 0.5545 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7777 0.5226 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7971 0.5306 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8027 0.5359 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8348 0.5121 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8122 0.5062 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8272 0.5063 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7908 0.5358 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8254 0.5917 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8133 0.4826 sec/batch
# Nearest to often: as, usually, considered, throbbing, severity, sometimes, humour, devoutly,
# Nearest to it: is, the, of, that, from, in, was, as,
# Nearest to seven: one, three, six, four, eight, five, zero, two,
# Nearest to eight: one, six, zero, four, nine, three, five, two,
# Nearest to only: this, that, at, however, podium, annal, as, to,
# Nearest to had: was, were, before, early, made, but, the, unprecedented,
# Nearest to about: ukrainians, terrors, greatest, news, from, sealand, utilise, spread,
# Nearest to states: united, u, congress, pennsylvania, refer, resumption, state, andres,
# Nearest to question: questions, ambassador, psychometric, stranded, come, shadowing, ought, wootton,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, institutes, graduate, education, research, nascar, mcm, postgraduate,
# Nearest to applied: ferroelectric, gamble, demonstration, industrialists, sometimes, monopolized, nucleophile, ashur,
# Nearest to bible: flavianum, easton, headings, prescribes, marini, graeca, correctly, superstar,
# Nearest to paris: montparnasse, conservatoire, mie, ais, une, parliamentarism, cimeti, supervision,
# Nearest to orthodox: nicaea, orthodoxy, ecumenical, oriental, canons, eastern, congregations, unaccountable,
# Nearest to alternative: grunge, aldermen, refurbishment, costs, alles, peninsula, philosophicus, teslas,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8025 0.5634 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7745 0.5320 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7693 0.5578 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7494 0.5468 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8442 0.5257 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8035 0.5363 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9284 0.5243 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8559 0.5294 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8550 0.5322 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7549 0.5461 sec/batch
# Nearest to often: usually, as, throbbing, considered, sometimes, humour, severity, zainab,
# Nearest to it: is, the, of, that, was, in, from, as,
# Nearest to seven: one, three, six, four, eight, five, zero, two,
# Nearest to eight: one, six, four, zero, three, nine, seven, five,
# Nearest to only: this, at, muppet, as, annal, however, podium, venda,
# Nearest to had: was, were, before, but, made, early, carlsberg, unprecedented,
# Nearest to about: news, ukrainians, terrors, greatest, it, utilise, poached, from,
# Nearest to states: united, u, congress, pennsylvania, state, resumption, andres, refer,
# Nearest to question: questions, psychometric, ought, stranded, ambassador, what, know, answer,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, graduate, institutes, education, research, mcm, nascar, postgraduate,
# Nearest to applied: gamble, demonstration, ferroelectric, sometimes, industrialists, kinematics, nucleophile, monoids,
# Nearest to bible: flavianum, easton, headings, prescribes, graeca, hoch, marini, superstar,
# Nearest to paris: conservatoire, montparnasse, ais, une, mie, cimeti, politique, parliamentarism,
# Nearest to orthodox: nicaea, orthodoxy, congregations, ecumenical, oriental, archive, albanian, unaccountable,
# Nearest to alternative: grunge, aldermen, refurbishment, alles, costs, peninsula, ddd, hispanics,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7039 0.5505 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8149 0.5489 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7333 0.5350 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8311 0.5596 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7607 0.5446 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7983 0.6145 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8139 0.3082 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7762 0.5511 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8060 0.5058 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7890 0.5966 sec/batch
# Nearest to often: usually, as, throbbing, considered, particularly, severity, sometimes, humour,
# Nearest to it: is, the, of, that, from, a, was, to,
# Nearest to seven: one, three, six, four, eight, five, zero, two,
# Nearest to eight: one, six, four, zero, nine, three, seven, five,
# Nearest to only: this, at, as, however, annal, a, podium, that,
# Nearest to had: was, were, before, that, but, made, succeed, nursed,
# Nearest to about: news, ukrainians, terrors, it, utilise, greatest, the, an,
# Nearest to states: united, u, state, pennsylvania, congress, dahlgren, resumption, elks,
# Nearest to question: questions, ought, ambassador, psychometric, stranded, what, know, answer,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, institutes, research, graduate, education, nascar, mcm, neurobiology,
# Nearest to applied: demonstration, sometimes, gamble, ferroelectric, garrisons, ashur, monopolized, lithography,
# Nearest to bible: flavianum, easton, headings, marini, prescribes, graeca, hoch, superstar,
# Nearest to paris: conservatoire, montparnasse, une, ais, mie, cimeti, parliamentarism, lit,
# Nearest to orthodox: nicaea, orthodoxy, archive, congregations, ecumenical, oriental, davidic, albanian,
# Nearest to alternative: grunge, costs, refurbishment, aldermen, alles, such, congeners, hispanics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7577 0.4913 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7688 0.4663 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7793 0.4680 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7241 0.5664 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7796 0.5693 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7666 0.5289 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8383 0.5564 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6967 0.5355 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7638 0.5911 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7570 0.5441 sec/batch
# Nearest to often: usually, as, considered, a, particularly, severity, throbbing, sometimes,
# Nearest to it: the, of, is, that, from, in, a, as,
# Nearest to seven: one, three, four, six, eight, five, zero, two,
# Nearest to eight: one, six, four, zero, five, three, nine, seven,
# Nearest to only: this, at, as, the, however, a, that, to,
# Nearest to had: was, were, before, but, early, made, that, began,
# Nearest to about: news, greatest, utilise, terrors, it, from, spread, ukrainians,
# Nearest to states: united, u, state, nation, refer, pennsylvania, elks, congress,
# Nearest to question: questions, psychometric, ought, what, answer, shadowing, ambassador, stranded,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, institutes, graduate, research, education, mcm, nascar, hogeschool,
# Nearest to applied: ferroelectric, gamble, demonstration, sometimes, nucleophile, monoids, lithography, serviced,
# Nearest to bible: flavianum, easton, headings, deuteronomy, prescribes, marini, translation, graeca,
# Nearest to paris: conservatoire, montparnasse, une, ais, cimeti, mie, lit, politique,
# Nearest to orthodox: orthodoxy, ecumenical, congregations, oriental, nicaea, archive, judaean, davidic,
# Nearest to alternative: grunge, refurbishment, aldermen, costs, alles, hispanics, such, peninsula,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6572 0.5502 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7676 0.5853 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7868 0.5859 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8186 0.5788 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7470 0.6028 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8629 0.6159 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7836 0.5561 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7637 0.5192 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7826 0.5221 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8121 0.5760 sec/batch
# Nearest to often: usually, as, a, severity, particularly, sometimes, throbbing, considered,
# Nearest to it: is, the, of, that, in, from, a, as,
# Nearest to seven: one, three, six, four, eight, five, zero, two,
# Nearest to eight: one, six, four, zero, nine, three, two, five,
# Nearest to only: this, at, however, the, to, as, a, that,
# Nearest to had: was, were, before, but, early, made, began, nursed,
# Nearest to about: news, terrors, greatest, utilise, from, it, the, ukrainians,
# Nearest to states: united, u, refer, pennsylvania, congress, nation, elks, state,
# Nearest to question: questions, what, ought, answer, psychometric, ambassador, stranded, shadowing,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, institutes, graduate, research, education, nascar, mcm, hogeschool,
# Nearest to applied: sometimes, ferroelectric, demonstration, monoids, nucleophile, gamble, oj, monopolized,
# Nearest to bible: flavianum, easton, headings, deuteronomy, prescribes, marini, superstar, judaica,
# Nearest to paris: conservatoire, montparnasse, mie, une, ais, cimeti, france, syringes,
# Nearest to orthodox: orthodoxy, eastern, oriental, ecumenical, nicaea, congregations, davidic, judaean,
# Nearest to alternative: grunge, costs, alles, refurbishment, aldermen, early, such, affords,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8014 0.5741 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7478 0.5650 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7540 0.5740 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7747 0.5545 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7990 0.5389 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8109 0.5561 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7924 0.5554 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8040 0.5228 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7479 0.5189 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7357 0.5008 sec/batch
# Nearest to often: usually, as, severity, particularly, a, simile, throbbing, considered,
# Nearest to it: is, the, of, that, in, from, was, as,
# Nearest to seven: one, three, four, six, five, eight, zero, two,
# Nearest to eight: one, six, four, three, nine, two, five, zero,
# Nearest to only: this, at, however, the, to, as, that, a,
# Nearest to had: was, were, before, early, but, made, in, the,
# Nearest to about: news, terrors, from, of, ukrainians, the, two, some,
# Nearest to states: united, u, nation, refer, state, elks, pennsylvania, congress,
# Nearest to question: questions, answer, psychometric, ought, what, ambassador, stranded, shadowing,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, institutes, graduate, mcm, education, nascar, research, hogeschool,
# Nearest to applied: sometimes, gamble, demonstration, ferroelectric, industrialists, plotted, nucleophile, monopolized,
# Nearest to bible: flavianum, easton, headings, deuteronomy, gunung, prescribes, graeca, superstar,
# Nearest to paris: conservatoire, montparnasse, mie, ais, une, france, cimeti, politique,
# Nearest to orthodox: orthodoxy, ecumenical, nicaea, oriental, eastern, asceticism, davidic, judaean,
# Nearest to alternative: grunge, costs, refurbishment, alles, aldermen, such, affords, friendliness,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8045 0.4855 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7781 0.5070 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8911 0.4851 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8692 0.5853 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8191 0.5148 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7799 0.5452 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7071 0.5433 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8014 0.4684 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6937 0.4956 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8465 0.4780 sec/batch
# Nearest to often: usually, as, severity, humour, particularly, throbbing, generally, considered,
# Nearest to it: is, the, of, that, from, in, was, its,
# Nearest to seven: one, three, four, six, eight, five, zero, two,
# Nearest to eight: one, nine, four, six, two, seven, zero, three,
# Nearest to only: this, at, the, that, however, which, to, podium,
# Nearest to had: was, were, early, before, but, began, decades, that,
# Nearest to about: news, the, terrors, it, ukrainians, from, utilise, an,
# Nearest to states: united, u, elks, state, pennsylvania, congress, nation, refer,
# Nearest to question: questions, what, answer, psychometric, ought, stranded, debate, ambassador,
# Nearest to http: htm, www, org, edu, com, html, earthlink, ahn,
# Nearest to institute: humanities, institutes, mcm, graduate, research, telegraphy, nascar, education,
# Nearest to applied: sometimes, gamble, ferroelectric, demonstration, monopolized, nucleophile, monoids, inversely,
# Nearest to bible: flavianum, easton, headings, gunung, prescribes, superstar, graeca, hoch,
# Nearest to paris: conservatoire, montparnasse, ais, mie, une, cimeti, france, politique,
# Nearest to orthodox: orthodoxy, ecumenical, nicaea, archive, eastern, fours, davidic, asceticism,
# Nearest to alternative: grunge, alles, costs, refurbishment, aldermen, such, friendliness, affords,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7588 0.5058 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7735 0.5256 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
