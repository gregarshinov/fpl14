# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
from collections import Counter
word_counts = Counter(int_words)

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import random
#import math
threshold = 1e-5
freq={}
prob={}
train_words=[]
for word in word_counts:
    freq[word]=word_counts[word]/len(int_words)
    prob[word]=1-np.sqrt(threshold/freq[word])
#print (prob)
for word in int_words:
    if (1-prob[word])>random.random():
        train_words.append(word)

print(len(train_words))
# Out:
# 4625617

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r=random.randint(1,window_size)
    word_window=words[idx-r:idx+r+1]
    
    return word_window

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.random_uniform((n_vocab, n_embedding))) 
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# Џ®¤Ї ЇЄ  Ё«Ё д ©« checkpoints г¦Ґ бгйҐбвўгҐв.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 5
batch_size = 1000
window_size = 3

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph,config=tf.ConfigProto(log_device_placement=True)) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/5 Iteration: 100 Avg. Training loss: 7.5455 0.4945 sec/batch
# Epoch 1/5 Iteration: 200 Avg. Training loss: 7.2303 0.4923 sec/batch
# Epoch 1/5 Iteration: 300 Avg. Training loss: 6.9065 0.4964 sec/batch
# Epoch 1/5 Iteration: 400 Avg. Training loss: 6.7774 0.4927 sec/batch
# Epoch 1/5 Iteration: 500 Avg. Training loss: 6.5923 0.4976 sec/batch
# Epoch 1/5 Iteration: 600 Avg. Training loss: 6.4815 0.4917 sec/batch
# Epoch 1/5 Iteration: 700 Avg. Training loss: 6.3931 0.4934 sec/batch
# Epoch 1/5 Iteration: 800 Avg. Training loss: 6.3269 0.4920 sec/batch
# Epoch 1/5 Iteration: 900 Avg. Training loss: 6.2006 0.4985 sec/batch
# Epoch 1/5 Iteration: 1000 Avg. Training loss: 6.1067 0.5065 sec/batch
# Nearest to in: karaites, recognitions, phospholipid, mubarak, counties, wagering, josh, retook,
# Nearest to into: clowns, glassware, lead, marchibroda, polydentate, literati, beast, graveyard,
# Nearest to state: ogg, advantage, yerushalmi, kimi, lamo, samhain, puff, soapbox,
# Nearest to only: nests, abbess, pleasantville, teleoperation, schumacher, extinct, hobart, lindbergh,
# Nearest to three: heimdallr, garnett, snub, gero, sobib, saunders, notables, sweetheart,
# Nearest to more: unaccustomed, paphos, palomino, apertures, sipe, assent, hindered, unexplained,
# Nearest to is: disorders, argue, hesychasm, tell, revolutionizing, detested, shiftrows, apatosaurus,
# Nearest to states: remit, eysteinn, neuronal, opinionated, theorem, mater, outdated, pmsd,
# Nearest to san: conscripted, quarreling, imdb, recites, framing, unresolved, golovachev, lpu,
# Nearest to writers: hydrophilic, pearls, altay, polic, rit, tonalsoft, admonitions, celta,
# Nearest to quite: fragmenting, fasciculata, bitchx, compton, vetoes, sins, montinari, offenbach,
# Nearest to stage: subshell, resembled, saguinus, lode, danner, mcmartin, zooming, naca,
# Nearest to egypt: cousteau, bluebird, rifles, hyginus, seaport, incredibles, troja, harpersanfrancisco,
# Nearest to arts: prestwich, tidak, geologists, arouse, kickers, rubicon, aerosmith, choc,
# Nearest to recorded: loka, lumpur, dmd, yalta, folklorist, eclipsed, script, subjugation,
# Nearest to versions: bringing, inspirational, vertical, transinformation, computable, charities, dine, shower,
# Epoch 1/5 Iteration: 1100 Avg. Training loss: 6.1234 0.7399 sec/batch
# Epoch 1/5 Iteration: 1200 Avg. Training loss: 6.0165 0.6993 sec/batch
# Epoch 1/5 Iteration: 1300 Avg. Training loss: 5.9929 0.7001 sec/batch
# Epoch 1/5 Iteration: 1400 Avg. Training loss: 5.8964 0.6808 sec/batch
# Epoch 1/5 Iteration: 1500 Avg. Training loss: 5.8891 0.6888 sec/batch
# Epoch 1/5 Iteration: 1600 Avg. Training loss: 5.8383 0.6671 sec/batch
# Epoch 1/5 Iteration: 1700 Avg. Training loss: 5.8141 0.6811 sec/batch
# Epoch 1/5 Iteration: 1800 Avg. Training loss: 5.7893 0.6634 sec/batch
# Epoch 1/5 Iteration: 1900 Avg. Training loss: 5.7457 0.6707 sec/batch
# Epoch 1/5 Iteration: 2000 Avg. Training loss: 5.7197 0.6794 sec/batch
# Nearest to in: karaites, recognitions, mubarak, retook, phospholipid, josh, counties, crowned,
# Nearest to into: clowns, lead, glassware, marchibroda, polydentate, stefan, graveyard, literati,
# Nearest to state: ogg, advantage, kimi, yerushalmi, lamo, samhain, puff, spartans,
# Nearest to only: nests, abbess, pleasantville, schumacher, djbdns, teleoperation, abul, extinct,
# Nearest to three: heimdallr, gero, garnett, notables, snub, sobib, eked, rockies,
# Nearest to more: unaccustomed, apertures, paphos, palomino, clergy, assent, macassar, sipe,
# Nearest to is: disorders, argue, hesychasm, barter, revolutionizing, tell, tumour, yyyy,
# Nearest to states: remit, opinionated, eysteinn, neuronal, theorem, mater, pmsd, outdated,
# Nearest to san: conscripted, quarreling, recites, framing, golovachev, unresolved, imdb, disappearance,
# Nearest to writers: hydrophilic, pearls, polic, altay, tonalsoft, rit, iguana, sacramento,
# Nearest to quite: fragmenting, fasciculata, bitchx, sins, vetoes, compton, pisin, montinari,
# Nearest to stage: subshell, resembled, lode, saguinus, zooming, danner, naca, mcmartin,
# Nearest to egypt: seaport, bluebird, cousteau, hyginus, rifles, incredibles, harpersanfrancisco, staring,
# Nearest to arts: prestwich, tidak, geologists, kickers, arouse, rubicon, aerosmith, choc,
# Nearest to recorded: loka, yalta, dmd, lumpur, eclipsed, folklorist, hints, solitaire,
# Nearest to versions: bringing, vertical, inspirational, transinformation, charities, missed, stimuli, dine,
# Epoch 1/5 Iteration: 2100 Avg. Training loss: 5.7028 0.6888 sec/batch
# Epoch 1/5 Iteration: 2200 Avg. Training loss: 5.6773 0.6549 sec/batch
# Epoch 1/5 Iteration: 2300 Avg. Training loss: 5.6329 0.6542 sec/batch
# Epoch 1/5 Iteration: 2400 Avg. Training loss: 5.6000 0.6611 sec/batch
# Epoch 1/5 Iteration: 2500 Avg. Training loss: 5.4770 0.6620 sec/batch
# Epoch 1/5 Iteration: 2600 Avg. Training loss: 5.5324 0.6605 sec/batch
# Epoch 1/5 Iteration: 2700 Avg. Training loss: 5.4952 0.6483 sec/batch
# Epoch 1/5 Iteration: 2800 Avg. Training loss: 5.4405 0.5210 sec/batch
# Epoch 1/5 Iteration: 2900 Avg. Training loss: 5.4863 0.4923 sec/batch
# Epoch 1/5 Iteration: 3000 Avg. Training loss: 5.4221 0.4946 sec/batch
# Nearest to in: karaites, recognitions, classes, below, jurchen, crowned, josh, phospholipid,
# Nearest to into: clowns, lead, graveyard, stefan, glassware, marchibroda, deafblind, dwell,
# Nearest to state: ogg, advantage, soapbox, yerushalmi, kimi, je, lamo, samhain,
# Nearest to only: nests, pleasantville, abul, abbess, teleoperation, djbdns, pup, extinct,
# Nearest to three: heimdallr, notables, eked, snub, recordable, garnett, gero, heretic,
# Nearest to more: unaccustomed, palomino, paphos, apertures, monadology, baire, macassar, assent,
# Nearest to is: disorders, argue, hesychasm, satan, adversary, barter, tell, yyyy,
# Nearest to states: remit, neuronal, clearwater, opinionated, theorem, mater, eysteinn, outdated,
# Nearest to san: conscripted, quarreling, recites, framing, golovachev, disappearance, shi, unresolved,
# Nearest to writers: hydrophilic, pearls, rit, polic, altay, tonalsoft, sacramento, celta,
# Nearest to quite: fragmenting, bitchx, fasciculata, vetoes, sins, pisin, compton, offenbach,
# Nearest to stage: subshell, saguinus, resembled, zooming, danner, lode, mcmartin, rebuilding,
# Nearest to egypt: bluebird, seaport, cousteau, hyginus, incredibles, staring, information, troja,
# Nearest to arts: prestwich, geologists, tidak, kickers, arouse, rubicon, aerosmith, gautama,
# Nearest to recorded: lumpur, loka, yalta, dmd, eclipsed, solitaire, refueling, hints,
# Nearest to versions: bringing, vertical, transinformation, inspirational, missed, charities, artifacts, stimuli,
# Epoch 1/5 Iteration: 3100 Avg. Training loss: 5.4034 0.5016 sec/batch
# Epoch 1/5 Iteration: 3200 Avg. Training loss: 5.3313 0.4926 sec/batch
# Epoch 1/5 Iteration: 3300 Avg. Training loss: 5.3807 0.4950 sec/batch
# Epoch 1/5 Iteration: 3400 Avg. Training loss: 5.3155 0.4994 sec/batch
# Epoch 1/5 Iteration: 3500 Avg. Training loss: 5.2951 0.4940 sec/batch
# Epoch 1/5 Iteration: 3600 Avg. Training loss: 5.2744 0.4927 sec/batch
# Epoch 1/5 Iteration: 3700 Avg. Training loss: 5.2332 0.4934 sec/batch
# Epoch 1/5 Iteration: 3800 Avg. Training loss: 5.1514 0.4937 sec/batch
# Epoch 1/5 Iteration: 3900 Avg. Training loss: 5.1939 0.4924 sec/batch
# Epoch 1/5 Iteration: 4000 Avg. Training loss: 5.1491 0.4968 sec/batch
# Nearest to in: the, of, zero, and, with, that, below, karaites,
# Nearest to into: lead, clowns, graveyard, stefan, prolonged, unsuspected, philosophicus, calvary,
# Nearest to state: ogg, advantage, soapbox, je, kimi, demerara, samhain, puff,
# Nearest to only: nests, for, abul, circumstance, pleasantville, djbdns, resembles, cipher,
# Nearest to three: two, heimdallr, eked, snub, notables, and, nine, beets,
# Nearest to more: monadology, palomino, unaccustomed, baire, athenaeus, clergy, apertures, macassar,
# Nearest to is: disorders, argue, adversary, satan, human, hesychasm, tell, barter,
# Nearest to states: remit, theorem, neuronal, prices, clearwater, ladakh, landesverband, mater,
# Nearest to san: conscripted, recites, framing, included, quarreling, quranic, golovachev, shi,
# Nearest to writers: hydrophilic, pearls, rit, social, tonalsoft, altay, sacramento, auxin,
# Nearest to quite: fragmenting, fasciculata, bitchx, pisin, vetoes, sins, offenbach, eugenio,
# Nearest to stage: subshell, rebuilding, saguinus, danner, zooming, lode, resembled, sonorous,
# Nearest to egypt: seaport, cousteau, bluebird, hyginus, incredibles, staring, troja, information,
# Nearest to arts: tidak, prestwich, geologists, arouse, kickers, aerosmith, prolog, rubicon,
# Nearest to recorded: yalta, lumpur, dmd, refueling, hints, loka, eclipsed, solitaire,
# Nearest to versions: bringing, vertical, transinformation, missed, inspirational, charities, emanating, artifacts,
# Epoch 1/5 Iteration: 4100 Avg. Training loss: 5.0721 0.5110 sec/batch
# Epoch 1/5 Iteration: 4200 Avg. Training loss: 5.0826 0.4953 sec/batch
# Epoch 1/5 Iteration: 4300 Avg. Training loss: 5.0509 0.4941 sec/batch
# Epoch 1/5 Iteration: 4400 Avg. Training loss: 5.0041 0.4964 sec/batch
# Epoch 1/5 Iteration: 4500 Avg. Training loss: 5.0039 0.4969 sec/batch
# Epoch 1/5 Iteration: 4600 Avg. Training loss: 4.9865 0.4906 sec/batch
# Epoch 2/5 Iteration: 4700 Avg. Training loss: 4.9515 0.3723 sec/batch
# Epoch 2/5 Iteration: 4800 Avg. Training loss: 4.8951 0.4910 sec/batch
# Epoch 2/5 Iteration: 4900 Avg. Training loss: 4.8137 0.4923 sec/batch
# Epoch 2/5 Iteration: 5000 Avg. Training loss: 4.7666 0.4897 sec/batch
# Nearest to in: of, the, and, zero, with, that, one, was,
# Nearest to into: for, lead, prolonged, unable, doubling, clowns, bassam, peace,
# Nearest to state: advantage, ogg, soapbox, from, phrase, demerara, petroleum, copyright,
# Nearest to only: for, the, of, is, nests, an, abul, circumstance,
# Nearest to three: two, nine, one, and, zero, diverted, four, eked,
# Nearest to more: monadology, palomino, arms, what, imdb, rules, references, athenaeus,
# Nearest to is: as, a, to, human, of, the, after, satan,
# Nearest to states: prices, theorem, remit, neuronal, united, coast, metabolized, clearwater,
# Nearest to san: conscripted, recites, framing, zero, included, quranic, quarreling, imdb,
# Nearest to writers: hydrophilic, social, rit, pearls, tonalsoft, altay, revival, part,
# Nearest to quite: pisin, fasciculata, vetoes, fragmenting, bitchx, eugenio, sins, sits,
# Nearest to stage: rebuilding, subshell, zooming, saguinus, danner, simpson, coastline, fatal,
# Nearest to egypt: seaport, cousteau, bluebird, hyginus, information, staring, harpersanfrancisco, rifles,
# Nearest to arts: tidak, prestwich, geologists, arouse, kickers, aerosmith, prolog, lejeune,
# Nearest to recorded: yalta, eclipsed, lumpur, refueling, dmd, hints, anemometers, loka,
# Nearest to versions: bringing, vertical, transinformation, dine, emanating, missed, artifacts, shower,
# Epoch 2/5 Iteration: 5100 Avg. Training loss: 4.7554 0.5012 sec/batch
# Epoch 2/5 Iteration: 5200 Avg. Training loss: 4.7126 0.4914 sec/batch
# Epoch 2/5 Iteration: 5300 Avg. Training loss: 4.6520 0.4961 sec/batch
# Epoch 2/5 Iteration: 5400 Avg. Training loss: 4.7027 0.4927 sec/batch
# Epoch 2/5 Iteration: 5500 Avg. Training loss: 4.6376 0.4926 sec/batch
# Epoch 2/5 Iteration: 5600 Avg. Training loss: 4.6087 0.4909 sec/batch
# Epoch 2/5 Iteration: 5700 Avg. Training loss: 4.5909 0.4951 sec/batch
# Epoch 2/5 Iteration: 5800 Avg. Training loss: 4.5063 0.4918 sec/batch
# Epoch 2/5 Iteration: 5900 Avg. Training loss: 4.5352 0.5026 sec/batch
# Epoch 2/5 Iteration: 6000 Avg. Training loss: 4.4977 0.4893 sec/batch
# Nearest to in: of, was, and, from, where, zero, on, the,
# Nearest to into: lead, for, so, prolonged, traditions, unable, regard, to,
# Nearest to state: advantage, ogg, from, soapbox, copyright, petroleum, phrase, etymology,
# Nearest to only: for, is, the, on, an, of, lose, nests,
# Nearest to three: two, zero, nine, one, four, five, eight, seven,
# Nearest to more: what, rules, for, monadology, references, the, arms, with,
# Nearest to is: as, a, that, not, for, only, of, while,
# Nearest to states: united, coast, prices, theorem, its, countries, remit, later,
# Nearest to san: conscripted, framing, included, quranic, recites, strongest, disappearance, shi,
# Nearest to writers: social, hydrophilic, part, rit, pearls, revival, less, rigdon,
# Nearest to quite: pisin, fasciculata, most, sins, bitchx, fragmenting, sits, vetoes,
# Nearest to stage: rebuilding, formed, subshell, simpson, saguinus, sources, fatal, announcement,
# Nearest to egypt: seaport, information, cousteau, bluebird, hyginus, harpersanfrancisco, of, osama,
# Nearest to arts: prestwich, tidak, arouse, geologists, prolog, xi, kickers, aerosmith,
# Nearest to recorded: yalta, refueling, by, dmd, eclipsed, anemometers, understand, can,
# Nearest to versions: bringing, vertical, artifacts, transinformation, dine, missed, computable, shower,
# Epoch 2/5 Iteration: 6100 Avg. Training loss: 4.5030 0.5044 sec/batch
# Epoch 2/5 Iteration: 6200 Avg. Training loss: 4.4469 0.4904 sec/batch
# Epoch 2/5 Iteration: 6300 Avg. Training loss: 4.4469 0.4989 sec/batch
# Epoch 2/5 Iteration: 6400 Avg. Training loss: 4.3968 0.4913 sec/batch
# Epoch 2/5 Iteration: 6500 Avg. Training loss: 4.4064 0.5236 sec/batch
# Epoch 2/5 Iteration: 6600 Avg. Training loss: 4.4167 0.8735 sec/batch
# Epoch 2/5 Iteration: 6700 Avg. Training loss: 4.3460 0.9411 sec/batch
# Epoch 2/5 Iteration: 6800 Avg. Training loss: 4.3473 0.5644 sec/batch
# Epoch 2/5 Iteration: 6900 Avg. Training loss: 4.3842 0.5741 sec/batch
# Epoch 2/5 Iteration: 7000 Avg. Training loss: 4.3135 0.5551 sec/batch
# Nearest to in: where, classes, include, zero, was, may, from, at,
# Nearest to into: lead, so, traditions, prolonged, for, its, regard, unable,
# Nearest to state: advantage, ogg, from, copyright, soapbox, phrase, etymology, controls,
# Nearest to only: is, who, for, on, an, lose, beliefs, example,
# Nearest to three: two, zero, four, nine, one, five, eight, seven,
# Nearest to more: what, rules, but, your, monadology, clergy, even, identity,
# Nearest to is: as, not, it, that, can, example, a, should,
# Nearest to states: united, coast, countries, prices, theorem, general, part, entered,
# Nearest to san: conscripted, included, framing, strongest, recites, quranic, regular, disappearance,
# Nearest to writers: social, revival, hydrophilic, pearls, less, part, violations, sacramento,
# Nearest to quite: most, pisin, sins, fasciculata, vetoes, sits, fragmenting, bitchx,
# Nearest to stage: formed, rebuilding, coastline, announcement, sources, scientific, fatal, simpson,
# Nearest to egypt: seaport, information, cousteau, of, harpersanfrancisco, osama, times, bluebird,
# Nearest to arts: geologists, prestwich, prolog, tidak, arouse, dense, together, xi,
# Nearest to recorded: by, refueling, eclipsed, yalta, immediately, simply, attempts, understand,
# Nearest to versions: bringing, vertical, artifacts, missed, dine, transinformation, alice, shower,
# Epoch 2/5 Iteration: 7100 Avg. Training loss: 4.2719 0.6490 sec/batch
# Epoch 2/5 Iteration: 7200 Avg. Training loss: 4.2822 0.5536 sec/batch
# Epoch 2/5 Iteration: 7300 Avg. Training loss: 4.2302 0.6509 sec/batch
# Epoch 2/5 Iteration: 7400 Avg. Training loss: 4.2754 0.5178 sec/batch
# Epoch 2/5 Iteration: 7500 Avg. Training loss: 4.2561 0.4946 sec/batch
# Epoch 2/5 Iteration: 7600 Avg. Training loss: 4.2291 0.4992 sec/batch
# Epoch 2/5 Iteration: 7700 Avg. Training loss: 4.2336 0.5173 sec/batch
# Epoch 2/5 Iteration: 7800 Avg. Training loss: 4.2268 0.5754 sec/batch
# Epoch 2/5 Iteration: 7900 Avg. Training loss: 4.1609 0.5513 sec/batch
# Epoch 2/5 Iteration: 8000 Avg. Training loss: 4.1605 0.4983 sec/batch
# Nearest to in: where, may, war, permanent, country, demographic, century, air,
# Nearest to into: lead, so, its, traditions, prolonged, regard, defending, smaller,
# Nearest to state: advantage, ogg, etymology, copyright, from, phrase, soapbox, controls,
# Nearest to only: on, lose, sides, above, beliefs, really, for, consider,
# Nearest to three: two, four, zero, five, nine, eight, one, six,
# Nearest to more: what, rules, than, identity, your, but, monadology, clergy,
# Nearest to is: it, possible, example, can, if, should, as, important,
# Nearest to states: united, coast, countries, immigration, prices, general, part, owned,
# Nearest to san: conscripted, framing, included, quranic, strongest, portrayal, shi, arrived,
# Nearest to writers: revival, social, hydrophilic, violations, pearls, part, stronger, lament,
# Nearest to quite: most, pisin, sins, sits, fragmenting, membership, fasciculata, legal,
# Nearest to stage: formed, rebuilding, sources, scientific, fatal, first, simpson, coastline,
# Nearest to egypt: seaport, times, information, osama, of, cousteau, harpersanfrancisco, hyginus,
# Nearest to arts: geologists, masses, dense, prolog, together, prestwich, xi, tidak,
# Nearest to recorded: eclipsed, simply, immediately, refueling, yalta, by, hints, first,
# Nearest to versions: bringing, vertical, artifacts, protecting, missed, transinformation, dine, emanating,
# Epoch 2/5 Iteration: 8100 Avg. Training loss: 4.1635 0.5064 sec/batch
# Epoch 2/5 Iteration: 8200 Avg. Training loss: 4.1762 0.5402 sec/batch
# Epoch 2/5 Iteration: 8300 Avg. Training loss: 4.1680 0.5555 sec/batch
# Epoch 2/5 Iteration: 8400 Avg. Training loss: 4.1399 0.6751 sec/batch
# Epoch 2/5 Iteration: 8500 Avg. Training loss: 4.1520 1.1165 sec/batch
# Epoch 2/5 Iteration: 8600 Avg. Training loss: 4.0705 1.0939 sec/batch
# Epoch 2/5 Iteration: 8700 Avg. Training loss: 4.1010 1.1386 sec/batch
# Epoch 2/5 Iteration: 8800 Avg. Training loss: 4.1051 1.0708 sec/batch
# Epoch 2/5 Iteration: 8900 Avg. Training loss: 4.0289 1.0746 sec/batch
# Epoch 2/5 Iteration: 9000 Avg. Training loss: 4.0819 0.8204 sec/batch
# Nearest to in: permanent, where, country, war, demographic, century, interim, world,
# Nearest to into: lead, traditions, its, prolonged, so, exhausting, smaller, caused,
# Nearest to state: advantage, etymology, controls, ogg, u, highway, soapbox, copyright,
# Nearest to only: lose, above, consider, really, not, on, beliefs, sides,
# Nearest to three: four, two, zero, nine, one, eight, seven, five,
# Nearest to more: than, what, rules, less, monadology, value, your, clergy,
# Nearest to is: example, usually, possible, if, above, note, case, object,
# Nearest to states: united, countries, immigration, coast, president, general, district, u,
# Nearest to san: conscripted, strongest, quranic, framing, included, arrived, eyewitness, francisco,
# Nearest to writers: revival, social, lament, hydrophilic, pearls, violations, stronger, colonization,
# Nearest to quite: sins, most, practice, pisin, condemn, isn, sits, membership,
# Nearest to stage: formed, rebuilding, sources, simpson, teams, trumpeter, coastline, home,
# Nearest to egypt: seaport, times, osama, cousteau, ephraim, public, third, harpersanfrancisco,
# Nearest to arts: geologists, membership, masses, prolog, together, arouse, dense, xi,
# Nearest to recorded: eclipsed, refueling, acre, yalta, immediately, hints, academies, simply,
# Nearest to versions: bringing, vertical, artifacts, shower, emanating, alice, dine, charities,
# Epoch 2/5 Iteration: 9100 Avg. Training loss: 4.0695 1.2613 sec/batch
# Epoch 2/5 Iteration: 9200 Avg. Training loss: 4.0381 0.8313 sec/batch
# Epoch 3/5 Iteration: 9300 Avg. Training loss: 4.0551 0.4973 sec/batch
# Epoch 3/5 Iteration: 9400 Avg. Training loss: 3.9953 0.7203 sec/batch
# Epoch 3/5 Iteration: 9500 Avg. Training loss: 3.9604 0.7213 sec/batch
# Epoch 3/5 Iteration: 9600 Avg. Training loss: 3.9447 1.1401 sec/batch
# Epoch 3/5 Iteration: 9700 Avg. Training loss: 3.9372 1.1537 sec/batch
# Epoch 3/5 Iteration: 9800 Avg. Training loss: 3.9331 1.0994 sec/batch
# Epoch 3/5 Iteration: 9900 Avg. Training loss: 3.9052 1.1284 sec/batch
# Epoch 3/5 Iteration: 10000 Avg. Training loss: 3.8522 0.9683 sec/batch
# Nearest to in: permanent, panther, ballet, war, century, emigrate, include, sheedy,
# Nearest to into: lead, exhausting, its, traditions, prolonged, smaller, insect, each,
# Nearest to state: advantage, controls, u, etymology, ogg, soapbox, copyright, highway,
# Nearest to only: above, really, not, nests, construct, lose, value, sides,
# Nearest to three: four, zero, two, eight, nine, seven, six, one,
# Nearest to more: than, rules, monadology, what, terminal, waits, capable, techniques,
# Nearest to is: example, usually, note, disorders, exists, important, above, characteristics,
# Nearest to states: united, countries, coast, immigration, district, president, south, general,
# Nearest to san: conscripted, strongest, francisco, framing, quranic, included, arrived, michael,
# Nearest to writers: revival, lament, tony, pearls, social, hydrophilic, violations, rite,
# Nearest to quite: sins, practice, pisin, most, sits, true, condemn, prose,
# Nearest to stage: formed, rebuilding, teams, space, fatal, simpson, sources, carrier,
# Nearest to egypt: seaport, osama, times, arabia, public, cousteau, of, constitution,
# Nearest to arts: geologists, membership, masses, arouse, prolog, prestwich, xi, together,
# Nearest to recorded: eclipsed, acre, academies, immediately, refueling, graduating, hints, weakened,
# Nearest to versions: bringing, vertical, shower, emanating, artifacts, dine, alice, stimuli,
# Epoch 3/5 Iteration: 10100 Avg. Training loss: 3.9279 1.1672 sec/batch
# Epoch 3/5 Iteration: 10200 Avg. Training loss: 3.8757 0.8243 sec/batch
# Epoch 3/5 Iteration: 10300 Avg. Training loss: 3.8543 0.8379 sec/batch
# Epoch 3/5 Iteration: 10400 Avg. Training loss: 3.7680 1.1795 sec/batch
# Epoch 3/5 Iteration: 10500 Avg. Training loss: 3.8260 1.0559 sec/batch
# Epoch 3/5 Iteration: 10600 Avg. Training loss: 3.8216 1.0566 sec/batch
# Epoch 3/5 Iteration: 10700 Avg. Training loss: 3.8274 0.8615 sec/batch
# Epoch 3/5 Iteration: 10800 Avg. Training loss: 3.8163 0.6460 sec/batch
# Epoch 3/5 Iteration: 10900 Avg. Training loss: 3.8163 0.5922 sec/batch
# Epoch 3/5 Iteration: 11000 Avg. Training loss: 3.7953 0.6893 sec/batch
# Nearest to in: recognitions, laura, demographic, postal, interim, panther, permanent, ballet,
# Nearest to into: lead, transformed, smaller, exhausting, tandy, prolonged, insect, epiphanes,
# Nearest to state: u, ogg, advantage, council, controls, etymology, united, soapbox,
# Nearest to only: lose, construct, not, nests, really, person, above, we,
# Nearest to three: four, zero, two, seven, eight, five, nine, six,
# Nearest to more: than, capable, less, waits, terminal, rules, identity, arrow,
# Nearest to is: example, usually, exists, meaning, quantum, characteristic, above, disorders,
# Nearest to states: united, countries, immigration, coast, district, president, urged, owned,
# Nearest to san: francisco, strongest, conscripted, quranic, framing, included, senior, missouri,
# Nearest to writers: lament, revival, tony, endowment, sacramento, pearls, bryan, clubhouse,
# Nearest to quite: sins, practice, true, fundamental, inflections, assertions, philosophic, eugenio,
# Nearest to stage: formed, rebuilding, simpson, teams, ordered, space, fatal, annoy,
# Nearest to egypt: seaport, osama, arabia, coastline, constitution, ephraim, cousteau, times,
# Nearest to arts: geologists, membership, prestwich, students, privations, prolog, cuba, inspirations,
# Nearest to recorded: eclipsed, acre, academies, refueling, during, dave, prophesied, truce,
# Nearest to versions: bringing, vertical, shower, emanating, stimuli, artifacts, computer, computable,
# Epoch 3/5 Iteration: 11100 Avg. Training loss: 3.8087 0.5773 sec/batch
# Epoch 3/5 Iteration: 11200 Avg. Training loss: 3.8238 0.5641 sec/batch
# Epoch 3/5 Iteration: 11300 Avg. Training loss: 3.7735 0.5816 sec/batch
# Epoch 3/5 Iteration: 11400 Avg. Training loss: 3.7572 0.5758 sec/batch
# Epoch 3/5 Iteration: 11500 Avg. Training loss: 3.7964 0.5798 sec/batch
# Epoch 3/5 Iteration: 11600 Avg. Training loss: 3.7457 0.5398 sec/batch
# Epoch 3/5 Iteration: 11700 Avg. Training loss: 3.7641 0.5385 sec/batch
# Epoch 3/5 Iteration: 11800 Avg. Training loss: 3.6809 0.7661 sec/batch
# Epoch 3/5 Iteration: 11900 Avg. Training loss: 3.6791 1.1202 sec/batch
# Epoch 3/5 Iteration: 12000 Avg. Training loss: 3.7484 1.0329 sec/batch
# Nearest to in: recognitions, demographic, laura, permanent, exported, sheedy, postal, ballet,
# Nearest to into: transformed, exhausting, smaller, epiphanes, homosexual, lead, dearly, housekeeping,
# Nearest to state: u, controls, council, advantage, ogg, etymology, constitutional, promotion,
# Nearest to only: not, construct, above, lose, really, we, if, parameters,
# Nearest to three: four, zero, two, eight, five, seven, one, six,
# Nearest to more: than, capable, monadology, common, less, otherwise, terminal, identity,
# Nearest to is: example, note, meaning, usually, characteristic, exists, above, equal,
# Nearest to states: united, countries, immigration, district, president, member, commonwealth, coast,
# Nearest to san: francisco, strongest, quranic, conscripted, pius, framing, rudolph, michael,
# Nearest to writers: revival, lament, tony, inspired, bryan, rite, science, clubhouse,
# Nearest to quite: sins, fundamental, true, practice, method, think, eugenio, curtail,
# Nearest to stage: teams, rebuilding, formed, simpson, exogenous, ordered, discrimination, feathers,
# Nearest to egypt: seaport, osama, coastline, arabia, constitution, arab, egyptians, ephraim,
# Nearest to arts: geologists, prestwich, privations, membership, inspirations, presented, students, clarence,
# Nearest to recorded: eclipsed, acre, academies, truce, ever, mediated, she, refueling,
# Nearest to versions: bringing, vertical, shower, computer, charities, emanating, systems, artifacts,
# Epoch 3/5 Iteration: 12100 Avg. Training loss: 3.7368 1.1495 sec/batch
# Epoch 3/5 Iteration: 12200 Avg. Training loss: 3.7239 1.1718 sec/batch
# Epoch 3/5 Iteration: 12300 Avg. Training loss: 3.7113 1.1021 sec/batch
# Epoch 3/5 Iteration: 12400 Avg. Training loss: 3.7307 0.7188 sec/batch
# Epoch 3/5 Iteration: 12500 Avg. Training loss: 3.6766 0.4914 sec/batch
# Epoch 3/5 Iteration: 12600 Avg. Training loss: 3.6651 0.4921 sec/batch
# Epoch 3/5 Iteration: 12700 Avg. Training loss: 3.6831 0.4845 sec/batch
# Epoch 3/5 Iteration: 12800 Avg. Training loss: 3.6109 0.4829 sec/batch
# Epoch 3/5 Iteration: 12900 Avg. Training loss: 3.7112 0.4866 sec/batch
# Epoch 3/5 Iteration: 13000 Avg. Training loss: 3.7294 0.4810 sec/batch
# Nearest to in: laura, interim, frederik, recognitions, panther, completed, demographic, sheedy,
# Nearest to into: transformed, situated, housekeeping, exhausting, tandy, epiphanes, homosexual, insect,
# Nearest to state: u, council, states, cabinet, controls, united, district, nguyen,
# Nearest to only: lose, construct, above, person, not, economies, superior, if,
# Nearest to three: four, zero, eight, seven, two, five, one, six,
# Nearest to more: than, monadology, waits, capable, less, casual, terminal, common,
# Nearest to is: note, meaning, savior, example, ritalin, triangle, hesychasm, quantum,
# Nearest to states: united, countries, immigration, district, member, president, u, commonwealth,
# Nearest to san: francisco, rudolph, michael, quranic, senior, conscripted, strongest, rhodes,
# Nearest to writers: revival, science, fiction, lament, novelists, stories, bryan, authors,
# Nearest to quite: sins, true, think, forms, assertions, merits, fundamental, curtail,
# Nearest to stage: formed, rebuilding, teams, discrimination, simpson, whitehouse, feathers, trumpeter,
# Nearest to egypt: seaport, arabia, osama, arab, coastline, egyptians, ephraim, israel,
# Nearest to arts: membership, prestwich, students, clarence, style, geologists, privations, presented,
# Nearest to recorded: eclipsed, ever, acre, band, singles, kahanamoku, academies, album,
# Nearest to versions: computer, systems, vertical, specification, bringing, extensions, shower, emanating,
# Epoch 3/5 Iteration: 13100 Avg. Training loss: 3.7113 0.4984 sec/batch
# Epoch 3/5 Iteration: 13200 Avg. Training loss: 3.5876 0.4810 sec/batch
# Epoch 3/5 Iteration: 13300 Avg. Training loss: 3.6539 0.4832 sec/batch
# Epoch 3/5 Iteration: 13400 Avg. Training loss: 3.6405 0.4815 sec/batch
# Epoch 3/5 Iteration: 13500 Avg. Training loss: 3.5698 0.4779 sec/batch
# Epoch 3/5 Iteration: 13600 Avg. Training loss: 3.6157 0.4874 sec/batch
# Epoch 3/5 Iteration: 13700 Avg. Training loss: 3.6506 0.4852 sec/batch
# Epoch 3/5 Iteration: 13800 Avg. Training loss: 3.6063 0.4833 sec/batch
# Epoch 4/5 Iteration: 13900 Avg. Training loss: 3.6661 0.1219 sec/batch
# Epoch 4/5 Iteration: 14000 Avg. Training loss: 3.5950 0.4847 sec/batch
# Nearest to in: panther, completed, sheedy, laura, frisia, permanent, demographic, frederik,
# Nearest to into: transformed, exhausting, tandy, situated, housekeeping, heterocyclic, accommodating, insect,
# Nearest to state: states, u, district, council, missouri, highway, formed, united,
# Nearest to only: construct, lose, person, not, if, skimmed, above, lombardic,
# Nearest to three: four, zero, eight, two, six, one, seven, five,
# Nearest to more: than, casual, waits, monadology, less, capable, useful, terminal,
# Nearest to is: ritalin, meaning, characteristic, note, exists, representations, triangle, quantum,
# Nearest to states: united, countries, immigration, district, member, constitution, commonwealth, mexico,
# Nearest to san: francisco, rudolph, jose, rhodes, senior, arrived, missouri, quranic,
# Nearest to writers: revival, fiction, authors, novelists, lament, stories, science, readers,
# Nearest to quite: true, sins, assertions, practice, think, inflections, condemn, pretext,
# Nearest to stage: teams, trumpeter, annoy, mlb, performance, discrimination, feathers, simpson,
# Nearest to egypt: seaport, arabia, osama, arab, coastline, egyptians, sudan, israel,
# Nearest to arts: students, prestwich, membership, style, geologists, presented, clarence, inspirations,
# Nearest to recorded: band, ever, album, eclipsed, acre, singles, kahanamoku, summer,
# Nearest to versions: computer, systems, version, extensions, shower, windows, software, specification,
# Epoch 4/5 Iteration: 14100 Avg. Training loss: 3.5602 0.5080 sec/batch
# Epoch 4/5 Iteration: 14200 Avg. Training loss: 3.5557 0.4845 sec/batch
# Epoch 4/5 Iteration: 14300 Avg. Training loss: 3.5454 0.4836 sec/batch
# Epoch 4/5 Iteration: 14400 Avg. Training loss: 3.5501 0.4845 sec/batch
# Epoch 4/5 Iteration: 14500 Avg. Training loss: 3.5446 0.4822 sec/batch
# Epoch 4/5 Iteration: 14600 Avg. Training loss: 3.4690 0.4859 sec/batch
# Epoch 4/5 Iteration: 14700 Avg. Training loss: 3.5354 0.4844 sec/batch
# Epoch 4/5 Iteration: 14800 Avg. Training loss: 3.5679 0.4852 sec/batch
# Epoch 4/5 Iteration: 14900 Avg. Training loss: 3.5331 0.7565 sec/batch
# Epoch 4/5 Iteration: 15000 Avg. Training loss: 3.4417 0.4914 sec/batch
# Nearest to in: laura, sheedy, completed, frederik, panther, stra, recognitions, discounted,
# Nearest to into: transformed, situated, tandy, insect, exhausting, housekeeping, heterocyclic, divided,
# Nearest to state: states, district, u, council, municipalities, independent, missouri, prime,
# Nearest to only: lose, construct, not, lombardic, person, hira, eventual, dominate,
# Nearest to three: four, zero, seven, eight, unpaved, two, one, six,
# Nearest to more: than, less, monadology, casual, waits, capable, terminal, huge,
# Nearest to is: note, triangle, ritalin, meaning, equal, representations, above, exists,
# Nearest to states: united, countries, immigration, district, member, constitution, commonwealth, state,
# Nearest to san: francisco, jose, rudolph, diego, rhodes, missouri, strongest, puerto,
# Nearest to writers: novelists, authors, fiction, literature, stories, science, revival, readers,
# Nearest to quite: merits, true, inflections, sins, illustrates, pretext, poison, condemn,
# Nearest to stage: mlb, performance, whitehouse, feathers, annoy, wonderland, candle, decimal,
# Nearest to egypt: arabia, seaport, arab, osama, egyptians, sudan, israel, coastline,
# Nearest to arts: students, prestwich, style, presented, membership, school, clarence, inspirations,
# Nearest to recorded: band, album, ever, singles, debut, acre, kahanamoku, billboard,
# Nearest to versions: computer, systems, version, operating, functionality, specifications, shower, windows,
# Epoch 4/5 Iteration: 15100 Avg. Training loss: 3.4427 0.5387 sec/batch
# Epoch 4/5 Iteration: 15200 Avg. Training loss: 3.4680 0.6065 sec/batch
# Epoch 4/5 Iteration: 15300 Avg. Training loss: 3.4771 0.4821 sec/batch
# Epoch 4/5 Iteration: 15400 Avg. Training loss: 3.4937 0.4817 sec/batch
# Epoch 4/5 Iteration: 15500 Avg. Training loss: 3.4596 0.4801 sec/batch
# Epoch 4/5 Iteration: 15600 Avg. Training loss: 3.4573 0.4787 sec/batch
# Epoch 4/5 Iteration: 15700 Avg. Training loss: 3.4777 0.4839 sec/batch
# Epoch 4/5 Iteration: 15800 Avg. Training loss: 3.5112 0.4811 sec/batch
# Epoch 4/5 Iteration: 15900 Avg. Training loss: 3.4422 0.5137 sec/batch
# Epoch 4/5 Iteration: 16000 Avg. Training loss: 3.4454 0.4823 sec/batch
# Nearest to in: sheedy, dichromate, exported, laura, discounted, recognitions, demographic, completed,
# Nearest to into: transformed, tandy, heterocyclic, insect, divided, housekeeping, desegregation, exhausting,
# Nearest to state: u, district, states, university, council, missouri, independent, municipalities,
# Nearest to only: not, lose, lombardic, construct, just, person, above, all,
# Nearest to three: four, zero, unpaved, five, two, seven, eight, runways,
# Nearest to more: than, capable, monadology, less, waits, casual, causing, sophisticated,
# Nearest to is: note, meaning, equal, triangle, above, ritalin, characteristic, exists,
# Nearest to states: united, countries, immigration, member, constitution, commonwealth, diplomatic, district,
# Nearest to san: francisco, jose, diego, rudolph, los, rhodes, california, missouri,
# Nearest to writers: fiction, novelists, authors, literature, science, poets, stories, revival,
# Nearest to quite: forms, inflections, true, illustrates, sins, gathered, merits, curtail,
# Nearest to stage: mlb, performance, performances, whitehouse, annoy, feathers, fatal, puff,
# Nearest to egypt: arabia, arab, seaport, osama, coastline, syria, egyptians, sudan,
# Nearest to arts: students, school, style, presented, prestwich, college, sciences, lanham,
# Nearest to recorded: band, album, singles, recording, ever, debut, billboard, summer,
# Nearest to versions: version, operating, released, computer, specifications, functionality, extensions, ms,
# Epoch 4/5 Iteration: 16100 Avg. Training loss: 3.4455 0.4886 sec/batch
# Epoch 4/5 Iteration: 16200 Avg. Training loss: 3.4672 0.4795 sec/batch
# Epoch 4/5 Iteration: 16300 Avg. Training loss: 3.4325 0.6917 sec/batch
# Epoch 4/5 Iteration: 16400 Avg. Training loss: 3.3789 0.5506 sec/batch
# Epoch 4/5 Iteration: 16500 Avg. Training loss: 3.4378 0.5876 sec/batch
# Epoch 4/5 Iteration: 16600 Avg. Training loss: 3.4401 0.6803 sec/batch
# Epoch 4/5 Iteration: 16700 Avg. Training loss: 3.4500 0.7025 sec/batch
# Epoch 4/5 Iteration: 16800 Avg. Training loss: 3.4278 0.9180 sec/batch
# Epoch 4/5 Iteration: 16900 Avg. Training loss: 3.4568 1.0082 sec/batch
# Epoch 4/5 Iteration: 17000 Avg. Training loss: 3.4493 1.0018 sec/batch
# Nearest to in: sheedy, completed, frederik, hrerbunker, laura, dichromate, recognitions, demographic,
# Nearest to into: transformed, tandy, heterocyclic, divided, desegregation, subdivided, region, epiphanes,
# Nearest to state: district, independent, u, minister, council, cabinet, senator, states,
# Nearest to only: not, lombardic, gluing, person, construct, lose, thirds, monadology,
# Nearest to three: four, zero, eight, two, five, seven, six, isbn,
# Nearest to more: than, less, capable, monadology, casual, waits, considerably, common,
# Nearest to is: triangle, meaning, note, ritalin, representations, hesychasm, characteristic, savior,
# Nearest to states: united, countries, commonwealth, immigration, member, district, constitution, caribbean,
# Nearest to san: francisco, jose, rudolph, rafael, puerto, diego, california, rhodes,
# Nearest to writers: fiction, authors, novelists, science, literature, poets, readers, stories,
# Nearest to quite: forms, sins, true, inflections, merits, illustrates, think, condemn,
# Nearest to stage: performance, mlb, whitehouse, wonderland, performances, puff, annoy, feathers,
# Nearest to egypt: arabia, arab, israel, syria, osama, egyptians, sudan, seaport,
# Nearest to arts: students, style, school, sciences, college, institutions, presented, prestwich,
# Nearest to recorded: album, band, singles, recording, billboard, summer, charts, billy,
# Nearest to versions: version, specifications, operating, systems, ms, newer, extensions, bit,
# Epoch 4/5 Iteration: 17100 Avg. Training loss: 3.4168 1.0655 sec/batch
# Epoch 4/5 Iteration: 17200 Avg. Training loss: 3.3688 0.9605 sec/batch
# Epoch 4/5 Iteration: 17300 Avg. Training loss: 3.4012 0.9485 sec/batch
# Epoch 4/5 Iteration: 17400 Avg. Training loss: 3.3633 0.9230 sec/batch
# Epoch 4/5 Iteration: 17500 Avg. Training loss: 3.4112 0.9271 sec/batch
# Epoch 4/5 Iteration: 17600 Avg. Training loss: 3.4519 0.8661 sec/batch
# Epoch 4/5 Iteration: 17700 Avg. Training loss: 3.4942 0.9321 sec/batch
# Epoch 4/5 Iteration: 17800 Avg. Training loss: 3.3582 0.9007 sec/batch
# Epoch 4/5 Iteration: 17900 Avg. Training loss: 3.3837 0.9016 sec/batch
# Epoch 4/5 Iteration: 18000 Avg. Training loss: 3.4002 0.8666 sec/batch
# Nearest to in: sheedy, hrerbunker, dichromate, frederik, laura, completed, discounted, nationalized,
# Nearest to into: transformed, tandy, desegregation, subdivided, divided, region, heterocyclic, northern,
# Nearest to state: district, missouri, u, independent, states, municipalities, formed, senator,
# Nearest to only: person, not, lombardic, superior, lose, construct, castel, gluing,
# Nearest to three: four, unpaved, zero, eight, seven, five, two, one,
# Nearest to more: than, less, monadology, casual, capable, waits, cheaper, refined,
# Nearest to is: triangle, note, meaning, representations, ritalin, equal, above, savior,
# Nearest to states: united, constitution, immigration, countries, commonwealth, district, president, member,
# Nearest to san: francisco, jose, diego, california, rudolph, puerto, los, rafael,
# Nearest to writers: novelists, fiction, authors, poets, science, literature, readers, american,
# Nearest to quite: true, inflections, pretext, fragmenting, forms, seem, derive, sins,
# Nearest to stage: performance, mlb, whitehouse, performances, musicians, wonderland, trumpeter, funniest,
# Nearest to egypt: arabia, arab, syria, israel, sudan, egyptians, seaport, osama,
# Nearest to arts: students, school, style, college, sciences, institutions, martial, architecture,
# Nearest to recorded: album, band, singles, recording, debut, billboard, charts, flopped,
# Nearest to versions: version, windows, systems, newer, extensions, operating, basic, functionality,
# Epoch 4/5 Iteration: 18100 Avg. Training loss: 3.2965 0.8088 sec/batch
# Epoch 4/5 Iteration: 18200 Avg. Training loss: 3.3426 0.5935 sec/batch
# Epoch 4/5 Iteration: 18300 Avg. Training loss: 3.3586 0.4910 sec/batch
# Epoch 4/5 Iteration: 18400 Avg. Training loss: 3.3654 0.4923 sec/batch
# Epoch 4/5 Iteration: 18500 Avg. Training loss: 3.3972 0.4897 sec/batch
# Epoch 5/5 Iteration: 18600 Avg. Training loss: 3.3633 0.4846 sec/batch
# Epoch 5/5 Iteration: 18700 Avg. Training loss: 3.3114 0.4868 sec/batch
# Epoch 5/5 Iteration: 18800 Avg. Training loss: 3.3030 0.4844 sec/batch
# Epoch 5/5 Iteration: 18900 Avg. Training loss: 3.3265 0.4844 sec/batch
# Epoch 5/5 Iteration: 19000 Avg. Training loss: 3.3227 0.4854 sec/batch
# Nearest to in: sheedy, dichromate, discounted, completed, hrerbunker, sardonic, frederik, frisia,
# Nearest to into: transformed, subdivided, desegregation, divided, tandy, exhausting, heterocyclic, caravans,
# Nearest to state: district, missouri, michigan, senator, municipalities, formed, u, iowa,
# Nearest to only: lombardic, hira, not, construct, castel, gluing, bingham, gelre,
# Nearest to three: four, zero, unpaved, eight, seven, two, six, one,
# Nearest to more: than, casual, waits, less, monadology, capable, considerably, cheaper,
# Nearest to is: ritalin, triangle, representations, meaning, hesychasm, characteristic, ineffable, equal,
# Nearest to states: united, constitution, commonwealth, immigration, countries, district, mexico, legislation,
# Nearest to san: francisco, diego, jose, los, puerto, california, rudolph, rafael,
# Nearest to writers: novelists, authors, fiction, poets, literature, artists, readers, science,
# Nearest to quite: forms, inflections, fragmenting, anything, true, pretext, represent, going,
# Nearest to stage: performance, performances, mlb, whitehouse, musicians, roles, wonderland, studio,
# Nearest to egypt: syria, arabia, arab, egyptians, bc, israel, sudan, syrian,
# Nearest to arts: students, style, martial, school, sciences, disciplines, architecture, college,
# Nearest to recorded: album, band, singles, recording, billboard, charts, months, flopped,
# Nearest to versions: version, operating, windows, ms, os, dos, xp, systems,
# Epoch 5/5 Iteration: 19100 Avg. Training loss: 3.3106 0.4996 sec/batch
# Epoch 5/5 Iteration: 19200 Avg. Training loss: 3.2402 0.4834 sec/batch
# Epoch 5/5 Iteration: 19300 Avg. Training loss: 3.3199 0.4798 sec/batch
# Epoch 5/5 Iteration: 19400 Avg. Training loss: 3.3301 0.4815 sec/batch
# Epoch 5/5 Iteration: 19500 Avg. Training loss: 3.3207 0.4837 sec/batch
# Epoch 5/5 Iteration: 19600 Avg. Training loss: 3.2517 0.4832 sec/batch
# Epoch 5/5 Iteration: 19700 Avg. Training loss: 3.2005 0.4883 sec/batch
# Epoch 5/5 Iteration: 19800 Avg. Training loss: 3.2510 0.4817 sec/batch
# Epoch 5/5 Iteration: 19900 Avg. Training loss: 3.2032 0.4994 sec/batch
# Epoch 5/5 Iteration: 20000 Avg. Training loss: 3.2921 0.5196 sec/batch
# Nearest to in: dichromate, sheedy, lawlessness, stra, hrerbunker, discounted, completed, nationalized,
# Nearest to into: transformed, divided, subdivided, desegregation, heterocyclic, tandy, region, maclachlan,
# Nearest to state: district, michigan, missouri, university, u, municipalities, county, illinois,
# Nearest to only: lombardic, eternity, hira, gluing, staircases, construct, bingham, monadology,
# Nearest to three: four, zero, unpaved, two, eight, rd, seven, km,
# Nearest to more: than, less, considerably, casual, waits, capable, sophisticated, cheaper,
# Nearest to is: ritalin, triangle, meaning, representations, symbol, equal, above, hesychasm,
# Nearest to states: united, commonwealth, immigration, constitution, countries, caribbean, member, canada,
# Nearest to san: francisco, diego, jose, los, california, puerto, rudolph, rafael,
# Nearest to writers: novelists, authors, poets, fiction, literature, science, readers, fantasy,
# Nearest to quite: forms, daunting, inflections, fragmenting, knew, represent, impermanent, illustrates,
# Nearest to stage: performance, mlb, funniest, musicians, performances, whitehouse, candle, misalignment,
# Nearest to egypt: syria, bc, arabia, egyptians, arab, sudan, israel, sinai,
# Nearest to arts: students, institutions, school, sciences, style, academic, college, architecture,
# Nearest to recorded: album, band, recording, singles, billboard, musicians, tracks, summer,
# Nearest to versions: version, ms, operating, windows, dos, latest, os, basic,
# Epoch 5/5 Iteration: 20100 Avg. Training loss: 3.2687 0.6610 sec/batch
# Epoch 5/5 Iteration: 20200 Avg. Training loss: 3.2590 1.0479 sec/batch
# Epoch 5/5 Iteration: 20300 Avg. Training loss: 3.2560 1.1022 sec/batch
# Epoch 5/5 Iteration: 20400 Avg. Training loss: 3.2891 1.1460 sec/batch
# Epoch 5/5 Iteration: 20500 Avg. Training loss: 3.2938 1.0052 sec/batch
# Epoch 5/5 Iteration: 20600 Avg. Training loss: 3.2110 1.1123 sec/batch
# Epoch 5/5 Iteration: 20700 Avg. Training loss: 3.2357 0.8706 sec/batch
# Epoch 5/5 Iteration: 20800 Avg. Training loss: 3.2720 0.8342 sec/batch
# Epoch 5/5 Iteration: 20900 Avg. Training loss: 3.2499 0.7235 sec/batch
# Epoch 5/5 Iteration: 21000 Avg. Training loss: 3.2203 0.9177 sec/batch
# Nearest to in: hrerbunker, dichromate, laura, sheedy, frederik, stra, discounted, lawlessness,
# Nearest to into: transformed, divided, subdivided, desegregation, heterocyclic, insect, housekeeping, beast,
# Nearest to state: district, michigan, missouri, university, formed, u, municipalities, senator,
# Nearest to only: lombardic, monadology, gluing, just, not, superior, consequently, magnetotail,
# Nearest to three: four, zero, isbn, nd, rd, eight, two, five,
# Nearest to more: than, considerably, less, capable, cheaper, waits, casual, monadology,
# Nearest to is: ritalin, triangle, meaning, characteristic, representations, note, hesychasm, equal,
# Nearest to states: united, commonwealth, constitution, federal, establishments, member, immigration, countries,
# Nearest to san: francisco, diego, jose, california, los, puerto, antonio, rudolph,
# Nearest to writers: novelists, authors, fiction, poets, literature, readers, artists, science,
# Nearest to quite: forms, whitlock, impermanent, indicates, daunting, sprite, seem, cardozo,
# Nearest to stage: performance, performances, whitehouse, mlb, funniest, musical, musicians, puff,
# Nearest to egypt: syria, arabia, egyptians, arab, israel, bc, sudan, ethiopian,
# Nearest to arts: students, institutions, school, sciences, college, style, universities, martial,
# Nearest to recorded: album, band, recording, singles, tracks, charts, songs, chart,
# Nearest to versions: version, ms, newer, dos, operating, windows, released, basic,
# Epoch 5/5 Iteration: 21100 Avg. Training loss: 3.2272 0.5625 sec/batch
# Epoch 5/5 Iteration: 21200 Avg. Training loss: 3.2263 0.5774 sec/batch
# Epoch 5/5 Iteration: 21300 Avg. Training loss: 3.2414 0.5937 sec/batch
# Epoch 5/5 Iteration: 21400 Avg. Training loss: 3.2412 0.4989 sec/batch
# Epoch 5/5 Iteration: 21500 Avg. Training loss: 3.2582 0.5299 sec/batch
# Epoch 5/5 Iteration: 21600 Avg. Training loss: 3.2737 0.5032 sec/batch
# Epoch 5/5 Iteration: 21700 Avg. Training loss: 3.2087 0.4896 sec/batch
# Epoch 5/5 Iteration: 21800 Avg. Training loss: 3.2006 0.4893 sec/batch
# Epoch 5/5 Iteration: 21900 Avg. Training loss: 3.2128 0.5123 sec/batch
# Epoch 5/5 Iteration: 22000 Avg. Training loss: 3.2043 0.4821 sec/batch
# Nearest to in: dichromate, hrerbunker, sheedy, religous, lawlessness, discounted, laura, frederik,
# Nearest to into: transformed, region, subdivided, desegregation, divided, insect, beast, overwrite,
# Nearest to state: district, illinois, michigan, states, legislature, county, senator, property,
# Nearest to only: perestroika, lombardic, superior, monadology, person, hira, gluing, gelre,
# Nearest to three: four, zero, five, isbn, seven, rd, eight, two,
# Nearest to more: than, less, considerably, monadology, waits, casual, deeper, cheaper,
# Nearest to is: representations, ritalin, note, triangle, endpoints, meaning, characteristic, hesychasm,
# Nearest to states: united, constitution, federal, commonwealth, member, caribbean, u, countries,
# Nearest to san: francisco, jose, diego, california, antonio, los, puerto, juan,
# Nearest to writers: novelists, authors, fiction, poets, literature, artists, science, readers,
# Nearest to quite: forms, daunting, whitlock, impermanent, fragmenting, seem, sprite, bunyip,
# Nearest to stage: performance, whitehouse, performances, funniest, musicians, mlb, actors, musical,
# Nearest to egypt: syria, israel, egyptians, arab, arabia, bc, sinai, ethiopian,
# Nearest to arts: students, academic, sciences, style, school, institutions, college, centre,
# Nearest to recorded: album, singles, band, recording, charts, chart, musicians, flopped,
# Nearest to versions: version, ms, windows, dos, basic, newer, xp, intended,
# Epoch 5/5 Iteration: 22100 Avg. Training loss: 3.2159 0.5204 sec/batch
# Epoch 5/5 Iteration: 22200 Avg. Training loss: 3.2951 0.4825 sec/batch
# Epoch 5/5 Iteration: 22300 Avg. Training loss: 3.2823 0.4865 sec/batch
# Epoch 5/5 Iteration: 22400 Avg. Training loss: 3.2312 0.5003 sec/batch
# Epoch 5/5 Iteration: 22500 Avg. Training loss: 3.1658 0.5374 sec/batch
# Epoch 5/5 Iteration: 22600 Avg. Training loss: 3.1869 0.4860 sec/batch
# Epoch 5/5 Iteration: 22700 Avg. Training loss: 3.1877 0.4935 sec/batch
# Epoch 5/5 Iteration: 22800 Avg. Training loss: 3.1567 0.5536 sec/batch
# Epoch 5/5 Iteration: 22900 Avg. Training loss: 3.1790 0.5188 sec/batch
# Epoch 5/5 Iteration: 23000 Avg. Training loss: 3.2090 0.5239 sec/batch
# Nearest to in: hrerbunker, dichromate, sheedy, lawlessness, fulton, discounted, stirner, frederik,
# Nearest to into: subdivided, transformed, divided, desegregation, region, yunnan, overwrite, housekeeping,
# Nearest to state: michigan, missouri, district, illinois, county, senator, iowa, legislature,
# Nearest to only: lombardic, construct, perestroika, magnetotail, monadology, ordinals, skimmed, gluing,
# Nearest to three: four, unpaved, zero, one, seven, eight, two, five,
# Nearest to more: than, less, considerably, casual, monadology, cheaper, waits, banteng,
# Nearest to is: ritalin, triangle, endpoints, hesychasm, representations, symbol, nominative, populous,
# Nearest to states: united, commonwealth, constitution, establishments, federal, u, member, bordered,
# Nearest to san: francisco, jose, diego, los, california, puerto, juan, antonio,
# Nearest to writers: novelists, authors, fiction, poets, literature, births, artists, fantasy,
# Nearest to quite: whitlock, daunting, pretext, impermanent, sprite, fragmenting, represent, rasterization,
# Nearest to stage: performance, performances, musical, actors, whitehouse, roles, musicians, theatre,
# Nearest to egypt: syria, israel, arab, egyptians, arabia, bc, sinai, syrian,
# Nearest to arts: students, martial, sciences, academic, school, engineering, disciplines, architecture,
# Nearest to recorded: album, band, recording, singles, charts, months, albums, songs,
# Nearest to versions: version, ms, dos, released, windows, xp, operating, newer,
# Epoch 5/5 Iteration: 23100 Avg. Training loss: 3.2219 0.5197 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
