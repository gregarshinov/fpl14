# %%
import numpy as np
import os
from random import shuffle
import re

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="52185e14-5bb9-43e1-86e7-350a67cd0bdb">Loading BokehJS ...</span>
#     </div>

# %%
import urllib.request
import lxml.etree

# %%
file = open('ted_en-20160408.xml', 'r', encoding="utf8")

# %%
doc = lxml.etree.parse(file)
input_text = '\n'.join(doc.xpath('//content/text()'))
del doc

# %%
i = input_text.find("Hyowon Gweon: See this?")
input_text[i-20:i+150]
# Out:
# ' baby does.\n(Video) Hyowon Gweon: See this? (Ball squeaks) Did you see that? (Ball squeaks) Cool. See this one? (Ball squeaks) Wow.\nLaura Schulz: Told you. (Laughs)\n(Vide'

# %%
input_text_noparens = re.sub(r'\([^)]*\)', '', input_text)

# %%
i = input_text_noparens.find("Hyowon Gweon: See this?")
input_text_noparens[i-20:i+150]
# Out:
# "hat the baby does.\n Hyowon Gweon: See this?  Did you see that?  Cool. See this one?  Wow.\nLaura Schulz: Told you. \n HG: See this one?  Hey Clara, this one's for you. You "

# %%
sentences_strings_ted = []
for line in input_text_noparens.split('\n'):
    m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
    sentences_strings_ted.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)

# Uncomment if you need to save some RAM: these strings are about 50MB.
# del input_text, input_text_noparens

# Let's view the first few:
sentences_strings_ted[:5]
# Out:
# ["Here are two reasons companies fail: they only do more of the same, or they only do what's new",
#  'To me the real, real solution to quality growth is figuring out the balance between two activities: exploration and exploitation',
#  ' Both are necessary, but it can be too much of a good thing',
#  'Consider Facit',
#  " I'm actually old enough to remember them"]

# %%
sentences_ted = []
for sent_str in sentences_strings_ted:
    tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
    sentences_ted.append(tokens)

# %%
len(sentences_ted)
# Out:
# 266694

# %%
print(sentences_ted[0])
print(sentences_ted[1])
# Out:
# ['here', 'are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's', 'new']
# ['to', 'me', 'the', 'real', 'real', 'solution', 'to', 'quality', 'growth', 'is', 'figuring', 'out', 'the', 'balance', 'between', 'two', 'activities', 'exploration', 'and', 'exploitation']

# %%
words_ted = [item for sublist in sentences_ted for item in sublist]
freq={}
for w in words_ted:
    if w in freq:
        freq[w] += 1
    else:
        freq[w] = 1

# %%
top1000 = sorted(freq, key = lambda x: int(freq[x]), reverse = True)
top1000 = top1000[:1000]

counts_ted_top1000 = []
for i in top1000:
    counts_ted_top1000.append(freq[i])

# %%
hist, edges = np.histogram(counts_ted_top1000, density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Top-1000 words distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fc85ca0c-0775-4a2b-a0db-c7382bf74020"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("fc85ca0c-0775-4a2b-a0db-c7382bf74020");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fc85ca0c-0775-4a2b-a0db-c7382bf74020");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fc85ca0c-0775-4a2b-a0db-c7382bf74020' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"96f6c35f-8d61-4d21-b828-97abd54b2bc5":{"roots":{"references":[{"attributes":{},"id":"ff39f2d0-534b-4e0f-b373-94f9c64520e1","type":"ResetTool"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"63192916-ccdd-45c6-8685-1a4e5db4f304","type":"Quad"},{"attributes":{"plot":{"id":"2facedcf-5669-4819-83a2-a28df7955a1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"a8470c0f-6456-415b-8504-7bdc8a3e7874","type":"BasicTicker"}},"id":"12fb7c9c-5643-4045-bc84-2b84d2ec53e9","type":"Grid"},{"attributes":{"formatter":{"id":"1db9c0cc-f730-4fb8-924e-ba0f11530bf3","type":"BasicTickFormatter"},"plot":{"id":"2facedcf-5669-4819-83a2-a28df7955a1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"7ec14016-532a-49a2-83c2-6843df657a1b","type":"BasicTicker"}},"id":"bc772763-e0ac-4956-84ed-4fd6fc767dda","type":"LinearAxis"},{"attributes":{"formatter":{"id":"d27d5d51-240f-46b9-b202-089d5a09cda8","type":"BasicTickFormatter"},"plot":{"id":"2facedcf-5669-4819-83a2-a28df7955a1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"a8470c0f-6456-415b-8504-7bdc8a3e7874","type":"BasicTicker"}},"id":"d134d7bc-c766-4eac-acac-20f957c68bfc","type":"LinearAxis"},{"attributes":{},"id":"0b5b465c-531a-4281-8b18-c2fa2e6455b3","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"2facedcf-5669-4819-83a2-a28df7955a1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"7ec14016-532a-49a2-83c2-6843df657a1b","type":"BasicTicker"}},"id":"dd7201fe-18ec-46b2-a223-3c23d61407a3","type":"Grid"},{"attributes":{},"id":"949384e0-6356-4e75-ac71-bf3853c0c929","type":"WheelZoomTool"},{"attributes":{},"id":"1db9c0cc-f730-4fb8-924e-ba0f11530bf3","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"c4d6b19b-1793-42f6-91ce-3751b6f8fc94","type":"DataRange1d"},{"attributes":{"source":{"id":"83810eb1-6aca-41ed-b42c-60a59615f466","type":"ColumnDataSource"}},"id":"9ab3e5e3-77db-4a0c-a5f4-1098e0a41d88","type":"CDSView"},{"attributes":{"plot":null,"text":"Top-1000 words distribution"},"id":"f2afb3de-cd0f-4f3d-be1d-0e7234d6f218","type":"Title"},{"attributes":{},"id":"d27d5d51-240f-46b9-b202-089d5a09cda8","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"35b493a6-698a-4c86-abe2-c71fb4892f5c","type":"DataRange1d"},{"attributes":{"data_source":{"id":"83810eb1-6aca-41ed-b42c-60a59615f466","type":"ColumnDataSource"},"glyph":{"id":"63192916-ccdd-45c6-8685-1a4e5db4f304","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"abd64190-2260-4667-8605-83028964b3b6","type":"Quad"},"selection_glyph":null,"view":{"id":"9ab3e5e3-77db-4a0c-a5f4-1098e0a41d88","type":"CDSView"}},"id":"180172dd-1d6f-48ae-87f7-ab11eb5fce07","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"83810eb1-6aca-41ed-b42c-60a59615f466","type":"ColumnDataSource"},{"attributes":{},"id":"90b5f0c0-b5d4-41a5-b9ca-02a8e045ff05","type":"SaveTool"},{"attributes":{},"id":"7ec14016-532a-49a2-83c2-6843df657a1b","type":"BasicTicker"},{"attributes":{},"id":"fe4bf9ea-35d9-4db0-b866-aed7d489325c","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fe4bf9ea-35d9-4db0-b866-aed7d489325c","type":"PanTool"},{"id":"949384e0-6356-4e75-ac71-bf3853c0c929","type":"WheelZoomTool"},{"id":"ff39f2d0-534b-4e0f-b373-94f9c64520e1","type":"ResetTool"},{"id":"90b5f0c0-b5d4-41a5-b9ca-02a8e045ff05","type":"SaveTool"}]},"id":"ca6d1abd-e07a-4fe3-8b92-db68772308e6","type":"Toolbar"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_colo ...

# %%
from gensim.models import Word2Vec

# %%
model1 = Word2Vec(sentences_ted, min_count=10)

# %%
model1.most_similar("man")
# Out:
# [('woman', 0.8370866179466248),
#  ('guy', 0.8027213215827942),
#  ('lady', 0.772685170173645),
#  ('girl', 0.7476345300674438),
#  ('boy', 0.7447001934051514),
#  ('soldier', 0.7234354615211487),
#  ('gentleman', 0.7049674987792969),
#  ('poet', 0.6929847002029419),
#  ('kid', 0.6863695979118347),
#  ('rabbi', 0.6764403581619263)]

# %%
model1.most_similar("computer")
# Out:
# [('machine', 0.7308882474899292),
#  ('robot', 0.7239102125167847),
#  ('software', 0.7124124765396118),
#  ('device', 0.6820383071899414),
#  ('program', 0.6371703743934631),
#  ('3d', 0.6336008310317993),
#  ('chip', 0.6303318738937378),
#  ('interface', 0.6233747005462646),
#  ('camera', 0.6195968389511108),
#  ('simulation', 0.616118311882019)]

# %%
model1.most_similar(positive=['flower', 'tree'], negative=['ground'])
# Out:
# [('neuron', 0.7101984024047852),
#  ('creature', 0.6920633912086487),
#  ('photo', 0.6713805198669434),
#  ('bird', 0.6547281742095947),
#  ('section', 0.6507145762443542),
#  ('bacterium', 0.647260844707489),
#  ('bee', 0.6467205286026001),
#  ('cage', 0.6423370242118835),
#  ('dolphin', 0.642247200012207),
#  ('tube', 0.6411620378494263)]

# %%
words_top_vec_ted = model1[top1000]

# %%
print(words_top_vec_ted)
# Out:
# [[-0.36918798 -1.32064271  0.90669852 ...,  0.92583233 -2.86785889
#   -0.01630816]
#  [-0.1027891  -0.03383823 -0.21138939 ...,  0.93501687 -0.99886638
#   -1.90030503]
#  [-0.23670186  0.32994321  0.79477692 ..., -0.31519613  1.17926311
#   -0.47619048]
#  ...,
#  [-1.19546926  0.40297848  0.72879303 ...,  1.10878217 -0.53809792
#   -1.14782846]
#  [-1.18012702 -0.27771175  1.21320963 ...,  0.28534794 -1.4027549
#   -0.51754224]
#  [ 1.16119611  1.04694653 -0.85677665 ...,  0.77769578 -0.73290694
#   -1.1953845 ]]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
top1000_tsne = tsne.fit_transform(words_top_vec_ted)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=top1000_tsne[:,0],
                                    x2=top1000_tsne[:,1],
                                    names=top1000))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c66b909-75ba-4217-9deb-3b51256b0abd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("8c66b909-75ba-4217-9deb-3b51256b0abd");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c66b909-75ba-4217-9deb-3b51256b0abd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c66b909-75ba-4217-9deb-3b51256b0abd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c1f1df9a-8faa-43aa-84be-36ea1ae6f082":{"roots":{"references":[{"attributes":{"plot":null,"text":"word2vec T-SNE for most common words"},"id":"a0131e7f-2f39-45ca-97c4-ad58bd588fb8","type":"Title"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"aa16fc7d-2477-4083-9d86-5fe5cb9db91d","type":"Circle"},{"attributes":{},"id":"62a99bad-8ea1-493c-8df7-ad5fa74c98a1","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"e658c863-7a40-406e-9c7f-81881e2b43f5","subtype":"Figure","type":"Plot"},"source":{"id":"287b850c-ee24-4459-bfe8-f1a22d19806b","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"b7798b51-5ce9-4a08-9281-27875a997841","type":"LabelSet"},{"attributes":{},"id":"04817c96-d698-4001-b496-21ec1d32e9f0","type":"ResetTool"},{"attributes":{"source":{"id":"287b850c-ee24-4459-bfe8-f1a22d19806b","type":"ColumnDataSource"}},"id":"0ca70531-1af9-49be-b9c5-c4d8d06ec8c5","type":"CDSView"},{"attributes":{},"id":"80baa572-0fb1-44cc-9ecd-6b8d2f28f7c2","type":"SaveTool"},{"attributes":{},"id":"9f282be9-c970-44a3-906e-96a140e5591e","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0d3bb607-45cd-4050-b1df-ad8ed57e5ab0","type":"PanTool"},{"id":"62a99bad-8ea1-493c-8df7-ad5fa74c98a1","type":"WheelZoomTool"},{"id":"04817c96-d698-4001-b496-21ec1d32e9f0","type":"ResetTool"},{"id":"80baa572-0fb1-44cc-9ecd-6b8d2f28f7c2","type":"SaveTool"}]},"id":"a5004c85-f148-4d13-9b69-15e68fc2acde","type":"Toolbar"},{"attributes":{},"id":"d8c17ac8-f626-4fd9-a4b3-fdeda9012c55","type":"LinearScale"},{"attributes":{"callback":null},"id":"010a8b78-69a0-4651-83e7-3c2ead0bf1b3","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"b05e4450-2682-4603-bcba-2471e0bab51f","type":"Circle"},{"attributes":{},"id":"3c33a621-8137-4ecb-a301-d0e820e3fd3d","type":"BasicTickFormatter"},{"attributes":{},"id":"c9cd1e23-5fd1-433c-a906-aa97afaa5e86","type":"LinearScale"},{"attributes":{"plot":{"id":"e658c863-7a40-406e-9c7f-81881e2b43f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"92ee5adc-2c6f-4aac-9b7b-9de27f04f19c","type":"BasicTicker"}},"id":"3bb6f0e5-c8d2-4ad4-88d4-98c0e73be06f","type":"Grid"},{"attributes":{"formatter":{"id":"3c33a621-8137-4ecb-a301-d0e820e3fd3d","type":"BasicTickFormatter"},"plot":{"id":"e658c863-7a40-406e-9c7f-81881e2b43f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"92ee5adc-2c6f-4aac-9b7b-9de27f04f19c","type":"BasicTicker"}},"id":"cd721593-e2f0-4563-a719-96a6c6aa166e","type":"LinearAxis"},{"attributes":{},"id":"92ee5adc-2c6f-4aac-9b7b-9de27f04f19c","type":"BasicTicker"},{"attributes":{"formatter":{"id":"9f282be9-c970-44a3-906e-96a140e5591e","type":"BasicTickFormatter"},"plot":{"id":"e658c863-7a40-406e-9c7f-81881e2b43f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"58a57b3f-a246-4539-818f-ea200923dfa9","type":"BasicTicker"}},"id":"4f6df913-812a-4e13-85f9-97f473ff2163","type":"LinearAxis"},{"attributes":{"callback":null},"id":"4ced7b0d-99b2-40a4-9257-6957493d3370","type":"DataRange1d"},{"attributes":{},"id":"58a57b3f-a246-4539-818f-ea200923dfa9","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"e658c863-7a40-406e-9c7f-81881e2b43f5","subtype":"Figure","type":"Plot"},"ticker":{"id":"58a57b3f-a246-4539-818f-ea200923dfa9","type":"BasicTicker"}},"id":"68759eb5-49ef-455c-b0ee-9d328a64c4e4","type":"Grid"},{"attributes":{"below":[{"id":"cd721593-e2f0-4563-a719-96a6c6aa166e","type":"LinearAxis"}],"left":[{"id":"4f6df913-812a-4e13-85f9-97f473ff2163","type":"LinearAxis"}],"ren ...

# %%
input_text = str(open('wiki.train.raw', 'r').read())
print(input_text[:1000])


sentences_wiki = []
for line in input_text.split('\n'):
    s = [x for x in line.split('.') if x and len(x.split()) >= 5]
    sentences_wiki.extend(s)
    
for s_i in range(len(sentences_wiki)):
    sentences_wiki[s_i] = re.sub("[^a-z]", " ", sentences_wiki[s_i].lower())
    sentences_wiki[s_i] = re.sub(r'\([^)]*\)', '', sentences_wiki[s_i])
del input_text
# Out:
#
#  = Valkyria Chronicles III =
#
#  Senjō no Valkyria 3 : Unrecorded Chronicles ( Japanese : 戦場のヴァルキュリア3 , lit . Valkyria of the Battlefield 3 ) , commonly referred to as Valkyria Chronicles III outside Japan , is a tactical role @-@ playing video game developed by Sega and Media.Vision for the PlayStation Portable . Released in January 2011 in Japan , it is the third game in the Valkyria series . Employing the same fusion of tactical and real @-@ time gameplay as its predecessors , the story runs parallel to the first game and follows the " Nameless " , a penal military unit serving the nation of Gallia during the Second Europan War who perform secret black operations and are pitted against the Imperial unit " Calamaty Raven " .
#  The game began development in 2010 , carrying over a large portion of the work done on Valkyria Chronicles II . While it retained the standard features of the series , it also underwent multiple adjustments , such as making the game more forgiving for series

# %%
n_sentences_wiki = []
for sent_str in sentences_wiki:
    n_sentences_wiki.append(sent_str.split())

# sample 1/5 of the data
shuffle(n_sentences_wiki)
print(len(n_sentences_wiki))
n_sentences_wiki = n_sentences_wiki[:int(len(n_sentences_wiki)/5)]
print(len(n_sentences_wiki))
# Out:
# 1429102
# 285820

# %%
freqs = {}
for sentence in n_sentences_wiki:
    for word in sentence:
        if word in freqs:
            freqs[word] += 1
        else:
            freqs[word] = 1

# %%
words_top_wiki = sorted(freqs, key=lambda x: int(freqs[x]), reverse=True)
counts_wiki_top1000 = [freqs[word] for word in words_top_wiki[:1000]]

print(words_top_wiki[:10])
print(counts_wiki_top1000[:10])
# Out:
# ['the', 'of', 'and', 'in', 'to', 'a', 'was', 's', 'on', 'as']
# [429871, 183856, 167962, 145492, 133052, 120971, 71687, 55047, 51595, 48557]

# %%
hist, edges = np.histogram(counts_wiki_top1000, density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Top-1000 words distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="31bb7da8-c5c8-4f85-a5c1-687451558225"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("31bb7da8-c5c8-4f85-a5c1-687451558225");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("31bb7da8-c5c8-4f85-a5c1-687451558225");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '31bb7da8-c5c8-4f85-a5c1-687451558225' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b3cc7c2b-3e41-442a-a8d0-6af5a6c77b94":{"roots":{"references":[{"attributes":{"plot":{"id":"5e8fca1e-849f-4ba7-bb44-e8fe6dcdf067","subtype":"Figure","type":"Plot"}},"id":"31875356-b9a2-4277-bbbe-d66b5733c599","type":"SaveTool"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3111ef1b-6035-4c81-99ec-b089e9061c4a","type":"Quad"},{"attributes":{"below":[{"id":"87b3307f-6859-428b-994e-69cae392ed77","type":"LinearAxis"}],"left":[{"id":"6dbc595a-158a-4ad3-ba64-8d1a53f13cd1","type":"LinearAxis"}],"renderers":[{"id":"87b3307f-6859-428b-994e-69cae392ed77","type":"LinearAxis"},{"id":"b9b5ee6d-f4ac-4c5d-ad74-3eda2a16647c","type":"Grid"},{"id":"6dbc595a-158a-4ad3-ba64-8d1a53f13cd1","type":"LinearAxis"},{"id":"ecaccb89-868e-42de-93f6-60a5be4364d2","type":"Grid"},{"id":"e8125f8b-a38b-46cb-a3c6-3a3ef96a3e12","type":"GlyphRenderer"}],"title":{"id":"1998b91b-327c-4daf-99f3-94d3f42963bf","type":"Title"},"tool_events":{"id":"a5224ae0-dd8c-4a38-b018-d39c275373af","type":"ToolEvents"},"toolbar":{"id":"08c46c1f-b415-48d0-9a81-bd8361428660","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"ff43851c-2bfe-4a48-852c-87a1bcf84499","type":"DataRange1d"},"y_range":{"id":"a9cfde82-980a-44c2-9b8d-c0135c471798","type":"DataRange1d"}},"id":"5e8fca1e-849f-4ba7-bb44-e8fe6dcdf067","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"11d360a4-23fa-4565-83b6-dc11aadb323c","type":"BasicTickFormatter"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"1b3c70d0-0f0f-44e7-bdc3-cdae6bae5188","type":"Quad"},{"attributes":{},"id":"7fd32546-e019-4218-9bcd-fc89055afd81","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"d1469d0d-6115-47e0-92bb-2f8a98f80ea2","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"5e8fca1e-849f-4ba7-bb44-e8fe6dcdf067","subtype":"Figure","type":"Plot"}},"id":"c67c2e2e-5466-4293-9e0a-37f6351a5351","type":"PanTool"},{"attributes":{"plot":null,"text":"Top-1000 words distribution"},"id":"1998b91b-327c-4daf-99f3-94d3f42963bf","type":"Title"},{"attributes":{"plot":{"id":"5e8fca1e-849f-4ba7-bb44-e8fe6dcdf067","subtype":"Figure","type":"Plot"}},"id":"df04c05a-ef8a-4edd-9409-2c0f7ab09343","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"ff43851c-2bfe-4a48-852c-87a1bcf84499","type":"DataRange1d"},{"attributes":{"data_source":{"id":"d1469d0d-6115-47e0-92bb-2f8a98f80ea2","type":"ColumnDataSource"},"glyph":{"id":"3111ef1b-6035-4c81-99ec-b089e9061c4a","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1b3c70d0-0f0f-44e7-bdc3-cdae6bae5188","type":"Quad"},"selection_glyph":null},"id":"e8125f8b-a38b-46cb-a3c6-3a3ef96a3e12","type":"GlyphRenderer"},{"attributes":{},"id":"a5224ae0-dd8c-4a38-b018-d39c275373af","type":"ToolEvents"},{"attributes":{"plot":{"id":"5e8fca1e-849f-4ba7-bb44-e8fe6dcdf067","subtype":"Figure","type":"Plot"}},"id":"5c6669ee-50e8-49ba-a6cf-cd8f87d70a45","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c67c2e2e-5466-4293-9e0a-37f6351a5351","type":"PanTool"},{"id":"df04c05a-ef8a-4edd-9409-2c0f7ab09343","type":"WheelZoomTool"},{"id":"5c6669ee-50e8-49ba-a6cf-cd8f87d70a45","type":"ResetTool"},{"id":"31875356-b9a2-4277-bbbe-d66b5733c599","type":"SaveTool"}]},"id":"08c46c1f-b415-48d0-9a81-bd8361428660","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"5e8fca1e-849f-4ba7-bb44-e8fe6dcdf067","subtype":"Figure","type":"Plot"},"ticker":{"i ...

# %%
model2 = Word2Vec(min_count = 5, size=100, sentences = n_sentences_wiki)

# %%
model2.most_similar('boy')
# Out:
# [('protagonist', 0.7549673914909363),
#  ('girl', 0.7314180135726929),
#  ('dog', 0.7259712219238281),
#  ('man', 0.705185055732727),
#  ('dragon', 0.7040812373161316),
#  ('hero', 0.7023768424987793),
#  ('kid', 0.6906249523162842),
#  ('monster', 0.6857444047927856),
#  ('baby', 0.6763310432434082),
#  ('batman', 0.6622106432914734)]

# %%
model2.most_similar('flower')
# Out:
# [('coloured', 0.8598988056182861),
#  ('metallic', 0.8580095767974854),
#  ('winged', 0.8567759990692139),
#  ('pale', 0.8539287447929382),
#  ('tiny', 0.8502558469772339),
#  ('spore', 0.8488335609436035),
#  ('walled', 0.8438517451286316),
#  ('olive', 0.8370686173439026),
#  ('slender', 0.8330860137939453),
#  ('buff', 0.832647442817688)]

# %%
model2.most_similar(positive=['man', 'boy'], negative=['girl'])
# Out:
# [('protagonist', 0.6099501848220825),
#  ('hero', 0.6006561517715454),
#  ('sword', 0.5794966816902161),
#  ('dragon', 0.5587184429168701),
#  ('batman', 0.5460250973701477),
#  ('character', 0.5434754490852356),
#  ('doctor', 0.5370021462440491),
#  ('player', 0.5330149531364441),
#  ('robot', 0.5314503312110901),
#  ('master', 0.5190551280975342)]

# %%
# This assumes words_top_wiki is a list of strings, the top 1000 words
words_top_vec_wiki = model2[words_top_wiki[:1000]]
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_wiki_tsne[:,0],
                                    x2=words_top_wiki_tsne[:,1],
                                    names=words_top_wiki))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
# /Users/galiasadykova/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:89: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3ad5db33-ce4e-4e04-a43a-ef49b97b9784"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3ad5db33-ce4e-4e04-a43a-ef49b97b9784");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3ad5db33-ce4e-4e04-a43a-ef49b97b9784");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3ad5db33-ce4e-4e04-a43a-ef49b97b9784' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d9f0d33c-d637-45f6-a44f-b2ed3bfc3b62":{"roots":{"references":[{"attributes":{},"id":"7c290c4e-a031-4fbf-9b9f-0f3dc8389370","type":"BasicTickFormatter"},{"attributes":{},"id":"901ee671-08de-4ebd-8a44-312c527efa71","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"}},"id":"ffe66d47-aab3-4f0e-8e1f-6d6d1651c401","type":"SaveTool"},{"attributes":{"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"}},"id":"b7e3fa10-0001-43a8-9a95-dde44a24f293","type":"ResetTool"},{"attributes":{"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"}},"id":"14fe0eca-cf9a-4d0a-a1eb-8433923cd6ae","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"}},"id":"d8d4996e-7108-4840-b6ee-a13ccf237ce6","type":"PanTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"e047d8bb-4dcd-4183-b692-a91114fe01b0","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b5b9a26-f727-4b4f-86d3-e65b67324665","type":"BasicTicker"}},"id":"981f1161-4043-4a3a-9b79-ccc0d30cc815","type":"Grid"},{"attributes":{},"id":"3b5b9a26-f727-4b4f-86d3-e65b67324665","type":"BasicTicker"},{"attributes":{"data_source":{"id":"ac85a0b0-47dc-4444-9351-cbf39ec63acb","type":"ColumnDataSource"},"glyph":{"id":"e047d8bb-4dcd-4183-b692-a91114fe01b0","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a4290a62-4f69-474f-ac28-d7185cf02dfe","type":"Circle"},"selection_glyph":null},"id":"4e4b8b44-274a-4eb2-9f39-53ae8f1973f6","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"901ee671-08de-4ebd-8a44-312c527efa71","type":"BasicTickFormatter"},"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b5b9a26-f727-4b4f-86d3-e65b67324665","type":"BasicTicker"}},"id":"8f47f487-2079-437f-baae-50a97b3b0667","type":"LinearAxis"},{"attributes":{"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"},"ticker":{"id":"e10349fe-8385-4d5d-a02f-0d19533e95c2","type":"BasicTicker"}},"id":"793fc9b7-136a-445d-be99-eead6006dae7","type":"Grid"},{"attributes":{},"id":"e10349fe-8385-4d5d-a02f-0d19533e95c2","type":"BasicTicker"},{"attributes":{"callback":null},"id":"c654d528-22c7-4ed5-b9ed-04706592bd11","type":"DataRange1d"},{"attributes":{"formatter":{"id":"7c290c4e-a031-4fbf-9b9f-0f3dc8389370","type":"BasicTickFormatter"},"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"},"ticker":{"id":"e10349fe-8385-4d5d-a02f-0d19533e95c2","type":"BasicTicker"}},"id":"cc00e938-bc16-4cd9-9050-75f0bafdc790","type":"LinearAxis"},{"attributes":{"plot":{"id":"56014279-d5f4-4efd-9b8b-575d178ba527","subtype":"Figure","type":"Plot"},"source":{"id":"ac85a0b0-47dc-4444-9351-cbf39ec63acb","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"d4ff574e-e2a6-445e-b787-e936de0bab6c","type":"LabelSet"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d8d4996e-7108-4840-b6ee-a13ccf237ce6","type":"PanTool"},{"id":"14fe0eca-cf9a-4d0a-a1eb-8433923cd6ae","type":"WheelZoomTool"},{"id":"b7e3fa10-0001-43a8-9a95-dde44a24f293","type":"ResetTool"},{"id":"ffe66d47-aab3-4f0e-8e1f-6d6d1651c401","type":"SaveTool"}]},"id":"ea6d607d-3758-4967-a089-2f817162d96d","type":"Toolbar"},{"attributes":{},"id":"a876dd7e-a937-4774-a2c7-fdf70e6283ad","type":"ToolEvents"},{"attributes":{"callback":null},"id":"52e2a398-e2b3-4112-97ce-95f67342ae09","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0. ...
